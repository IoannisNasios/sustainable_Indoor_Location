# %%
print('Connect to google drive')


from google.colab import drive
drive.mount('/gdrive')=
# Out:
# Connect to google drive
# Mounted at /gdrive

# %%
print('Import necessary libraries')

import numpy as np
import pandas as pd
import scipy.stats as stats
from pathlib import Path
import glob
import pickle

import warnings
warnings.filterwarnings("ignore")

import random
import os
# os.environ["CUDA_VISIBLE_DEVICES"]="0"
import gc
import tqdm

from sklearn.model_selection import StratifiedKFold, GroupKFold
from sklearn.preprocessing import StandardScaler, LabelEncoder

import joblib

import tensorflow as tf
import tensorflow.keras.layers as L
import tensorflow.keras.models as M
import tensorflow.keras.backend as K
from tensorflow.keras.callbacks import ReduceLROnPlateau, ModelCheckpoint, EarlyStopping, LearningRateScheduler
# Out:
# Import necessary libraries

# %%
base_path='/gdrive/My Drive/Colab Notebooks/'
weights_path='/gdrive/My Drive/Colab Notebooks/weights/'

# %%
def euclidean_distance(x_true,y_true, x_pred, y_pred):
    return np.mean(((x_true-x_pred)**2+(y_true-y_pred)**2)**0.5)

# %%
version='forPdata423_BSSIDSresilience'

# %%
data=pd.read_csv('/gdrive/My Drive/Colab Notebooks/data423.csv.zip') ta.shape
# Out:
# (14373, 316)

# %%
rssidsnums=[int(x[4:]) for x in data.columns if 'rsid' in x]
print(len(rssidsnums))
# Out:
# 312

# %%
data.head()
# Out:
#    rsid1  rsid2  rsid3  ...      y      timestamp                        path
# 0    -93   -999    -81  ...  25.89  1633934464983  record_2021_10_11_07_41_02
# 1    -93   -999    -81  ...  25.89  1633934467125  record_2021_10_11_07_41_02
# 2   -999   -999   -999  ...  25.89  1633934469251  record_2021_10_11_07_41_02
# 3   -999   -999   -999  ...  25.89  1633934471370  record_2021_10_11_07_41_02
# 4    -78   -999   -999  ...  25.74  1633934473508  record_2021_10_11_07_41_02
#
# [5 rows x 316 columns]

# %%
# print('split path-timestamp in 2 columns')
# data[['path','timestamp']]=data['path-timestamp'].str.split('-',expand=True)
# print('remove path-timestamp column')
# data.drop('path-timestamp', axis=1,inplace=True)

# %%
# data.head()

# %%
dataA=data.copy()

# %%
# num_of_lines=len(dataA)
# data2=[]
# for i in range(num_of_lines):
#     # if i % 1000 == 0:
#     #     print(f'current:{i}')

#     tmp=dataA.iloc[i,:-4].astype(int).reset_index(drop=False)
#     tmp.columns=['BSSID','Signal_Strength']
#     tmp=tmp.sort_values(['Signal_Strength', 'BSSID'],ascending=False)
#     target = dataA.iloc[i,-4:]

#     line = pd.concat([pd.Series(tmp.BSSID.astype(str)), tmp.Signal_Strength.astype(int), target])

#     line.index = [str(i) for i in range(2*len(tmp)+4)]

#     data2.append(line.values)
# data2 = pd.DataFrame(np.stack(data2))

# data2.columns = [f'BSSID{str(i)}' for i in range(len(tmp))] + [f'Signal_Strength_{str(i)}' for i in range(len(tmp))] + ['x','y', 'timestamp', 'path']
# # data.to_csv(SAVEDIR+file_name, index=False)

# %%
# target

# %%
# data=data2.copy()

# %%
# data.head()

# %%
# a=data.loc[:,[x for x in data.columns if x.startswith('Signal_Strength')]].max().values
# MAX_NUM_WIFIS=np.where(a[a>-999])[0].max()
# MAX_NUM_WIFIS

# %%
# wifi_bssids = []
# for i in range(len(BSSID_FEATS)):
#     wifi_bssids.extend(data.iloc[:,i].values.tolist())
# wifi_bssids = list(set(wifi_bssids))

# wifi_bssids = np.unique(wifi_bssids)
# wifi_bssids_size = len(wifi_bssids)
# print(wifi_bssids_size)

# wifi_bssids_dict={}
# counter = 0               #<-------------  1 not 0
# for wf in wifi_bssids:
#     wifi_bssids_dict[wf]=counter
#     counter+=1
# # import joblib
# # joblib.dump(wifi_bssids_dict,'wifi_bssids_dict2')

# %%
# for i in BSSID_FEATS[:MAX_NUM_WIFIS]:
# for i in BSSID_FEATS:
#     data.loc[:,i] = data.loc[:,i] .apply(lambda x: wifi_bssids_dict[x])

# %%
# data.loc[:,BSSID_FEATS[:MAX_NUM_WIFIS]]=data.loc[:,BSSID_FEATS[:MAX_NUM_WIFIS]].astype('float32')

# %%
# Ms=np.mean(data.loc[:,RSSI_FEATS[:MAX_NUM_WIFIS]].values.astype('float32'),axis=0)
# Ss=np.std(data.loc[:,RSSI_FEATS[:MAX_NUM_WIFIS]].values.astype('float32'),axis=0)
# # joblib.dump(Ms,'means_of_rssids2')
# # joblib.dump(Ss,'stds_of_rssids2')
# Ms[:5],Ss[:5]

# %%
# for i in range(MAX_NUM_WIFIS):
#     data.loc[:,RSSI_FEATS[i]] = ((data.loc[:,RSSI_FEATS[i]] - Ms[i])/(Ss[i]+1)).astype('float32')

# %%
# data.loc[:,RSSI_FEATS].head()

# %%
# TRAIN_FEATS=[x for x in data.columns if x not in ['x', 'y', 'path', 'timestamp']]
# len(TRAIN_FEATS)

# %%
# d2=data.loc[:,TRAIN_FEATS].copy()
# d2[d2==-999]=0
# d2[d2!=0]=1

# %%
# d2.head()

# %%
# import matplotlib.pyplot as plt
# plt.hist(np.sum(d2,0),50)
# plt.show()

# %%
# Ms=np.mean(data.loc[:,TRAIN_FEATS].values,axis=0)
# Ss=np.std(data.loc[:,TRAIN_FEATS].values,axis=0)

# # joblib.dump(Ms,'means_of_rssids2')
# # joblib.dump(Ss,'stds_of_rssids2')

# for i in range(len(TRAIN_FEATS)):
#     data.loc[:,TRAIN_FEATS[i]] = (data.loc[:,TRAIN_FEATS[i]] - Ms[i])/(Ss[i]+1)

# %%
# unpaths=data.path.unique()

# %%
# print('we have ',len(unpaths),' unique paths')

# %%
# USE_FEATS=TRAIN_FEATS[:]
# # USE_FEATS=np.array(TRAIN_FEATS)[np.where((np.sum(d2,0))>200)[0]]
# USE_FEATS.shape

# %% [markdown]
# ### CV TRAIN

# %%
def create_model(bssid_size1, rssi_size):

    def myFunc(x,size=bssid_size1):
        return x[:,:size]
    def myFunc2(x,size=bssid_size1):
        return x[:,size:]
            
    input_layer_all = L.Input(shape=(bssid_size1+ rssi_size,), name='inputL', dtype='float32')
    # input_layer_all = L.Dropout(0.1, name='do1')(input_layer_all)    
    input_embd_layer = L.Lambda(myFunc )(input_layer_all)
    x1 = L.Embedding(wifi_bssids_size, 4, name='emb_bssid')(input_embd_layer)
#     x1 = L.Dropout(0.1)(x1)
    x1 = L.Flatten( name='fl_bssid')(x1)
    # print(x1.shape)
    
    
    # rssi feats
    # input_layer = L.Input((rssi_size, ), name='input_rsid', dtype='float32')
    input_layer = L.Lambda(myFunc2)(input_layer_all)
    x2 = L.BatchNormalization(name='bn1')(input_layer)
    x2 = L.Dense(rssi_size * 1, name='dn1')(x2)
    x2 = L.Dropout(0.1, name='do1')(x2)    
#     x2 = L.Dense(NUM_FEATS * 4, activation='relu')(x2)
    # print(x2.shape)
    

    
    # main stream
    x = L.Concatenate(axis=1, name='concat')([x1, x2])
    # print(x.shape)
#     x = L.Flatten()(x)
    x = L.BatchNormalization(name='bn2')(x)
    x = L.Dropout(0.5, name='do2')(x)
    x = L.Dense(256, name='dn2')(x)
#     x = L.Dropout(0.1)(x)
#     x = L.Dense(256, activation='relu')(x)

    x = L.Reshape((1 , 256), name='resh')(x)
#     x = L.Reshape((1 , -1))(x)
    # print(x.shape)
    x = L.BatchNormalization(name='bn3')(x)
    x = L.LSTM(128, return_sequences=True, name='lstm1')(x)
    x = L.Dropout(0.2, name='do3')(x)
    x = L.BatchNormalization(name='bn4')(x)    
    x = L.LSTM(64, return_sequences=True, name='lstm2')(x)
    x = L.Dropout(0.2, name='do4')(x)
#     x = L.Bidirectional(L.LSTM(512, return_sequences=True))(x)
#     x = L.BatchNormalization()(x)    
#     x = L.Bidirectional(L.LSTM(256, return_sequences=True))(x)    
    x = L.BatchNormalization(name='bn5')(x)
    x = L.LSTM(32, return_sequences=False, name='lstm3')(x)
    # x = L.LSTM(128, return_sequences=False, name='lstm3')(x)
#     x = L.Dropout(0.1)(x)
    # print(x.shape)
    
    
    
    x = L.BatchNormalization(name='bn6')(x)
#     x = L.Dropout(0.1)(x)
#     x = L.Dense(64)(x)
# #     x = L.Dropout(0.1)(x)
#     x = L.Dense(128)(x)
# #     x = L.Dense(64, activation='relu')(x)

    
    
    output_layer_1 = L.Dense(2, name='xy')(x)
#     output_layer_2 = L.Dense(1, activation='softmax', name='floor')(x)

    model = M.Model(inputs=input_layer_all, 
#     model = M.Model([input_embd_layer, input_embd_layerb, input_layer, input_site_layer], 
                    outputs=output_layer_1)
#                     [output_layer_1, output_layer_2])

    model.compile(optimizer=tf.keras.optimizers.Adam(lr=0.001),
                  loss='mse', metrics=['mse'])

    return model    
# model =  create_model(bssid_size1=MAX_NUM_WIFIS, rssi_size=MAX_NUM_WIFIS )
# model.summary()

# %%
def _cosine_anneal_schedule(t):
    cos_inner = np.pi * (t % (epochs // snapshots))
    cos_inner /= epochs // snapshots
    cos_out = np.cos(cos_inner) + 1
    return float(lr_0 / 2 * cos_out)

# %%
# NUM_FEATS=MAX_NUM_WIFIS
# NUM_FEATS

# %%
# # data.loc[:, ['x', 'y'] ]=data.loc[:, ['x', 'y'] ].values.astype('float32')
# # data.loc[:, ['x'] ]=data.loc[:, ['x'] ].values.astype('float32')
# # data.loc[:, ['y'] ]=data.loc[:, ['y'] ].values.astype('float32')
# data.x=data.x.values.astype('float32')
# data.y=data.y.values.astype('float32')
# data.loc[:, ['x', 'y'] ].dtypes

# %%
# X_train.min().values

# %%
# X_train.loc[:,RSSI_FEATS[:NUM_FEATS]].astype('float32').values
# X_train.loc[:,RSSI_FEATS[:NUM_FEATS]].values
# X_train.loc[:,RSSI_FEATS[NUM_FEATS-1]].values
# np.concatenate((X_train.loc[:,BSSID_FEATS[:NUM_FEATS]].values, X_train.loc[:,RSSI_FEATS[:NUM_FEATS]].values),1).shape
# np.concatenate((X_val.loc[:,BSSID_FEATS[:NUM_FEATS]].values, X_val.loc[:,RSSI_FEATS[:NUM_FEATS]].values),1).max()
# data.loc[:, ['x', 'y'] ].reset_index(drop=True).values

# %%
NUM_FEATS=60

# %%
data.shape
# Out:
# (14373, 316)

# %%
data.head()
# Out:
#    rsid1  rsid2  rsid3  ...      y      timestamp                        path
# 0    -93   -999    -81  ...  25.89  1633934464983  record_2021_10_11_07_41_02
# 1    -93   -999    -81  ...  25.89  1633934467125  record_2021_10_11_07_41_02
# 2   -999   -999   -999  ...  25.89  1633934469251  record_2021_10_11_07_41_02
# 3   -999   -999   -999  ...  25.89  1633934471370  record_2021_10_11_07_41_02
# 4    -78   -999   -999  ...  25.74  1633934473508  record_2021_10_11_07_41_02
#
# [5 rows x 316 columns]

# %%
TRAIN_FEATS=[x for x in data.columns if x not in ['x', 'y', 'path', 'timestamp']]
len(TRAIN_FEATS)
# Out:
# 312

# %%
keras_models=[]
wifi_bssids_size=312
name='keras'+'forPdata423'
for f in range(5):
    model = create_model(bssid_size1=60, rssi_size=60  )
    model.load_weights(weights_path+name+'_fold'+str(f)+'.hdf5')
    keras_models.append(model)

# %%
name='keras'+'forPdata423'
weights_path+name+'_fold'+str(f)+'.hdf5'
# Out:
# '/gdrive/My Drive/Colab Notebooks/weights/kerasforPdata423_fold4.hdf5'

# %%
dataA.iloc[:,-4-1:]
# Out:
#        rsid312      x      y      timestamp                        path
# 0         -999  43.26  25.89  1633934464983  record_2021_10_11_07_41_02
# 1         -999  43.26  25.89  1633934467125  record_2021_10_11_07_41_02
# 2         -999  43.26  25.89  1633934469251  record_2021_10_11_07_41_02
# 3         -999  43.26  25.89  1633934471370  record_2021_10_11_07_41_02
# 4         -999  40.85  25.74  1633934473508  record_2021_10_11_07_41_02
# ...        ...    ...    ...            ...                         ...
# 14368     -999  46.05  19.15  1634711038854  record_2021_10_20_07_23_22
# 14369     -999  46.05  19.15  1634711040987  record_2021_10_20_07_23_22
# 14370     -999  45.27  22.71  1634711043120  record_2021_10_20_07_23_22
# 14371     -999  45.27  22.71  1634711045229  record_2021_10_20_07_23_22
# 14372     -999  43.49  22.71  1634711047366  record_2021_10_20_07_23_22
#
# [14373 rows x 5 columns]

# %%
# CROSS VALIDATION

name='keras'+version

scores=[]
for rs in range(312):
    # np.random.seed(2022+rs)
    # selected_rsidnums=np.sort(np.random.choice(np.arange(min(rssidsnums),max(rssidsnums)), size=234,replace=False))
    # selected_rsids=['rsid'+str(x) for x in selected_rsidnums]
    # selected_rsids=['rsid'+str(x) for x in range(312-rs)]
    # TRAIN_FEATS=selected_rsids[:]
    # selected_columns=selected_rsids[:]+ ['x', 'y', 'path', 'timestamp']
    # # print(len(selected_rsids))
    ########################################## Create data ##########################################
    # data = dataA.loc[:,selected_columns]
    data = dataA.copy()
    # data.iloc[:,-4-rs:-4]=-999
    data.iloc[:,np.random.choice(np.arange(312),size=rs, replace=False)]=-999

    num_of_lines=len(dataA)
    data2=[]
    for i in range(num_of_lines):
        # if i % 1000 == 0:
        #     print(f'current:{i}')

        tmp=data.iloc[i,:-4].astype(int).reset_index(drop=False)
        tmp.columns=['BSSID','Signal_Strength']
        tmp=tmp.sort_values(['Signal_Strength', 'BSSID'],ascending=False)
        target = data.iloc[i,-4:]

        line = pd.concat([pd.Series(tmp.BSSID.astype(str)), tmp.Signal_Strength.astype(int), target])

        line.index = [str(i) for i in range(2*len(tmp)+4)]

        data2.append(line.values)
    data2 = pd.DataFrame(np.stack(data2))

    data2.columns = [f'BSSID{str(i)}' for i in range(len(tmp))] + [f'Signal_Strength_{str(i)}' for i in range(len(tmp))] + ['x','y', 'timestamp', 'path']
    # data.to_csv(SAVEDIR+file_name, index=False)

    data=data2.copy()

    BSSID_FEATS=[x for x in data.columns if x.startswith('BSSID')]
    RSSI_FEATS=[x for x in data.columns if x.startswith('Signal_Strength')]

    # len(BSSID_FEATS),len(RSSI_FEATS)


    wifi_bssids = []
    for i in range(len(BSSID_FEATS)):
        wifi_bssids.extend(data.iloc[:,i].values.tolist())
    wifi_bssids = list(set(wifi_bssids))

    wifi_bssids = np.unique(wifi_bssids)
    wifi_bssids_size = len(wifi_bssids)
    # print(wifi_bssids_size)

    wifi_bssids_dict={}
    counter = 0               #<-------------  1 not 0
    for wf in wifi_bssids:
        wifi_bssids_dict[wf]=counter
        counter+=1


    for i in BSSID_FEATS:
        data.loc[:,i] = data.loc[:,i] .apply(lambda x: wifi_bssids_dict[x])

    data.loc[:,BSSID_FEATS[:NUM_FEATS]]=data.loc[:,BSSID_FEATS[:NUM_FEATS]].astype('float32')

    Ms=np.mean(data.loc[:,RSSI_FEATS[:NUM_FEATS]].values.astype('float32'),axis=0)
    Ss=np.std(data.loc[:,RSSI_FEATS[:NUM_FEATS]].values.astype('float32'),axis=0)

    for i in range(NUM_FEATS):
        data.loc[:,RSSI_FEATS[i]] = ((data.loc[:,RSSI_FEATS[i]] - Ms[i])/(Ss[i]+1)).astype('float32')

    unpaths=data.path.unique()

    data.x=data.x.values.astype('float32')
    data.y=data.y.values.astype('float32')
    ##########################################


    score_df = pd.DataFrame()
    oof = list()
    predictions = list()

    oof_x, oof_y = np.zeros(data.shape[0]), np.zeros(data.shape[0])
    preds_x, preds_y = 0, 0

    scores_per_fold=[]

    all_preds=[]
    all_targets=[]

    np.random.seed(42)
    sh=np.random.permutation(unpaths)


    k=5
    val_size=int(len(sh)/k)
    for f in range(k):
        # print('fold:', f)

        if f<(k-1):
            val_paths=sh[val_size*f:val_size*(f+1)]
        else:
            val_paths=sh[val_size*f:]

        train_paths=[x for x in unpaths if x not in val_paths]
        
        val_paths=np.array(val_paths)
        train_paths=np.array(train_paths)

        # X_train = data.loc[data.path.isin(train_paths), BSSID_FEATS + RSSI_FEATS ].reset_index(drop=True)

        # y_train =  data.loc[data.path.isin(train_paths), ['x', 'y'] ].reset_index(drop=True).values

        X_val = data.loc[data.path.isin(val_paths), BSSID_FEATS + RSSI_FEATS ].reset_index(drop=True)
        y_val = data.loc[data.path.isin(val_paths), ['x', 'y'] ].reset_index(drop=True).values


        model = keras_models[f]
        
        val_predsXY = model.predict(np.concatenate((X_val.loc[:,BSSID_FEATS[:NUM_FEATS]].values, X_val.loc[:,RSSI_FEATS[:NUM_FEATS]].values),1)) 

        
        # print(euclidean_distance(val_predsXY[:,0], val_predsXY[:,1], y_val[:,0], y_val[:,1]))

        all_preds.append(val_predsXY)
        all_targets.append(y_val)
            

    all_predsV=np.vstack(all_preds)
    all_targetsV=np.vstack(all_targets)    
    print(rs,'mean validation error, 5-fold', euclidean_distance(all_targetsV[:,0], all_targetsV[:,1], all_predsV[:,0], all_predsV[:,1]))
    scores.append(euclidean_distance(all_targetsV[:,0], all_targetsV[:,1], all_predsV[:,0], all_predsV[:,1]))
    print(np.mean(scores))
    print('---------------------')
# Out:
# 0 mean validation error, 5-fold 2.0863175
# 2.0863175
# ---------------------
# 1 mean validation error, 5-fold 2.0862408
# 2.0862792
# ---------------------
# 2 mean validation error, 5-fold 2.0863001
# 2.0862863
# ---------------------
# 3 mean validation error, 5-fold 2.1003313
# 2.0897975
# ---------------------
# 4 mean validation error, 5-fold 2.0992732
# 2.0916927
# ---------------------
# 5 mean validation error, 5-fold 2.1102674
# 2.0947886
# ---------------------
# 6 mean validation error, 5-fold 2.1094189
# 2.0968785
# ---------------------
# 7 mean validation error, 5-fold 2.110074
# 2.098528
# ---------------------
# 8 mean validation error, 5-fold 2.1118834
# 2.1000118
# ---------------------
# 9 mean validation error, 5-fold 2.1122077
# 2.1012313
# ---------------------
# 10 mean validation error, 5-fold 2.1120398
# 2.1022139
# ---------------------
# 11 mean validation error, 5-fold 2.1130483
# 2.1031168
# ---------------------
# 12 mean validation error, 5-fold 2.1127179
# 2.1038554
# ---------------------
# 13 mean validation error, 5-fold 2.1179547
# 2.1048625
# ---------------------
# 14 mean validation error, 5-fold 2.1183245
# 2.1057599
# ---------------------
# 15 mean validation error, 5-fold 2.1225736
# 2.1068108
# ---------------------
# 16 mean validation error, 5-fold 2.1240401
# 2.1078243
# ---------------------
# 17 mean validation error, 5-fold 2.1316285
# 2.1091468
# ---------------------
# 18 mean validation error, 5-fold 2.14266
# 2.1109104
# ---------------------
# 19 mean validation error, 5-fold 2.1435366
# 2.1125417
# ---------------------
# 20 mean validation error, 5-fold 2.1464505
# 2.1141565
# ---------------------
# 21 mean validation error, 5-fold 2.146684
# 2.115635
# ---------------------
# 22 mean validation error, 5-fold 2.1683083
# 2.1179252
# ---------------------
# 23 mean validation error, 5-fold 2.1912642
# 2.120981
# ---------------------
# 24 mean validation error, 5-fold 2.1890972
# 2.1237059
# ---------------------
# 25 mean validation error, 5-fold 2.1894627
# 2.1262348
# ---------------------
# 26 mean validation error, 5-fold 2.1887236
# 2.1285493
# ---------------------
# 27 mean validation error, 5-fold 2.202179
# 2.1311789
# ---------------------
# 28 mean validation error, 5-fold 2.2034671
# 2.1336715
# ---------------------
# 29 mean validation error, 5-fold 2.2021396
# 2.1359537
# ---------------------
# 30 mean validation error, 5-fold 2.2058923
# 2.1382098
# ---------------------
# 31 mean validation error, 5-fold 2.2333884
# 2.1411843
# ---------------------
# 32 mean validation error, 5-fold 2.2378876
# 2.1441147
# ---------------------
# 33 mean validation error, 5-fold 2.2365472
# 2.1468334
# ---------------------
# 34 mean validation error, 5-fold 2.2371547
# 2.1494138
# ---------------------
# 35 mean validation error, 5-fold 2.2369616
# 2.1518457
# ---------------------
# 36 mean validation error, 5-fold 2.2371798
# 2.1541522
# ---------------------
# 37 mean validation error, 5-fold 2.2362213
# 2.1563118
# ---------------------
# 38 mean validation error, 5-fold 2.235905
# 2.1583529
# ---------------------
# 39 mean validation error, 5-fold 2.2472448
# 2.1605747
# ---------------------
# 40 mean validation error, 5-fold 2.2467458
# 2.1626763
# ---------------------
# 41 mean validation error, 5-fold 2.2440724
# 2.1646144
# ---------------------
# 42 mean validation error, 5-fold 2.244138
# 2.1664639
# ---------------------
# 43 mean validation error, 5-fold 2.2444546
# 2.1682363
# ---------------------
# 44 mean validation error, 5-fold 2.2742035
# 2.170591
# ---------------------
# 45 mean validation error, 5-fold 2.2723665
# 2.1728036
# ---------------------
# 46 mean validation error, 5-fold 2.2735586
# 2.1749473
# ---------------------
# 47 mean validation error, 5-fold 2.2736042
# 2.177003
# ---------------------
# 48 mean validation error, 5-fold 2.2811024
# 2.1791275
# ---------------------
# 49 mean validation error, 5-fold 2.2814224
# 2.1811733
# ---------------------
# 50 mean validation error, 5-fold 2.281482
# 2.1831403
# ---------------------
# 51 mean validation error, 5-fold 2.2810087
# 2.185022
# ---------------------
# 52 mean validation error, 5-fold 2.281054
# 2.186834
# ---------------------
# 53 mean validation error, 5-fold 2.2832716
# 2.1886199
# ---------------------
# 54 mean validation error, 5-fold 2.279596
# 2.190274
# ---------------------
# 55 mean validation error, 5-fold 2.306647
# 2.1923523
# ---------------------
# 56 mean validation error, 5-fold 2.308321
# 2.1943867
# ---------------------
# 57 mean validation error, 5-fold 2.3603318
# 2.197248
# ---------------------
# 58 mean validation error, 5-fold 2.3635375
# 2.2000663
# ---------------------
# 59 mean validation error, 5-fold 2.3858347
# 2.2031624
# ---------------------
# 60 mean validation error, 5-fold 2.3858392
# 2.206157
# ---------------------
# 61 mean validation error, 5-fold 2.3885827
# 2.2090993
# ---------------------
# 62 mean validation error, 5-fold 2.396637
# 2.2120762
# ---------------------
# 63 mean validation error, 5-fold 2.4015334
# 2.2150366
# ---------------------
# 64 mean validation error, 5-fold 2.5241802
# 2.2197928
# ---------------------
# 65 mean validation error, 5-fold 2.5284448
# 2.2244692
# ---------------------
# 66 mean validation error, 5-fold 2.5323327
# 2.2290642
# ---------------------
# 67 mean validation error, 5-fold 2.5863676
# 2.2343187
# ---------------------
# 68 mean validation error, 5-fold 2.60533
# 2.2396958
# ---------------------
# 69 mean validation error, 5-fold 2.6236002
# 2.24518
# ---------------------
# 70 mean validation error, 5-fold 2.6222863
# 2.2504914
# ---------------------
# 71 mean validation error, 5-fold 2.6463535
# 2.2559896
# ---------------------
# 72 mean validation error, 5-fold 2.6658733
# 2.2616043
# ---------------------
# 73 mean validation error, 5-fold 2.6869109
# 2.2673516
# ---------------------
# 74 mean validation error, 5-fold 2.686781
# 2.2729442
# ---------------------
# 75 mean validation error, 5-fold 2.7677195
# 2.2794542
# ---------------------
# 76 mean validation error, 5-fold 2.7764032
# 2.285908
# ---------------------
# 77 mean validation error, 5-fold 2.7766216
# 2.2921994
# ---------------------
# 78 mean validation error, 5-fold 2.7782524
# 2.298352
# ---------------------
# 79 mean validation error, 5-fold 2.783579
# 2.3044171
# ---------------------
# 80 mean validation error, 5-fold 2.795033
# 2.310474
# ---------------------
# 81 mean validation error, 5-fold 2.8038282
# 2.3164907
# ---------------------
# 82 mean validation error, 5-fold 2.8067052
# 2.3223968
# ---------------------
# 83 mean validation error, 5-fold 2.8063776
# 2.3281584
# ---------------------
# 84 mean validation error, 5-fold 2.8114076
# 2.3338437
# ---------------------
# 85 mean validation error, 5-fold 2.8233914
# 2.3395362
# ---------------------
# 86 mean validation error, 5-fold 2.977956
# 2.3468742
# ---------------------
# 87 mean validation error, 5-fold 2.9777184
# 2.354043
# ---------------------
# 88 mean validation error, 5-fold 2.9783034
# 2.3610573
# ---------------------
# 89 mean validation error, 5-fold 3.0214324
# 2.3683949
# ---------------------
# 90 mean validation error, 5-fold 3.0225215
# 2.375583
# ---------------------
# 91 mean validation error, 5-fold 3.0293624
# 2.3826892
# ---------------------
# 92 mean validation error, 5-fold 3.0292306
# 2.3896413
# ---------------------
# 93 mean validation error, 5-fold 3.0303373
# 2.3964572
# ---------------------
# 94 mean validation error, 5-fold 3.0393994
# 2.4032252
# ---------------------
# 95 mean validation error, 5-fold 3.06397
# 2.4101079
# ---------------------
# 96 mean validation error, 5-fold 3.0836942
# 2.417052
# ---------------------
# 97 mean validation error, 5-fold 3.0881774
# 2.4239001
# ---------------------
# 98 mean validation error, 5-fold 3.0905473
# 2.430634
# ---------------------
# 99 mean validation error, 5-fold 3.096873
# 2.4372964
# ---------------------
# 100 mean validation error, 5-fold 3.098197
# 2.44384
# ---------------------
# 101 mean validation error, 5-fold 3.1313825
# 2.4505806
# ---------------------
# 102 mean validation error, 5-fold 3.13687
# 2.4572434
# ---------------------
# 103 mean validation error, 5-fold 3.1415746
# 2.4638238
# ---------------------
# 104 mean validation error, 5-fold 3.146357
# 2.470324
# ---------------------
# 105 mean validation error, 5-fold 3.1533463
# 2.4767678
# ---------------------
# 106 mean validation error, 5-fold 3.273051
# 2.4842095
# ---------------------
# 107 mean validation error, 5-fold 3.2762194
# 2.491543
# ---------------------
# 108 mean validation error, 5-fold 3.2775142
# 2.4987538
# ---------------------
# 109 mean validation error, 5-fold 3.2990422
# 2.5060291
# ---------------------
# 110 mean validation error, 5-fold 3.3291416
# 2.5134444
# ---------------------
# 111 mean validation error, 5-fold 3.3287919
# 2.5207245
# ---------------------
# 112 mean validation error, 5-fold 3.3740299
# 2.5282757
# ---------------------
# 113 mean validation error, 5-fold 3.3951418
# 2.5358799
# ---------------------
# 114 mean validation error, 5-fold 3.4022563
# 2.5434134
# ---------------------
# 115 mean validation error, 5-fold 3.4032245
# 2.5508256
# ---------------------
# 116 mean validation error, 5-fold 3.6239934
# 2.559998
# ---------------------
# 117 mean validation error, 5-fold 3.6243205
# 2.569018
# ---------------------
# 118 mean validation error, 5-fold 3.6164281
# 2.5778196
# ---------------------
# 119 mean validation error, 5-fold 3.6640348
# 2.5868714
# ---------------------
# 120 mean validation error, 5-fold 3.708051
# 2.5961373
# ---------------------
# 121 mean validation error, 5-fold 3.692255
# 2.6051219
# ---------------------
# 122 mean validation error, 5-fold 3.7433736
# 2.6143758
# ---------------------
# 123 mean validation error, 5-fold 3.7445579
# 2.6234903
# ---------------------
# 124 mean validation error, 5-fold 3.8621893
# 2.6334
# ---------------------
# 125 mean validation error, 5-fold 3.8623905
# 2.643154
# ---------------------
# 126 mean validation error, 5-fold 3.8657267
# 2.6527803
# ---------------------
# 127 mean validation error, 5-fold 3.883015
# 2.6623917
# ---------------------
# 128 mean validation error, 5-fold 4.005989
# 2.672807
# ---------------------
# 129 mean validation error, 5-fold 4.026995
# 2.6832237
# ---------------------
# 130 mean validation error, 5-fold 4.019269
# 2.6934228
# ---------------------
# 131 mean validation error, 5-fold 4.0082617
# 2.7033834
# ---------------------
# 132 mean validation error, 5-fold 4.00914
# 2.7132013
# ---------------------
# 133 mean validation error, 5-fold 4.0017014
# 2.722817
# ---------------------
# 134 mean validation error, 5-fold 4.0027614
# 2.732298
# ---------------------
# 135 mean validation error, 5-fold 4.0079103
# 2.7416778
# ---------------------
# 136 mean validation error, 5-fold 4.0488276
# 2.751219
# ---------------------
# 137 mean validation error, 5-fold 4.042978
# 2.7605793
# ---------------------
# 138 mean validation error, 5-fold 4.1388726
# 2.7704952
# ---------------------
# 139 mean validation error, 5-fold 4.1458435
# 2.7803192
# ---------------------
# 140 mean validation error, 5-fold 4.1559534
# 2.7900755
# ---------------------
# 141 mean validation error, 5-fold 4.1654954
# 2.7997615
# ---------------------
# 142 mean validation error, 5-fold 4.1652102
# 2.80931
# ---------------------
# 143 mean validation error, 5-fold 4.16417
# 2.818719
# ---------------------
# 144 mean validation error, 5-fold 4.1683087
# 2.8280263
# ---------------------
# 145 mean validation error, 5-fold 4.200631
# 2.8374279
# ---------------------
# 146 mean validation error, 5-fold 4.3852
# 2.847957
# ---------------------
# 147 mean validation error, 5-fold 4.388075
# 2.858363
# ---------------------
# 148 mean validation error, 5-fold 4.528673
# 2.869573
# ---------------------
# 149 mean validation error, 5-fold 4.650683
# 2.8814473
# ---------------------
# 150 mean validation error, 5-fold 4.6638846
# 2.8932514
# ---------------------
# 151 mean validation error, 5-fold 4.684019
# 2.9050326
# ---------------------
# 152 mean validation error, 5-fold 4.6879945
# 2.916686
# ---------------------
# 153 mean validation error, 5-fold 4.802838
# 2.9289336
# ---------------------
# 154 mean validation error, 5-fold 4.8393264
# 2.9412587
# ---------------------
# 155 mean validation error, 5-fold 4.84411
# 2.9534566
# ---------------------
# 156 mean validation error, 5-fold 4.953751
# 2.9661975
# ---------------------
# 157 mean validation error, 5-fold 4.9547606
# 2.9787834
# ---------------------
# 158 mean validation error, 5-fold 4.9810615
# 2.9913762
# ---------------------
# 159 mean validation error, 5-fold 5.490704
# 3.0069966
# ---------------------
# 160 mean validation error, 5-fold 5.5069356
# 3.0225244
# ---------------------
# 161 mean validation error, 5-fold 5.5052457
# 3.0378497
# ---------------------
# 162 mean validation error, 5-fold 5.611983
# 3.0536418
# ---------------------
# 163 mean validation error, 5-fold 5.722521
# 3.0699155
# ---------------------
# 164 mean validation error, 5-fold 5.726473
# 3.086016
# ---------------------
# 165 mean validation error, 5-fold 5.734984
# 3.1019735
# ---------------------
# 166 mean validation error, 5-fold 5.806969
# 3.1181715
# ---------------------
# 167 mean validation error, 5-fold 5.833738
# 3.1343355
# ---------------------
# 168 mean validation error, 5-fold 5.8319373
# 3.1502974
# ---------------------
# 169 mean validation error, 5-fold 5.819876
# 3.1660008
# ---------------------
# 170 mean validation error, 5-fold 5.819325
# 3.1815176
# ---------------------
# 171 mean validation error, 5-fold 5.83339
# 3.1969357
# ---------------------
# 172 mean validation error, 5-fold 5.835766
# 3.2121885
# ---------------------
# 173 mean validation error, 5-fold 5.830384
# 3.227236
# ---------------------
# 174 mean validation error, 5-fold 5.909094
# 3.2425606
# ---------------------
# 175 mean validation error, 5-fold 5.9129443
# 3.2577333
# ---------------------
# 176 mean validation error, 5-fold 5.920018
# 3.2727747
# ---------------------
# 177 mean validation error, 5-fold 5.9146543
# 3.2876165
# ---------------------
# 178 mean validation error, 5-fold 5.9166274
# 3.3023038
# ---------------------
# 179 mean validation error, 5-fold 5.9389415
# 3.3169515
# ---------------------
# 180 mean validation error, 5-fold 6.0077815
# 3.331818
# ---------------------
# 181 mean validation error, 5-fold 6.0085945
# 3.3465257
# ---------------------
# 182 mean validation error, 5-fold 6.007578
# 3.361067
# ---------------------
# 183 mean validation error, 5-fold 6.1817374
# 3.376397
# ---------------------
# 184 mean validation error, 5-fold 6.2799344
# 3.3920918
# ---------------------
# 185 mean validation error, 5-fold 6.289098
# 3.407667
# ---------------------
# 186 mean validation error, 5-fold 6.389319
# 3.4236114
# ---------------------
# 187 mean validation error, 5-fold 6.7947764
# 3.4415433
# ---------------------
# 188 mean validation error, 5-fold 6.8466687
# 3.45956
# ---------------------
# 189 mean validation error, 5-fold 6.847499
# 3.4773912
# ---------------------
# 190 mean validation error, 5-fold 6.865178
# 3.4951282
# ---------------------
# 191 mean validation error, 5-fold 6.8729477
# 3.512721
# ---------------------
# 192 mean validation error, 5-fold 6.868737
# 3.5301096
# ---------------------
# 193 mean validation error, 5-fold 6.870605
# 3.5473287
# ---------------------
# 194 mean validation error, 5-fold 7.201762
# 3.5660694
# ---------------------
# 195 mean validation error, 5-fold 7.190869
# 3.5845633
# ---------------------
# 196 mean validation error, 5-fold 7.2447753
# 3.603143
# ---------------------
# 197 mean validation error, 5-fold 7.3732467
# 3.622184
# ---------------------
# 198 mean validation error, 5-fold 8.121535
# 3.6447937
# ---------------------
# 199 mean validation error, 5-fold 8.357025
# 3.6683547
# ---------------------
# 200 mean validation error, 5-fold 8.363016
# 3.6917114
# ---------------------
# 201 mean validation error, 5-fold 8.361779
# 3.7148304
# ---------------------
# 202 mean validation error, 5-fold 8.386069
# 3.7378414
# ---------------------
# 203 mean validation error, 5-fold 8.410407
# 3.760746
# ---------------------
# 204 mean validation error, 5-fold 8.707644
# 3.7848773
# ---------------------
# 205 mean validation error, 5-fold 8.858204
# 3.8095052
# ---------------------
# 206 mean validation error, 5-fold 8.860375
# 3.8339055
# ---------------------
# 207 mean validation error, 5-fold 8.907576
# 3.8582983
# ---------------------
# 208 mean validation error, 5-fold 9.005603
# 3.8829267
# ---------------------
# 209 mean validation error, 5-fold 8.898873
# 3.9068122
# ---------------------
# 210 mean validation error, 5-fold 9.1106825
# 3.931475
# ---------------------
# 211 mean validation error, 5-fold 9.222411
# 3.956432
# ---------------------
# 212 mean validation error, 5-fold 9.224412
# 3.9811645
# ---------------------
# 213 mean validation error, 5-fold 9.392549
# 4.0064516
# ---------------------
# 214 mean validation error, 5-fold 9.419163
# 4.031627
# ---------------------
# 215 mean validation error, 5-fold 9.5869055
# 4.057346
# ---------------------
# 216 mean validation error, 5-fold 9.614132
# 4.082953
# ---------------------
# 217 mean validation error, 5-fold 9.557149
# 4.1080637
# ---------------------
# 218 mean validation error, 5-fold 9.688606
# 4.133546
# ---------------------
# 219 mean validation error, 5-fold 9.692477
# 4.158814
# ---------------------
# 220 mean validation error, 5-fold 9.726365
# 4.184006
# ---------------------
# 221 mean validation error, 5-fold 9.736806
# 4.209019
# ---------------------
# 222 mean validation error, 5-fold 9.778
# 4.233992
# ---------------------
# 223 mean validation error, 5-fold 9.775987
# 4.258733
# ---------------------
# 224 mean validation error, 5-fold 9.844791
# 4.28356
# ---------------------
# 225 mean validation error, 5-fold 9.948556
# 4.308626
# ---------------------
# 226 mean validation error, 5-fold 10.202886
# 4.334592
# ---------------------
# 227 mean validation error, 5-fold 10.210752
# 4.3603644
# ---------------------
# 228 mean validation error, 5-fold 10.249365
# 4.3860807
# ---------------------
# 229 mean validation error, 5-fold 10.677429
# 4.4134345
# ---------------------
# 230 mean validation error, 5-fold 10.724053
# 4.440753
# ---------------------
# 231 mean validation error, 5-fold 10.883937
# 4.468526
# ---------------------
# 232 mean validation error, 5-fold 10.882589
# 4.4960537
# ---------------------
# 233 mean validation error, 5-fold 11.130654
# 4.524407
# ---------------------
# 234 mean validation error, 5-fold 11.143785
# 4.552574
# ---------------------
# 235 mean validation error, 5-fold 11.280876
# 4.5810843
# ---------------------
# 236 mean validation error, 5-fold 11.289496
# 4.60939
# ---------------------
# 237 mean validation error, 5-fold 11.470862
# 4.6382194
# ---------------------
# 238 mean validation error, 5-fold 11.49054
# 4.6668906
# ---------------------
# 239 mean validation error, 5-fold 11.712575
# 4.6962476
# ---------------------
# 240 mean validation error, 5-fold 12.02078
# 4.7266393
# ---------------------
# 241 mean validation error, 5-fold 12.148854
# 4.75731
# ---------------------
# 242 mean validation error, 5-fold 12.463965
# 4.7890244
# ---------------------
# 243 mean validation error, 5-fold 12.60523
# 4.821058
# ---------------------
# 244 mean validation error, 5-fold 12.611248
# 4.8528547
# ---------------------
# 245 mean validation error, 5-fold 12.599225
# 4.884344
# ---------------------
# 246 mean validation error, 5-fold 12.731665
# 4.916115
# ---------------------
# 247 mean validation error, 5-fold 13.346492
# 4.950108
# ---------------------
# 248 mean validation error, 5-fold 13.444985
# 4.984224
# ---------------------
# 249 mean validation error, 5-fold 13.456954
# 5.018115
# ---------------------
# 250 mean validation error, 5-fold 13.479269
# 5.051825
# ---------------------
# 251 mean validation error, 5-fold 13.49393
# 5.0853252
# ---------------------
# 252 mean validation error, 5-fold 13.50792
# 5.118616
# ---------------------
# 253 mean validation error, 5-fold 13.633771
# 5.1521406
# ---------------------
# 254 mean validation error, 5-fold 13.7323885
# 5.185788
# ---------------------
# 255 mean validation error, 5-fold 13.767723
# 5.2193117
# ---------------------
# 256 mean validation error, 5-fold 13.891135
# 5.253054
# ---------------------
# 257 mean validation error, 5-fold 13.884422
# 5.2865086
# ---------------------
# 258 mean validation error, 5-fold 13.952877
# 5.319969
# ---------------------
# 259 mean validation error, 5-fold 13.923369
# 5.3530593
# ---------------------
# 260 mean validation error, 5-fold 14.285558
# 5.387284
# ---------------------
# 261 mean validation error, 5-fold 14.306386
# 5.421326
# ---------------------
# 262 mean validation error, 5-fold 14.400967
# 5.455469
# ---------------------
# 263 mean validation error, 5-fold 14.637582
# 5.49025
# ---------------------
# 264 mean validation error, 5-fold 14.832662
# 5.5255046
# ---------------------
# 265 mean validation error, 5-fold 14.806305
# 5.5603943
# ---------------------
# 266 mean validation error, 5-fold 14.743451
# 5.594788
# ---------------------
# 267 mean validation error, 5-fold 14.973396
# 5.629783
# ---------------------
# 268 mean validation error, 5-fold 15.201211
# 5.6653647
# ---------------------
# 269 mean validation error, 5-fold 15.368945
# 5.701304
# ---------------------
# 270 mean validation error, 5-fold 15.363093
# 5.736956
# ---------------------
# 271 mean validation error, 5-fold 15.30195
# 5.7721214
# ---------------------
# 272 mean validation error, 5-fold 15.282265
# 5.8069572
# ---------------------
# 273 mean validation error, 5-fold 15.480767
# 5.842263
# ---------------------
# 274 mean validation error, 5-fold 15.486564
# 5.8773336
# ---------------------
# 275 mean validation error, 5-fold 15.442737
# 5.9119906
# ---------------------
# 276 mean validation error, 5-fold 15.806393
# 5.9477105
# ---------------------
# 277 mean validation error, 5-fold 15.746141
# 5.982957
# ---------------------
# 278 mean validation error, 5-fold 15.77515
# 6.018054
# ---------------------
# 279 mean validation error, 5-fold 15.752411
# 6.0528197
# ---------------------
# 280 mean validation error, 5-fold 15.872936
# 6.087766
# ---------------------
# 281 mean validation error, 5-fold 15.809886
# 6.122242
# ---------------------
# 282 mean validation error, 5-fold 15.826252
# 6.1565323
# ---------------------
# 283 mean validation error, 5-fold 15.82774
# 6.190585
# ---------------------
# 284 mean validation error, 5-fold 15.807725
# 6.22433
# ---------------------
# 285 mean validation error, 5-fold 15.74643
# 6.2576237
# ---------------------
# 286 mean validation error, 5-fold 15.702324
# 6.2905326
# ---------------------
# 287 mean validation error, 5-fold 15.692636
# 6.323179
# ---------------------
# 288 mean validation error, 5-fold 15.827874
# 6.3560667
# ---------------------
# 289 mean validation error, 5-fold 15.850753
# 6.388807
# ---------------------
# 290 mean validation error, 5-fold 16.067978
# 6.4220686
# ---------------------
# 291 mean validation error, 5-fold 16.039722
# 6.455006
# ---------------------
# 292 mean validation error, 5-fold 16.011433
# 6.4876223
# ---------------------
# 293 mean validation error, 5-fold 16.578842
# 6.521946
# ---------------------
# 294 mean validation error, 5-fold 16.971884
# 6.5573697
# ---------------------
# 295 mean validation error, 5-fold 17.005316
# 6.592666
# ---------------------
# 296 mean validation error, 5-fold 17.00002
# 6.627708
# ---------------------
# 297 mean validation error, 5-fold 17.10929
# 6.6628804
# ---------------------
# 298 mean validation error, 5-fold 17.169992
# 6.698022
# ---------------------
# 299 mean validation error, 5-fold 17.17799
# 6.732955
# ---------------------
# 300 mean validation error, 5-fold 17.170918
# 6.7676325
# ---------------------
# 301 mean validation error, 5-fold 17.200363
# 6.8021774
# ---------------------
# 302 mean validation error, 5-fold 17.214819
# 6.8365426
# ---------------------
# 303 mean validation error, 5-fold 17.193354
# 6.8706117
# ---------------------
# 304 mean validation error, 5-fold 17.170742
# 6.9043827
# ---------------------
# 305 mean validation error, 5-fold 17.485865
# 6.9389625
# ---------------------
# 306 mean validation error, 5-fold 17.844517
# 6.9744854
# ---------------------
# 307 mean validation error, 5-fold 17.936666
# 7.010077
# ---------------------
# 308 mean validation error, 5-fold 18.136301
# 7.046084
# ---------------------
# 309 mean validation error, 5-fold 18.172022
# 7.0819745
# ---------------------
# 310 mean validation error, 5-fold 18.189194
# 7.117689
# ---------------------
# 311 mean validation error, 5-fold 18.18519
# 7.1531615
# ---------------------

# %%
plt.figure(figsize=(10,5))
plt.plot(scores)
plt.title('Keras - Error per num of not found BSSIDS (random) ')
plt.xlabel('Num BSSIDS')
plt.ylabel('Error in meters')
plt.show()

# %%
len(scores)
# Out:
# 312

# %%
pd.DataFrame({'num_bssids':np.arange(0,312),
              'scores':np.array(scores)}).to_csv('/gdrive/My Drive/Colab Notebooks/Keras_'+version+'_random.csv',index=False)

# %%
# unp=data.path.unique()
import matplotlib.pyplot as plt
# ind=np.array(data.loc[data.path==unp[1],:].index)
X_val2 = data.loc[data.path.isin(val_paths),:].reset_index(drop=True)
ind=np.array(X_val2.loc[X_val2.path==val_paths[12],:].index)
plt.figure(figsize=(10,5))
plt.title('Sigle Path, True and Predicted')

# plt.plot(data.x.iloc[ind].values,data.y.iloc[ind].values,'-.')
plt.plot(all_targetsV[ind,0], all_targetsV[ind,1],'-o',label='target path')
plt.plot(all_predsV[ind,0], all_predsV[ind,1],'-o',label='predicted path')
plt.legend()
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %%
# CROSS VALIDATION

name='keras'+version

scores=[]
for rs in range(50):
    np.random.seed(2022+rs)
    selected_rsidnums=np.sort(np.random.choice(np.arange(min(rssidsnums),max(rssidsnums)), size=156,replace=False))
    selected_rsids=['rsid'+str(x) for x in selected_rsidnums]
    # TRAIN_FEATS=selected_rsids[:]
    selected_columns=selected_rsids[:]+ ['x', 'y', 'path', 'timestamp']
    # print(len(selected_rsids))
    ########################################## Create data ##########################################
    data = dataA.loc[:,selected_columns]
    num_of_lines=len(dataA)
    data2=[]
    for i in range(num_of_lines):
        # if i % 1000 == 0:
        #     print(f'current:{i}')

        tmp=data.iloc[i,:-4].astype(int).reset_index(drop=False)
        tmp.columns=['BSSID','Signal_Strength']
        tmp=tmp.sort_values(['Signal_Strength', 'BSSID'],ascending=False)
        target = data.iloc[i,-4:]

        line = pd.concat([pd.Series(tmp.BSSID.astype(str)), tmp.Signal_Strength.astype(int), target])

        line.index = [str(i) for i in range(2*len(tmp)+4)]

        data2.append(line.values)
    data2 = pd.DataFrame(np.stack(data2))

    data2.columns = [f'BSSID{str(i)}' for i in range(len(tmp))] + [f'Signal_Strength_{str(i)}' for i in range(len(tmp))] + ['x','y', 'path', 'timestamp']
    # data.to_csv(SAVEDIR+file_name, index=False)

    data=data2.copy()

    BSSID_FEATS=[x for x in data.columns if x.startswith('BSSID')]
    RSSI_FEATS=[x for x in data.columns if x.startswith('Signal_Strength')]

    # len(BSSID_FEATS),len(RSSI_FEATS)


    wifi_bssids = []
    for i in range(len(BSSID_FEATS)):
        wifi_bssids.extend(data.iloc[:,i].values.tolist())
    wifi_bssids = list(set(wifi_bssids))

    wifi_bssids = np.unique(wifi_bssids)
    wifi_bssids_size = len(wifi_bssids)
    # print(wifi_bssids_size)

    wifi_bssids_dict={}
    counter = 0               #<-------------  1 not 0
    for wf in wifi_bssids:
        wifi_bssids_dict[wf]=counter
        counter+=1


    for i in BSSID_FEATS:
        data.loc[:,i] = data.loc[:,i] .apply(lambda x: wifi_bssids_dict[x])

    data.loc[:,BSSID_FEATS[:NUM_FEATS]]=data.loc[:,BSSID_FEATS[:NUM_FEATS]].astype('float32')

    Ms=np.mean(data.loc[:,RSSI_FEATS[:NUM_FEATS]].values.astype('float32'),axis=0)
    Ss=np.std(data.loc[:,RSSI_FEATS[:NUM_FEATS]].values.astype('float32'),axis=0)

    for i in range(NUM_FEATS):
        data.loc[:,RSSI_FEATS[i]] = ((data.loc[:,RSSI_FEATS[i]] - Ms[i])/(Ss[i]+1)).astype('float32')

    unpaths=data.path.unique()

    data.x=data.x.values.astype('float32')
    data.y=data.y.values.astype('float32')
    ##########################################


    score_df = pd.DataFrame()
    oof = list()
    predictions = list()

    oof_x, oof_y = np.zeros(data.shape[0]), np.zeros(data.shape[0])
    preds_x, preds_y = 0, 0

    scores_per_fold=[]

    all_preds=[]
    all_targets=[]

    np.random.seed(42)
    sh=np.random.permutation(unpaths)


    k=5
    val_size=int(len(sh)/k)
    for f in range(k):
        # print('fold:', f)

        if f<(k-1):
            val_paths=sh[val_size*f:val_size*(f+1)]
        else:
            val_paths=sh[val_size*f:]

        train_paths=[x for x in unpaths if x not in val_paths]
        
        val_paths=np.array(val_paths)
        train_paths=np.array(train_paths)

        X_train = data.loc[data.path.isin(train_paths), BSSID_FEATS + RSSI_FEATS ].reset_index(drop=True)

        y_train =  data.loc[data.path.isin(train_paths), ['x', 'y'] ].reset_index(drop=True).values

        X_val = data.loc[data.path.isin(val_paths), BSSID_FEATS + RSSI_FEATS ].reset_index(drop=True)
        y_val = data.loc[data.path.isin(val_paths), ['x', 'y'] ].reset_index(drop=True).values


        model = create_model(bssid_size1=NUM_FEATS, rssi_size=NUM_FEATS  )
        epochs=140
        snapshots = 7
        lr_0 = 0.01
        lr_anneal1 = LearningRateScheduler(schedule=_cosine_anneal_schedule, verbose=False)

        h = model.fit(np.concatenate((X_train.loc[:,BSSID_FEATS[:NUM_FEATS]].values, X_train.loc[:,RSSI_FEATS[:NUM_FEATS]].values),1),
                    y_train, 
                    batch_size=128*8, epochs=epochs, verbose=0,
                    validation_data=(np.concatenate((X_val.loc[:,BSSID_FEATS[:NUM_FEATS]].values, X_val.loc[:,RSSI_FEATS[:NUM_FEATS]].values),1),
                    y_val),
                    callbacks=[ lr_anneal1])
            
        epochs=140
        snapshots = 7
        lr_0 = 0.001
        lr_anneal1 = LearningRateScheduler(schedule=_cosine_anneal_schedule, verbose=False)

        h = model.fit(np.concatenate((X_train.loc[:,BSSID_FEATS[:NUM_FEATS]].values, X_train.loc[:,RSSI_FEATS[:NUM_FEATS]].values),1),
                    y_train, 
                    batch_size=128*8, epochs=epochs, verbose=0,
                    validation_data=(np.concatenate((X_val.loc[:,BSSID_FEATS[:NUM_FEATS]].values, X_val.loc[:,RSSI_FEATS[:NUM_FEATS]].values),1),
                    y_val),
                    callbacks=[ lr_anneal1])

        # model.save_weights(weights_path+name+'_fold'+str(f)+'.hdf5')
        val_predsXY = model.predict(np.concatenate((X_val.loc[:,BSSID_FEATS[:NUM_FEATS]].values, X_val.loc[:,RSSI_FEATS[:NUM_FEATS]].values),1)) 

        
        # print(euclidean_distance(val_predsXY[:,0], val_predsXY[:,1], y_val[:,0], y_val[:,1]))

        all_preds.append(val_predsXY)
        all_targets.append(y_val)
            

    all_predsV=np.vstack(all_preds)
    all_targetsV=np.vstack(all_targets)    
    print(rs,'mean validation error, 5-fold', euclidean_distance(all_targetsV[:,0], all_targetsV[:,1], all_predsV[:,0], all_predsV[:,1]))
    scores.append(euclidean_distance(all_targetsV[:,0], all_targetsV[:,1], all_predsV[:,0], all_predsV[:,1]))
    print(np.mean(scores))
    print('---------------------')
# Out:
# 0 mean validation error, 5-fold 2.2671878
# 2.2671878
# ---------------------
# 1 mean validation error, 5-fold 2.282078
# 2.274633
# ---------------------
# 2 mean validation error, 5-fold 2.2926831
# 2.2806497
# ---------------------
# 3 mean validation error, 5-fold 2.2649224
# 2.276718
# ---------------------
# 4 mean validation error, 5-fold 2.3079996
# 2.2829742
# ---------------------
# 5 mean validation error, 5-fold 2.2761319
# 2.281834
# ---------------------
# 6 mean validation error, 5-fold 2.333991
# 2.289285
# ---------------------
# 7 mean validation error, 5-fold 2.2860453
# 2.2888799
# ---------------------
# 8 mean validation error, 5-fold 2.2834997
# 2.2882822
# ---------------------
# 9 mean validation error, 5-fold 2.3148868
# 2.2909427
# ---------------------
# 10 mean validation error, 5-fold 2.2490253
# 2.287132
# ---------------------
# 11 mean validation error, 5-fold 2.228512
# 2.2822468
# ---------------------
# 12 mean validation error, 5-fold 2.2603738
# 2.2805643
# ---------------------
# 13 mean validation error, 5-fold 2.2693021
# 2.27976
# ---------------------
# 14 mean validation error, 5-fold 2.3120992
# 2.281916
# ---------------------
# 15 mean validation error, 5-fold 2.259971
# 2.2805443
# ---------------------
# 16 mean validation error, 5-fold 2.3516278
# 2.2847257
# ---------------------
# 17 mean validation error, 5-fold 2.2436502
# 2.2824435
# ---------------------
# 18 mean validation error, 5-fold 2.337443
# 2.2853384
# ---------------------
# 19 mean validation error, 5-fold 2.2198353
# 2.2820632
# ---------------------
# 20 mean validation error, 5-fold 2.2664635
# 2.2813206
# ---------------------
# 21 mean validation error, 5-fold 2.2911365
# 2.2817667
# ---------------------
# 22 mean validation error, 5-fold 2.2937334
# 2.282287
# ---------------------
# 23 mean validation error, 5-fold 2.3031025
# 2.2831542
# ---------------------
# 24 mean validation error, 5-fold 2.301748
# 2.2838979
# ---------------------
# 25 mean validation error, 5-fold 2.2905982
# 2.2841556
# ---------------------
# 26 mean validation error, 5-fold 2.2714043
# 2.2836833
# ---------------------
# 27 mean validation error, 5-fold 2.2635114
# 2.282963
# ---------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-59-e68dec626afa> in <module>()
#      67
#      68     for i in range(NUM_FEATS):
# ---> 69         data.loc[:,RSSI_FEATS[i]] = ((data.loc[:,RSSI_FEATS[i]] - Ms[i])/(Ss[i]+1)).astype('float32')
#      70
#      71     unpaths=data.path.unique()
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#     668
#     669         iloc = self if self.name == "iloc" else self.obj.iloc
# --> 670         iloc._setitem_with_indexer(indexer, value)
#     671
#     672     def _validate_key(self, key, axis: int):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _setitem_with_indexer(self, indexer, value)
#    1741                     # we have an equal len list/ndarray
#    1742                     # We only get here with len(labels) == len(ilocs) == 1
# -> 1743                     isetter(ilocs[0], value)
#    1744
#    1745                 elif lplane_indexer == 0 and len(value) == len(self.obj.index):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in isetter(loc, v)
#    1691
#    1692                 # reset the sliced object if unique
# -> 1693                 self.obj._iset_item(loc, ser)
#    1694
#    1695             # we need an iterable, with a ndim of at least 1
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in _iset_item(self, loc, value)
#    3099         #  but the behavior is the same as long as we pass broadcast=False
#    3100         value = self._sanitize_column(loc, value, broadcast=False)
# -> 3101         NDFrame._iset_item(self, loc, value)
#    3102
#    3103         # check if we are modifying a copy
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in _iset_item(self, loc, value)
#    3569
#    3570     def _iset_item(self, loc: int, value) -> None:
# -> 3571         self._mgr.iset(loc, value)
#    3572         self._clear_item_cache()
#    3573
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/managers.py in iset(self, loc, value)
#    1112                     removed_blknos.append(blkno)
#    1113                 else:
# -> 1114                     blk.delete(blk_locs)
#    1115                     self._blklocs[blk.mgr_locs.indexer] = np.arange(len(blk))
#    1116
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/blocks.py in delete(self, loc)
#     335         Delete given loc(-s) from block in-place.
#     336         """
# --> 337         self.values = np.delete(self.values, loc, 0)
#     338         self.mgr_locs = self.mgr_locs.delete(loc)
#     339
#
# <__array_function__ internals> in delete(*args, **kwargs)
#
# /usr/local/lib/python3.7/dist-packages/numpy/lib/function_base.py in delete(arr, obj, axis)
#    4407
#    4408         slobj[axis] = keep
# -> 4409         new = arr[tuple(slobj)]
#    4410
#    4411     if wrap:
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt
plt.plot(scores)
plt.title('oof score of every random BSSID SET')
plt.show()

plt.plot(np.cumsum(scores)/np.arange(1,len(scores)+1))
plt.title('Rolling mean score')
plt.show()

print(len(scores))
print(np.mean(scores))
print(np.std(scores))
# Out:
# 28
# 2.282963
# 0.030568602

# %%
plt.figure(figsize=(10,10))
plt.title('XY scatter plot of Predicted positions over target grid')
plt.plot(all_predsV[:,0],all_predsV[:,1],'.', label='Predicted position')
plt.plot(all_targetsV[:,0],all_targetsV[:,1],'o', label='target grid')
plt.legend()
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.show()
print('mean validation error, 5-fold', euclidean_distance(all_targetsV[:,0], all_targetsV[:,1], all_predsV[:,0], all_predsV[:,1]))
# Out:
# mean validation error, 5-fold 2.2635114

# %%
scoreperrow=[]
for row in range(len(all_targetsV)):
    scoreperrow.append(euclidean_distance(all_targetsV[row,0], all_targetsV[row,1], all_predsV[row,0], all_predsV[row,1]))
    
plt.figure(figsize=(10,10))
plt.title('XY scatter plot of Predicted positions with error magnitude over target grid')
plt.plot(all_targetsV[:,0],all_targetsV[:,1],'o', color="orange", label='target grid')
plt.scatter(all_predsV[:,0],all_predsV[:,1],s=0.5*np.array(scoreperrow)**2, label='Predicted position')
plt.legend()
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.show()
print('mean validation error, 5-fold', euclidean_distance(all_targetsV[:,0], all_targetsV[:,1], all_predsV[:,0], all_predsV[:,1]))
# Out:
# mean validation error, 5-fold 2.2635114

# %%
# CROSS VALIDATION

name='keras'+version

scores=[]
for rs in range(100):
    np.random.seed(2022+rs)
    selected_rsidnums=np.sort(np.random.choice(np.arange(min(rssidsnums),max(rssidsnums)), size=78,replace=False))
    selected_rsids=['rsid'+str(x) for x in selected_rsidnums]
    # TRAIN_FEATS=selected_rsids[:]
    selected_columns=selected_rsids[:]+ ['x', 'y', 'path', 'timestamp']
    # print(len(selected_rsids))
    ########################################## Create data ##########################################
    data = dataA.loc[:,selected_columns]
    num_of_lines=len(dataA)
    data2=[]
    for i in range(num_of_lines):
        # if i % 1000 == 0:
        #     print(f'current:{i}')

        tmp=data.iloc[i,:-4].astype(int).reset_index(drop=False)
        tmp.columns=['BSSID','Signal_Strength']
        tmp=tmp.sort_values(['Signal_Strength', 'BSSID'],ascending=False)
        target = data.iloc[i,-4:]

        line = pd.concat([pd.Series(tmp.BSSID.astype(str)), tmp.Signal_Strength.astype(int), target])

        line.index = [str(i) for i in range(2*len(tmp)+4)]

        data2.append(line.values)
    data2 = pd.DataFrame(np.stack(data2))

    data2.columns = [f'BSSID{str(i)}' for i in range(len(tmp))] + [f'Signal_Strength_{str(i)}' for i in range(len(tmp))] + ['x','y', 'path', 'timestamp']
    # data.to_csv(SAVEDIR+file_name, index=False)

    data=data2.copy()

    BSSID_FEATS=[x for x in data.columns if x.startswith('BSSID')]
    RSSI_FEATS=[x for x in data.columns if x.startswith('Signal_Strength')]

    # len(BSSID_FEATS),len(RSSI_FEATS)


    wifi_bssids = []
    for i in range(len(BSSID_FEATS)):
        wifi_bssids.extend(data.iloc[:,i].values.tolist())
    wifi_bssids = list(set(wifi_bssids))

    wifi_bssids = np.unique(wifi_bssids)
    wifi_bssids_size = len(wifi_bssids)
    # print(wifi_bssids_size)

    wifi_bssids_dict={}
    counter = 0               #<-------------  1 not 0
    for wf in wifi_bssids:
        wifi_bssids_dict[wf]=counter
        counter+=1


    for i in BSSID_FEATS:
        data.loc[:,i] = data.loc[:,i] .apply(lambda x: wifi_bssids_dict[x])

    data.loc[:,BSSID_FEATS[:NUM_FEATS]]=data.loc[:,BSSID_FEATS[:NUM_FEATS]].astype('float32')

    Ms=np.mean(data.loc[:,RSSI_FEATS[:NUM_FEATS]].values.astype('float32'),axis=0)
    Ss=np.std(data.loc[:,RSSI_FEATS[:NUM_FEATS]].values.astype('float32'),axis=0)

    for i in range(NUM_FEATS):
        data.loc[:,RSSI_FEATS[i]] = ((data.loc[:,RSSI_FEATS[i]] - Ms[i])/(Ss[i]+1)).astype('float32')

    unpaths=data.path.unique()

    data.x=data.x.values.astype('float32')
    data.y=data.y.values.astype('float32')
    ##########################################


    score_df = pd.DataFrame()
    oof = list()
    predictions = list()

    oof_x, oof_y = np.zeros(data.shape[0]), np.zeros(data.shape[0])
    preds_x, preds_y = 0, 0

    scores_per_fold=[]

    all_preds=[]
    all_targets=[]

    np.random.seed(42)
    sh=np.random.permutation(unpaths)


    k=5
    val_size=int(len(sh)/k)
    for f in range(k):
        # print('fold:', f)

        if f<(k-1):
            val_paths=sh[val_size*f:val_size*(f+1)]
        else:
            val_paths=sh[val_size*f:]

        train_paths=[x for x in unpaths if x not in val_paths]
        
        val_paths=np.array(val_paths)
        train_paths=np.array(train_paths)

        X_train = data.loc[data.path.isin(train_paths), BSSID_FEATS + RSSI_FEATS ].reset_index(drop=True)

        y_train =  data.loc[data.path.isin(train_paths), ['x', 'y'] ].reset_index(drop=True).values

        X_val = data.loc[data.path.isin(val_paths), BSSID_FEATS + RSSI_FEATS ].reset_index(drop=True)
        y_val = data.loc[data.path.isin(val_paths), ['x', 'y'] ].reset_index(drop=True).values


        model = create_model(bssid_size1=NUM_FEATS, rssi_size=NUM_FEATS  )
        epochs=140
        snapshots = 7
        lr_0 = 0.01
        lr_anneal1 = LearningRateScheduler(schedule=_cosine_anneal_schedule, verbose=False)

        h = model.fit(np.concatenate((X_train.loc[:,BSSID_FEATS[:NUM_FEATS]].values, X_train.loc[:,RSSI_FEATS[:NUM_FEATS]].values),1),
                    y_train, 
                    batch_size=128*8, epochs=epochs, verbose=0,
                    validation_data=(np.concatenate((X_val.loc[:,BSSID_FEATS[:NUM_FEATS]].values, X_val.loc[:,RSSI_FEATS[:NUM_FEATS]].values),1),
                    y_val),
                    callbacks=[ lr_anneal1])
            
        epochs=140
        snapshots = 7
        lr_0 = 0.001
        lr_anneal1 = LearningRateScheduler(schedule=_cosine_anneal_schedule, verbose=False)

        h = model.fit(np.concatenate((X_train.loc[:,BSSID_FEATS[:NUM_FEATS]].values, X_train.loc[:,RSSI_FEATS[:NUM_FEATS]].values),1),
                    y_train, 
                    batch_size=128*8, epochs=epochs, verbose=0,
                    validation_data=(np.concatenate((X_val.loc[:,BSSID_FEATS[:NUM_FEATS]].values, X_val.loc[:,RSSI_FEATS[:NUM_FEATS]].values),1),
                    y_val),
                    callbacks=[ lr_anneal1])

        # model.save_weights(weights_path+name+'_fold'+str(f)+'.hdf5')
        val_predsXY = model.predict(np.concatenate((X_val.loc[:,BSSID_FEATS[:NUM_FEATS]].values, X_val.loc[:,RSSI_FEATS[:NUM_FEATS]].values),1)) 

        
        # print(euclidean_distance(val_predsXY[:,0], val_predsXY[:,1], y_val[:,0], y_val[:,1]))

        all_preds.append(val_predsXY)
        all_targets.append(y_val)
            

    all_predsV=np.vstack(all_preds)
    all_targetsV=np.vstack(all_targets)    
    print(rs,'mean validation error, 5-fold', euclidean_distance(all_targetsV[:,0], all_targetsV[:,1], all_predsV[:,0], all_predsV[:,1]))
    scores.append(euclidean_distance(all_targetsV[:,0], all_targetsV[:,1], all_predsV[:,0], all_predsV[:,1]))
    print(np.mean(scores))
    print('---------------------')
# Out:
# 0 mean validation error, 5-fold 2.5735896
# 2.5735896
# ---------------------
# 1 mean validation error, 5-fold 2.538625
# 2.5561073
# ---------------------
# 2 mean validation error, 5-fold 2.49376
# 2.5353248
# ---------------------
# 3 mean validation error, 5-fold 2.47114
# 2.5192785
# ---------------------
# 4 mean validation error, 5-fold 2.5887396
# 2.5331707
# ---------------------
# 5 mean validation error, 5-fold 2.5449252
# 2.5351298
# ---------------------
# 6 mean validation error, 5-fold 2.6676733
# 2.5540645
# ---------------------
# 7 mean validation error, 5-fold 2.627102
# 2.5631943
# ---------------------
# 8 mean validation error, 5-fold 2.4649851
# 2.552282
# ---------------------
# 9 mean validation error, 5-fold 2.5391514
# 2.5509691
# ---------------------
# 10 mean validation error, 5-fold 2.4323359
# 2.5401843
# ---------------------
# 11 mean validation error, 5-fold 2.5439048
# 2.5404944
# ---------------------
# 12 mean validation error, 5-fold 2.4857166
# 2.5362806
# ---------------------
# 13 mean validation error, 5-fold 2.579049
# 2.5393355
# ---------------------
# 14 mean validation error, 5-fold 2.5400562
# 2.5393834
# ---------------------
# 15 mean validation error, 5-fold 2.6505835
# 2.5463336
# ---------------------
# 16 mean validation error, 5-fold 2.7531896
# 2.5585015
# ---------------------
# 17 mean validation error, 5-fold 2.546197
# 2.557818
# ---------------------
# 18 mean validation error, 5-fold 2.631257
# 2.561683
# ---------------------
# 19 mean validation error, 5-fold 2.5708563
# 2.562142
# ---------------------
# 20 mean validation error, 5-fold 2.5600116
# 2.5620403
# ---------------------
# 21 mean validation error, 5-fold 2.5674047
# 2.5622842
# ---------------------
# 22 mean validation error, 5-fold 2.493924
# 2.559312
# ---------------------
# 23 mean validation error, 5-fold 2.5001085
# 2.5568452
# ---------------------
# 24 mean validation error, 5-fold 2.6109042
# 2.5590076
# ---------------------
# 25 mean validation error, 5-fold 2.4798381
# 2.5559626
# ---------------------
# 26 mean validation error, 5-fold 2.6180232
# 2.5582612
# ---------------------
# 27 mean validation error, 5-fold 2.4868689
# 2.5557115
# ---------------------
# 28 mean validation error, 5-fold 2.6091685
# 2.5575547
# ---------------------
# 29 mean validation error, 5-fold 2.5765698
# 2.5581887
# ---------------------
# 30 mean validation error, 5-fold 2.4520962
# 2.5547662
# ---------------------
# 31 mean validation error, 5-fold 2.5050774
# 2.5532134
# ---------------------
# 32 mean validation error, 5-fold 2.5110037
# 2.5519342
# ---------------------
# 33 mean validation error, 5-fold 2.535192
# 2.551442
# ---------------------
# 34 mean validation error, 5-fold 2.499952
# 2.5499709
# ---------------------
# 35 mean validation error, 5-fold 2.5685394
# 2.5504866
# ---------------------
# 36 mean validation error, 5-fold 2.5517974
# 2.550522
# ---------------------
# 37 mean validation error, 5-fold 2.6328516
# 2.5526886
# ---------------------
# 38 mean validation error, 5-fold 2.527536
# 2.5520437
# ---------------------
# 39 mean validation error, 5-fold 2.525578
# 2.551382
# ---------------------
# 40 mean validation error, 5-fold 2.6738808
# 2.55437
# ---------------------
# 41 mean validation error, 5-fold 2.5148866
# 2.5534298
# ---------------------
# 42 mean validation error, 5-fold 2.6444218
# 2.5555458
# ---------------------
# 43 mean validation error, 5-fold 2.5764112
# 2.55602
# ---------------------
# 44 mean validation error, 5-fold 2.5717652
# 2.5563698
# ---------------------
# 45 mean validation error, 5-fold 2.5188603
# 2.5555544
# ---------------------
# 46 mean validation error, 5-fold 2.5980392
# 2.5564582
# ---------------------
# 47 mean validation error, 5-fold 2.4730272
# 2.5547204
# ---------------------
# 48 mean validation error, 5-fold 2.5300674
# 2.5542173
# ---------------------
# 49 mean validation error, 5-fold 2.4550183
# 2.5522332
# ---------------------
# 50 mean validation error, 5-fold 2.6363647
# 2.553883
# ---------------------
# 51 mean validation error, 5-fold 2.5626884
# 2.554052
# ---------------------
# 52 mean validation error, 5-fold 2.520576
# 2.5534205
# ---------------------
# 53 mean validation error, 5-fold 2.5806324
# 2.5539243
# ---------------------
# 54 mean validation error, 5-fold 2.578667
# 2.5543742
# ---------------------
# 55 mean validation error, 5-fold 2.640489
# 2.555912
# ---------------------
# 56 mean validation error, 5-fold 2.4748423
# 2.5544896
# ---------------------
# 57 mean validation error, 5-fold 2.4460583
# 2.5526202
# ---------------------
# 58 mean validation error, 5-fold 2.4889417
# 2.5515409
# ---------------------
# 59 mean validation error, 5-fold 2.5098677
# 2.5508463
# ---------------------
# 60 mean validation error, 5-fold 2.5430026
# 2.5507178
# ---------------------
# 61 mean validation error, 5-fold 2.5020285
# 2.5499325
# ---------------------
# 62 mean validation error, 5-fold 2.5547857
# 2.5500093
# ---------------------
# 63 mean validation error, 5-fold 2.564713
# 2.550239
# ---------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-41-d55b6e28cf31> in <module>()
#     126                     validation_data=(np.concatenate((X_val.loc[:,BSSID_FEATS[:NUM_FEATS]].values, X_val.loc[:,RSSI_FEATS[:NUM_FEATS]].values),1),
#     127                     y_val),
# --> 128                     callbacks=[ lr_anneal1])
#     129
#     130         epochs=140
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1214                 _r=1):
#    1215               callbacks.on_train_batch_begin(step)
# -> 1216               tmp_logs = self.train_function(iterator)
#    1217               if data_handler.should_sync:
#    1218                 context.async_wait()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     908
#     909       with OptionalXlaContext(self._jit_compile):
# --> 910         result = self._call(*args, **kwds)
#     911
#     912       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     940       # In this case we have created variables on the first call, so we run the
#     941       # defunned version which is guaranteed to never create variables.
# --> 942       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     943     elif self._stateful_fn is not None:
#     944       # Release the lock early so that multiple threads can perform the call
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    3129        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    3130     return graph_function._call_flat(
# -> 3131         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    3132
#    3133   @property
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1958       # No tape is watching; skip to running the function.
#    1959       return self._build_call_outputs(self._inference_function.call(
# -> 1960           ctx, args, cancellation_manager=cancellation_manager))
#    1961     forward_backward = self._select_forward_and_backward_functions(
#    1962         args,
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     601               inputs=args,
#     602               attrs=attrs,
# --> 603               ctx=ctx)
#     604         else:
#     605           outputs = execute.execute_with_cancellation(
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      57     ctx.ensure_initialized()
#      58     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 59                                         inputs, attrs, num_outputs)
#      60   except core._NotOkStatusException as e:
#      61     if name is not None:
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt
plt.plot(scores)
plt.title('oof score of every random BSSID SET')
plt.show()

plt.plot(np.cumsum(scores)/np.arange(1,len(scores)+1))
plt.title('Rolling mean score')
plt.show()

print(len(scores))
print(np.mean(scores))
print(np.std(scores))
# Out:
# 64
# 2.550239
# 0.06323206

# %%
plt.figure(figsize=(10,10))
plt.title('XY scatter plot of Predicted positions over target grid')
plt.plot(all_predsV[:,0],all_predsV[:,1],'.', label='Predicted position')
plt.plot(all_targetsV[:,0],all_targetsV[:,1],'o', label='target grid')
plt.legend()
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.show()
print('mean validation error, 5-fold', euclidean_distance(all_targetsV[:,0], all_targetsV[:,1], all_predsV[:,0], all_predsV[:,1]))
# Out:
# mean validation error, 5-fold 2.564713

# %%
scoreperrow=[]
for row in range(len(all_targetsV)):
    scoreperrow.append(euclidean_distance(all_targetsV[row,0], all_targetsV[row,1], all_predsV[row,0], all_predsV[row,1]))
    
plt.figure(figsize=(10,10))
plt.title('XY scatter plot of Predicted positions with error magnitude over target grid')
plt.plot(all_targetsV[:,0],all_targetsV[:,1],'o', color="orange", label='target grid')
plt.scatter(all_predsV[:,0],all_predsV[:,1],s=0.5*np.array(scoreperrow)**2, label='Predicted position')
plt.legend()
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.show()
print('mean validation error, 5-fold', euclidean_distance(all_targetsV[:,0], all_targetsV[:,1], all_predsV[:,0], all_predsV[:,1]))
# Out:
# mean validation error, 5-fold 2.564713

# %%
# for NUM_FEATS in range(46,87,4):

# %%
# # CROSS VALIDATION

# name='keras'+version


# np.random.seed(42)
# sh=np.random.permutation(unpaths)

# k=5
# val_size=int(len(sh)/k)
# alls=[]
# for NUM_FEATS in range(46,87,4):
#     print(NUM_FEATS)


#     score_df = pd.DataFrame()
#     oof = list()
#     predictions = list()

#     oof_x, oof_y = np.zeros(data.shape[0]), np.zeros(data.shape[0])
#     preds_x, preds_y = 0, 0

#     scores_per_fold=[]

#     all_preds=[]
#     all_targets=[]

#     for f in range(k):
#         print('fold:', f)

#         if f<(k-1):
#             val_paths=sh[val_size*f:val_size*(f+1)]
#         else:
#             val_paths=sh[val_size*f:]

#         train_paths=[x for x in unpaths if x not in val_paths]
        
#         val_paths=np.array(val_paths)
#         train_paths=np.array(train_paths)

#         X_train = data.loc[data.path.isin(train_paths), BSSID_FEATS + RSSI_FEATS ].reset_index(drop=True)

#         y_train =  data.loc[data.path.isin(train_paths), ['x', 'y'] ].reset_index(drop=True).values

#         X_val = data.loc[data.path.isin(val_paths), BSSID_FEATS + RSSI_FEATS ].reset_index(drop=True)
#         y_val = data.loc[data.path.isin(val_paths), ['x', 'y'] ].reset_index(drop=True).values


#         model = create_model(bssid_size1=NUM_FEATS, rssi_size=NUM_FEATS  )
#         epochs=100
#         snapshots = 5
#         lr_0 = 0.01
#         lr_anneal1 = LearningRateScheduler(schedule=_cosine_anneal_schedule, verbose=False)

#         h = model.fit(np.concatenate((X_train.loc[:,BSSID_FEATS[:NUM_FEATS]].values, X_train.loc[:,RSSI_FEATS[:NUM_FEATS]].values),1),
#                     y_train, 
#                     batch_size=128*8, epochs=epochs, verbose=0,
#                     validation_data=(np.concatenate((X_val.loc[:,BSSID_FEATS[:NUM_FEATS]].values, X_val.loc[:,RSSI_FEATS[:NUM_FEATS]].values),1),
#                     y_val),
#                     callbacks=[ lr_anneal1])
            
#         epochs=100
#         snapshots = 5
#         lr_0 = 0.001
#         lr_anneal1 = LearningRateScheduler(schedule=_cosine_anneal_schedule, verbose=False)

#         h = model.fit(np.concatenate((X_train.loc[:,BSSID_FEATS[:NUM_FEATS]].values, X_train.loc[:,RSSI_FEATS[:NUM_FEATS]].values),1),
#                     y_train, 
#                     batch_size=128*8, epochs=epochs, verbose=0,
#                     validation_data=(np.concatenate((X_val.loc[:,BSSID_FEATS[:NUM_FEATS]].values, X_val.loc[:,RSSI_FEATS[:NUM_FEATS]].values),1),
#                     y_val),
#                     callbacks=[ lr_anneal1])

#         model.save_weights(weights_path+name+'_fold'+str(f)+'.hdf5')
#         val_predsXY = model.predict(np.concatenate((X_val.loc[:,BSSID_FEATS[:NUM_FEATS]].values, X_val.loc[:,RSSI_FEATS[:NUM_FEATS]].values),1)) 

        
#         print(f,euclidean_distance(val_predsXY[:,0], val_predsXY[:,1], y_val[:,0], y_val[:,1]))

#         all_preds.append(val_predsXY)
#         all_targets.append(y_val)
            

#     all_predsV=np.vstack(all_preds)
#     all_targetsV=np.vstack(all_targets)    

#     alls.append(euclidean_distance(all_targetsV[:,0], all_targetsV[:,1], all_predsV[:,0], all_predsV[:,1]))
#     print('mean validation error, 5-fold', euclidean_distance(all_targetsV[:,0], all_targetsV[:,1], all_predsV[:,0], all_predsV[:,1]))

# %%
name
# Out:
# 'kerasforPdata423'

# %%
# plt.plot(np.array(alls))
# plt.show()

# %%
pd.DataFrame(all_predsV,columns=['x', 'y']).to_csv('/gdrive/My Drive/Colab Notebooks/'+name+'_oof.csv.gz', index=False, compression='gzip')
# pd.DataFrame(all_targetsV,columns=['x', 'y']).to_csv('/gdrive/My Drive/Colab Notebooks/all_targetsV.csv.gz', index=False, compression='gzip')

# %%
l=pd.read_csv('/gdrive/My Drive/Colab Notebooks/lgbmforPdata423_oof.csv.gz')

# %%
euclidean_distance(all_targetsV[:,0], all_targetsV[:,1], l.x.values, l.y.values)
# Out:
# 1.9529933161347668

# %%
euclidean_distance(all_targetsV[:,0], all_targetsV[:,1], (l.x.values+all_predsV[:,0])/2, (l.y.values+all_predsV[:,1])/2)
# Out:
# 1.933713321379115

# %%
euclidean_distance(all_targetsV[:,0], all_targetsV[:,1], (2*l.x.values+all_predsV[:,0])/3, (2*l.y.values+all_predsV[:,1])/3)
# Out:
# 1.9206065956477099

# %%
euclidean_distance(all_targetsV[:,0], all_targetsV[:,1], (2.5*l.x.values+all_predsV[:,0])/3.5, (2.5*l.y.values+all_predsV[:,1])/3.5)
# Out:
# 1.9205684892269967

# %%
euclidean_distance(all_targetsV[:,0], all_targetsV[:,1], (l.x.values*all_predsV[:,0])**0.5, (l.y.values*all_predsV[:,1])**0.5)
# Out:
# 1.9334018037272123

# %% [markdown]
# ## EVALUATION - PLOTS

# %%
import matplotlib.pyplot as plt
plt.plot(all_predsV[:,0],all_predsV[:,1],'.')
plt.show()

# %% [markdown]
# **5 FOLD CV PREDICTIONS OVER TARGET GRID**
# With blue dots are the true checkpoints
# Orange dots for predictions

# %%
plt.figure(figsize=(10,10))
plt.title('XY scatter plot of Predicted positions over target grid')
plt.plot(all_predsV[:,0],all_predsV[:,1],'.', label='Predicted position')
plt.plot(all_targetsV[:,0],all_targetsV[:,1],'o', label='target grid')
plt.legend()
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.show()
print('mean validation error, 5-fold', euclidean_distance(all_targetsV[:,0], all_targetsV[:,1], all_predsV[:,0], all_predsV[:,1]))
# Out:
# mean validation error, 5-fold 2.0872567

# %% [markdown]
# ## Full train

# %%
name='keras'+version

train_paths=unpaths[:]

train_paths=np.array(train_paths)
X_train = data.loc[data.path.isin(train_paths), BSSID_FEATS + RSSI_FEATS ].reset_index(drop=True)#.values

y_train =  data.loc[data.path.isin(train_paths), ['x', 'y'] ].reset_index(drop=True).values

model = create_model(bssid_size1=NUM_FEATS, rssi_size=NUM_FEATS  )
epochs=160
snapshots = 8
lr_0 = 0.01
lr_anneal1 = LearningRateScheduler(schedule=_cosine_anneal_schedule, verbose=False)

h = model.fit(np.concatenate((X_train.loc[:,BSSID_FEATS[:NUM_FEATS]].values, X_train.loc[:,RSSI_FEATS[:NUM_FEATS]].values),1),
                  y_train, 
                  batch_size=128*8, epochs=epochs, verbose=1,
                callbacks=[ lr_anneal1])

epochs=160
snapshots = 8
lr_0 = 0.001
lr_anneal1 = LearningRateScheduler(schedule=_cosine_anneal_schedule, verbose=False)

h = model.fit(np.concatenate((X_train.loc[:,BSSID_FEATS[:NUM_FEATS]].values, X_train.loc[:,RSSI_FEATS[:NUM_FEATS]].values),1),
                  y_train, 
                  batch_size=128*8, epochs=epochs, verbose=1,
                callbacks=[ lr_anneal1])
model.save_weights(weights_path+name+'_full'+'.hdf5')
train_predsXY = model.predict(np.concatenate((X_train.loc[:,BSSID_FEATS[:NUM_FEATS]].values, X_train.loc[:,RSSI_FEATS[:NUM_FEATS]].values),1))


print('train error',euclidean_distance(train_predsXY[:,0], train_predsXY[:,1], y_train[:,0], y_train[:,1]))
# Out:
# Epoch 1/160
# 15/15 [==============================] - 10s 84ms/step - loss: 2180.6851 - mse: 2180.6851 - lr: 0.0100
# Epoch 2/160
# 15/15 [==============================] - 1s 81ms/step - loss: 1966.9594 - mse: 1966.9594 - lr: 0.0099
# Epoch 3/160
# 15/15 [==============================] - 1s 84ms/step - loss: 1638.3950 - mse: 1638.3950 - lr: 0.0098
# Epoch 4/160
# 15/15 [==============================] - 1s 82ms/step - loss: 1197.9225 - mse: 1197.9225 - lr: 0.0095
# Epoch 5/160
# 15/15 [==============================] - 1s 82ms/step - loss: 752.6922 - mse: 752.6922 - lr: 0.0090
# Epoch 6/160
# 15/15 [==============================] - 1s 81ms/step - loss: 412.5598 - mse: 412.5598 - lr: 0.0085
160
# 15/15 [==============================] - 1s 85ms/step - loss: 3.4255 - mse: 3.4255 - lr: 5.0000e-04
# Epoch 132/160
# 15/15 [==============================] - 1s 90ms/step - loss: 3.5101 - mse: 3.5101 - lr: 4.2178e-04
# Epoch 133/160
# 15/15 [==============================] - 1s 87ms/step - loss: 3.4176 - mse: 3.4176 - lr: 3.4549e-04
# Epoch 134/160
# 15/15 [==============================] - 1s 84ms/step - loss: 3.4584 - mse: 3.4584 - lr: 2.7300e-04
# Epoch 135/160
# 15/15 [==============================] - 1s 84ms/step - loss: 3.5424 - mse: 3.5424 - lr: 2.0611e-04
# Epoch 136/160
# 15/15 [==============================] - 1s 88ms/step - loss: 3.4782 - mse: 3.4782 - lr: 1.4645e-04
# Epoch 137/160
# 15/15 [==============================] - 1s 85ms/step - loss: 3.4721 - mse: 3.4721 - lr: 9.5492e-05
# Epoch 138/160
# 15/15 [==============================] - 1s 83ms/step - loss: 3.4207 - mse: 3.4207 - lr: 5.4497e-05
# Epoch 139/160
# 15/15 [==============================] - 1s 85ms/step - loss: 3.4426 - mse: 3.4426 - lr: 2.4472e-05
# Epoch 140/160
# 15/15 [==============================] - 1s 89ms/step - loss: 3.4816 - mse: 3.4816 - lr: 6.1558e-06
# Epoch 141/160
# 15/15 [==============================] - 1s 86ms/step - loss: 3.4362 - mse: 3.4362 - lr: 0.0010
# Epoch 142/160
# 15/15 [==============================] - 1s 87ms/step - loss: 3.4112 - mse: 3.4112 - lr: 9.9384e-04
# Epoch 143/160
# 15/15 [==============================] - 1s 84ms/step - loss: 3.4491 - mse: 3.4491 - lr: 9.7553e-04
# Epoch 144/160
# 15/15 [==============================] - 1s 89ms/step - loss: 3.5140 - mse: 3.5140 - lr: 9.4550e-04
# Epoch 145/160
# 15/15 [==============================] - 1s 84ms/step - loss: 3.5328 - mse: 3.5328 - lr: 9.0451e-04
# Epoch 146/160
# 15/15 [==============================] - 1s 84ms/step - loss: 3.5828 - mse: 3.5828 - lr: 8.5355e-04
# Epoch 147/160
# 15/15 [==============================] - 1s 86ms/step - loss: 3.4933 - mse: 3.4933 - lr: 7.9389e-04
# Epoch 148/160
# 15/15 [==============================] - 1s 86ms/step - loss: 3.5526 - mse: 3.5526 - lr: 7.2700e-04
# Epoch 149/160
# 15/15 [==============================] - 1s 90ms/step - loss: 3.4732 - mse: 3.4732 - lr: 6.5451e-04
# Epoch 150/160
# 15/15 [==============================] - 1s 84ms/step - loss: 3.4675 - mse: 3.4675 - lr: 5.7822e-04
# Epoch 151/160
# 15/15 [==============================] - 1s 83ms/step - loss: 3.4853 - mse: 3.4853 - lr: 5.0000e-04
# Epoch 152/160
# 15/15 [==============================] - 1s 83ms/step - loss: 3.5897 - mse: 3.5897 - lr: 4.2178e-04
# Epoch 153/160
# 15/15 [==============================] - 1s 84ms/step - loss: 3.4724 - mse: 3.4724 - lr: 3.4549e-04
# Epoch 154/160
# 15/15 [==============================] - 1s 87ms/step - loss: 3.5265 - mse: 3.5265 - lr: 2.7300e-04
# Epoch 155/160
# 15/15 [==============================] - 1s 88ms/step - loss: 3.4231 - mse: 3.4231 - lr: 2.0611e-04
# Epoch 156/160
# 15/15 [==============================] - 1s 85ms/step - loss: 3.4980 - mse: 3.4980 - lr: 1.4645e-04
# Epoch 157/160
# 15/15 [==============================] - 1s 85ms/step - loss: 3.4102 - mse: 3.4102 - lr: 9.5492e-05
# Epoch 158/160
# 15/15 [==============================] - 1s 83ms/step - loss: 3.3619 - mse: 3.3619 - lr: 5.4497e-05
# Epoch 159/160
# 15/15 [==============================] - 1s 87ms/step - loss: 3.4530 - mse: 3.4530 - lr: 2.4472e-05
# Epoch 160/160
# 15/15 [==============================] - 1s 89ms/step - loss: 3.4858 - mse: 3.4858 - lr: 6.1558e-06
# train error 1.7826717
