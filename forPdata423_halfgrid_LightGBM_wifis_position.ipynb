# %%
print('Connect to google drive')
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Connect to google drive
# Mounted at /gdrive

# %%
print('Import necessary libraries')

import numpy as np
import pandas as pd
import scipy.stats as stats
from pathlib import Path
import glob
import pickle

import warnings
warnings.filterwarnings("ignore")

import random
import os
os.environ["CUDA_VISIBLE_DEVICES"]="0"
import gc
import tqdm

from sklearn.model_selection import StratifiedKFold, GroupKFold
from sklearn.preprocessing import StandardScaler, LabelEncoder

import joblib
import lightgbm as lgb
# Out:
# Import necessary libraries

# %%
base_path='/gdrive/My Drive/Colab Notebooks/'
weights_path='/gdrive/My Drive/Colab Notebooks/weights/'

# %%
def euclidean_distance(x_true,y_true, x_pred, y_pred):
    return np.mean(((x_true-x_pred)**2+(y_true-y_pred)**2)**0.5)

# %%
version='forPdata423_halfgrid'

# %%
data=pd.read_csv('/gdrive/My Drive/Colab Notebooks/data423.csv.zip') #
data.shape
# Out:
# (14373, 316)

# %%
data.head()
# Out:
#    rsid1  rsid2  rsid3  rsid4  rsid5  rsid6  rsid7  rsid8  rsid9  rsid10  ...  \
# 0    -93   -999    -81   -999   -999   -999   -999   -999   -999    -999  ...
# 1    -93   -999    -81   -999   -999   -999   -999   -999   -999    -999  ...
# 2   -999   -999   -999   -999   -999   -999   -999   -999   -999    -999  ...
# 3   -999   -999   -999   -999   -999   -999   -999   -999   -999    -999  ...
# 4    -78   -999   -999    -95   -999   -999   -999   -999   -999    -999  ...
#
#    rsid307  rsid308  rsid309  rsid310  rsid311  rsid312      x      y  \
# 0     -999     -999     -999     -999     -999     -999  43.26  25.89
# 1     -999     -999     -999     -999     -999     -999  43.26  25.89
# 2     -999     -999     -999     -999     -999     -999  43.26  25.89
# 3     -999     -999     -999     -999     -999     -999  43.26  25.89
# 4     -999     -999     -999     -999     -999     -999  40.85  25.74
#
#        timestamp                        path
# 0  1633934464983  record_2021_10_11_07_41_02
# 1  1633934467125  record_2021_10_11_07_41_02
# 2  1633934469251  record_2021_10_11_07_41_02
# 3  1633934471370  record_2021_10_11_07_41_02
# 4  1633934473508  record_2021_10_11_07_41_02
#
# [5 rows x 316 columns]

# %%
uniquePoints=data.loc[data.loc[:,['x','y']].duplicated()==False,['x','y']]
print('we have a target grid of',uniquePoints.shape[0],'unique points')

# sets divided in forPdata423_halfgrid_KNeighbors_wifis_position.ipynb
set1=[85,79,77,68,32,30,28,70,83,80,82,72,8,6,4,26,23,25,21,19,51,33,0,2,62,60,58,56,74,10,53,49,47,65,13,34,46,36,38,15,45,17,41,18]
set2=[84,78,86,67,69,31,29,27,71,81,73,76,7,5,3,24,9,22,20,50,64,1,63,61,59,57,55,52,54,11,48,12,66,75,14,35,37,39,16,40,42,44,43]

uniquePoints['pointNum']=np.arange(len(uniquePoints))
uniquePoints['setNum']=1
uniquePoints.setNum.iloc[set2]=2

data=data.merge(uniquePoints,left_on=['x','y'],right_on=['x','y'])
# Out:
# we have a target grid of 87 unique points

# %%
# print('split path-timestamp in 2 columns')
# data[['path','timestamp']]=data['path-timestamp'].str.split('-',expand=True)
# print('remove path-timestamp column')
# data.drop('path-timestamp', axis=1,inplace=True)

# %%
dataA=data.copy()

# %%
TRAIN_FEATS=[x for x in data.columns if x not in ['x', 'y', 'path', 'timestamp', 'pointNum', 'setNum']]
len(TRAIN_FEATS)
# Out:
# 312

# %%
unpaths=data.path.unique()

# %%
print('we have ',len(unpaths),' unique paths')
# Out:
# we have  423  unique paths

# %% [markdown]
# ### CV TRAIN

# %%
hyper_params = {
    'task': 'train',
    'boosting_type': 'gbdt',
    'objective': 'regression',
    'metric': ['l1','l2'],
    'learning_rate': 0.005,
    'feature_fraction': 0.2,
    'bagging_fraction': 0.8,
    'bagging_freq': 10,
    'verbose': 0,
    "max_depth": 11,
    "num_leaves": 256,  
    "max_bin": 256,
    "num_iterations": 15000
}
# hyper_params = {
#     'task': 'train',
#     'boosting_type': 'gbdt',
#     'objective': 'regression',
#     'metric': ['l1','l2'],
#     'learning_rate': 0.005,
#     'feature_fraction': 0.2,
#     'bagging_fraction': 0.8,
#     'bagging_freq': 10,
#     'verbose': 0,
#     "max_depth": 14,
#     "num_leaves": 256,  
#     "max_bin": 256,
#     "num_iterations": 15000
# }

# %%
# CROSS VALIDATION

name='lgbm'+version


split_score=[]
for split in [1,2]:
    data=dataA.loc[dataA.setNum==split,:]
    data.shape
    unpaths=data.path.unique()
    print('we have ',len(unpaths),' unique paths')
    score_df = pd.DataFrame()
    oof = list()
    predictions = list()

    oof_x, oof_y = np.zeros(data.shape[0]), np.zeros(data.shape[0])
    preds_x, preds_y = 0, 0

    scores_per_fold=[]

    all_preds=[]
    all_targets=[]

    np.random.seed(42)
    sh=np.random.permutation(unpaths)


    k=5
    val_size=int(len(sh)/k)
    for f in range(k):
        print('fold:', f)

        if f<(k-1):
            val_paths=sh[val_size*f:val_size*(f+1)]
        else:
            val_paths=sh[val_size*f:]

        train_paths=[x for x in unpaths if x not in val_paths]
        
        val_paths=np.array(val_paths)
        train_paths=np.array(train_paths)
        
        X_train = data.loc[data.path.isin(train_paths), TRAIN_FEATS ].reset_index(drop=True)

        y_trainXY =  data.loc[data.path.isin(train_paths), ['x', 'y'] ].reset_index(drop=True).values

        X_val = data.loc[data.path.isin(val_paths), TRAIN_FEATS ].reset_index(drop=True)
        y_valXY = data.loc[data.path.isin(val_paths), ['x', 'y'] ].reset_index(drop=True).values

        val_predsXY=[]
        for i in range(2):
            y_train = y_trainXY[:,i]
            y_val = y_valXY[:,i]

            gbm = lgb.LGBMRegressor(**hyper_params)
            model = gbm.fit(X_train, y_train,
                eval_set=[(X_train, y_train), (X_val, y_val)],
                eval_metric='l1',
                verbose=100,
                early_stopping_rounds=200)
            
            # joblib.dump(model, weights_path+'fold_'+str(f)+['x','y'][i]+'_v2')
            joblib.dump(model, weights_path+name+'split'+str(split)+'fold_'+str(f)+['x','y'][i]+'_v2')
            
            val_predsXY.append(gbm.predict(X_val, num_iteration=gbm.best_iteration_) )
        val_predsXY=np.stack(val_predsXY).T
        
        print(euclidean_distance(val_predsXY[:,0], val_predsXY[:,1], y_valXY[:,0], y_valXY[:,1]))

        all_preds.append(val_predsXY)
        all_targets.append(y_valXY)
            

    all_predsV=np.vstack(all_preds)
    all_targetsV=np.vstack(all_targets)    

    print('mean validation error, 5-fold', euclidean_distance(all_targetsV[:,0], all_targetsV[:,1], all_predsV[:,0], all_predsV[:,1]))
    split_score.append(euclidean_distance(all_targetsV[:,0], all_targetsV[:,1], all_predsV[:,0], all_predsV[:,1]))
print('average splits score', np.mean(split_score))
# Out:
# we have  423  unique paths
# fold: 0
# Training until validation scores don't improve for 200 rounds.
# [100]	training's l2: 39.6132	training's l1: 4.76095	valid_1's l2: 43.1557	valid_1's l1: 4.9643
# [200]	training's l2: 16.6362	training's l1: 3.12606	valid_1's l2: 19.3251	valid_1's l1: 3.36672
# [300]	training's l2: 7.69353	training's l1: 2.14164	valid_1's l2: 10.1905	valid_1's l1: 2.44735
# [400]	training's l2: 4.10038	training's l1: 1.55087	valid_1's l2: 6.58797	valid_1's l1: 1.93656
# [500]	training's l2: 2.56903	training's l1: 1.19898	valid_1's l2: 5.16637	valid_1's l1: 1.68469
# [600]	training's l2: 1.86671	training's l1: 0.986766	valid_1's l2: 4.54297	valid_1's l1: 1.54845
# [700]	training's l2: 1.5088	training's l1: 0.859049	valid_1's l2: 4.27723	valid_1's l1: 1.47706
# [800]	training's l2: 1.30581	training's l1: 0.779923	valid_1's l2: 4.15412	valid_1's l1: 1.44097
# [900]	training's l2: 1.1666	training's l1: 0.724123	valid_1's l2: 4.09065	valid_1's l1: 1.42446
# [1000]	training's l2: 1.0708	training's l1: 0.686391	valid_1's l2: 4.05742	valid_1's l1: 1.41433
# [1100]	training's l2: 1.00489	training's l1: 0.660464	valid_1's l2: 4.03994	valid_1's l1: 1.40894
# [1200]	training's l2: 0.957626	training's l1: 0.642102	valid_1's l2: 4.02762	valid_1's l1: 1.40485
# [1300]	training's l2: 0.921803	training's l1: 0.628618	valid_1's l2: 4.02173	valid_1's l1: 1.40262
# [1400]	training's l2: 0.886934	training's l1: 0.615748	valid_1's l2: 4.01837	valid_1's l1: 1.40113
# [1500]	training's l2: 0.861503	training's l1: 0.606144	valid_1's l2: 4.01303	valid_1's l1: 1.39935
# [1600]	training's l2: 0.833062	training's l1: 0.594993	valid_1's l2: 4.01087	valid_1's l1: 1.39914
# [1700]	training's l2: 0.808862	training's l1: 0.585918	valid_1's l2: 4.0053	valid_1's l1: 1.39883
# [1800]	training's l2: 0.786419	training's l1: 0.576787	valid_1's l2: 4.00543	valid_1's l1: 1.39861
# [1900]	training's l2: 0.764976	training's l1: 0.567613	valid_1's l2: 4.00236	valid_1's l1: 1.39797
# [2000]	training's l2: 0.744424	training's l1: 0.559474	valid_1's l2: 4.00766	valid_1's l1: 1.3985
# [2100]	training's l2: 0.722504	training's l1: 0.550166	valid_1's l2: 4.00549	valid_1's l1: 1.39815
# Early stopping, best iteration is:
# [1900]	training's l2: 0.764976	training's l1: 0.567613	valid_1's l2: 4.00236	valid_1's l1: 1.39797
# Training until validation scores don't improve for 200 rounds.
# [100]	training's l2: 50.781	training's l1: 5.69061	valid_1's l2: 49.7539	valid_1's l1: 5.38156
# [200]	training's l2: 20.1688	training's l1: 3.5767	valid_1's l2: 21.0044	valid_1's l1: 3.48416
# [300]	training's l2: 8.51625	training's l1: 2.30205	valid_1's l2: 10.0201	valid_1's l1: 2.37107
# [400]	training's l2: 4.01287	training's l1: 1.54226	valid_1's l2: 5.75903	valid_1's l1: 1.72885
# [500]	training's l2: 2.21018	training's l1: 1.10207	valid_1's l2: 4.07976	valid_1's l1: 1.38452
# [600]	training's l2: 1.45527	training's l1: 0.84728	valid_1's l2: 3.39366	valid_1's l1: 1.20875
# [700]	training's l2: 1.105	training's l1: 0.700164	valid_1's l2: 3.09592	valid_1's l1: 1.11499
# [800]	training's l2: 0.924055	training's l1: 0.61238	valid_1's l2: 2.95779	valid_1's l1: 1.06717
# [900]	training's l2: 0.814176	training's l1: 0.55711	valid_1's l2: 2.8882	valid_1's l1: 1.04308
# [1000]	training's l2: 0.742082	training's l1: 0.522856	valid_1's l2: 2.84924	valid_1's l1: 1.03088
# [1100]	training's l2: 0.6913	training's l1: 0.499872	valid_1's l2: 2.82501	valid_1's l1: 1.02435
# [1200]	training's l2: 0.654843	training's l1: 0.484274	valid_1's l2: 2.80939	valid_1's l1: 1.02138
# [1300]	training's l2: 0.628201	training's l1: 0.473674	valid_1's l2: 2.8	valid_1's l1: 1.01913
# [1400]	training's l2: 0.604367	training's l1: 0.463456	valid_1's l2: 2.79258	valid_1's l1: 1.01689
# [1500]	training's l2: 0.583713	training's l1: 0.454641	valid_1's l2: 2.78711	valid_1's l1: 1.01538
# [1600]	training's l2: 0.566333	training's l1: 0.4472	valid_1's l2: 2.78167	valid_1's l1: 1.01432
# [1700]	training's l2: 0.55044	training's l1: 0.440546	valid_1's l2: 2.77944	valid_1's l1: 1.01431
# [1800]	training's l2: 0.536193	training's l1: 0.43394	valid_1's l2: 2.7763	valid_1's l1: 1.01384
# [1900]	training's l2: 0.521434	training's l1: 0.427117	valid_1's l2: 2.77642	valid_1's l1: 1.01375
# [2000]	training's l2: 0.50875	training's l1: 0.420981	valid_1's l2: 2.7746	valid_1's l1: 1.01289
# [2100]	training's l2: 0.496232	training's l1: 0.414926	valid_1's l2: 2.7722	valid_1's l1: 1.01273
# [2200]	training's l2: 0.484092	training's l1: 0.408809	valid_1's l2: 2.77051	valid_1's l1: 1.01219
# [2300]	training's l2: 0.470808	training's l1: 0.401533	valid_1's l2: 2.76832	valid_1's l1: 1.01178
# [2400]	training's l2: 0.460309	training's l1: 0.395854	valid_1's l2: 2.76625	valid_1's l1: 1.01135
# [2500]	training's l2: 0.44959	training's l1: 0.39015	valid_1's l2: 2.76482	valid_1's l1: 1.01107
# [2600]	training's l2: 0.438305	training's l1: 0.384034	valid_1's l2: 2.76431	valid_1's l1: 1.0113
# [2700]	training's l2: 0.426654	training's l1: 0.377546	valid_1's l2: 2.76345	valid_1's l1: 1.01115
# [2800]	training's l2: 0.416548	training's l1: 0.371451	valid_1's l2: 2.76071	valid_1's l1: 1.0106
# [2900]	training's l2: 0.406473	training's l1: 0.365806	valid_1's l2: 2.76191	valid_1's l1: 1.01079
# [3000]	training's l2: 0.397212	training's l1: 0.360154	valid_1's l2: 2.75988	valid_1's l1: 1.01038
# [3100]	training's l2: 0.388518	training's l1: 0.354827	valid_1's l2: 2.75912	valid_1's l1: 1.0102
# [3200]	training's l2: 0.380765	training's l1: 0.34996	valid_1's l2: 2.75941	valid_1's l1: 1.01025
# [3300]	training's l2: 0.372421	training's l1: 0.344452	valid_1's l2: 2.75906	valid_1's l1: 1.01038
# Early stopping, best iteration is:
# [3117]	training's l2: 0.387558	training's l1: 0.354336	valid_1's l2: 2.75866	valid_1's l1: 1.01002
# 1.9999615183915267
# fold: 1
# Training until validation scores don't improve for 200 rounds.
# [100]	training's l2: 40.1092	training's l1: 4.77984	valid_1's l2: 40.7729	valid_1's l1: 4.84501
# [200]	training's l2: 16.8306	training's l1: 3.13712	valid_1's l2: 18.0036	valid_1's l1: 3.25465
# [300]	training's l2: 7.72097	training's l1: 2.14107	valid_1's l2: 9.27177	valid_1's l1: 2.33959
# [400]	training's l2: 4.08171	training's l1: 1.54472	valid_1's l2: 5.85361	valid_1's l1: 1.82705
# [500]	training's l2: 2.56301	training's l1: 1.19627	valid_1's l2: 4.5126	valid_1's l1: 1.56723
# [600]	training's l2: 1.8644	training's l1: 0.987422	valid_1's l2: 3.95731	valid_1's l1: 1.43597
# [700]	training's l2: 1.50998	training's l1: 0.859306	valid_1's l2: 3.72359	valid_1's l1: 1.37424
# [800]	training's l2: 1.30423	training's l1: 0.777515	valid_1's l2: 3.61369	valid_1's l1: 1.34367
# [900]	training's l2: 1.17078	training's l1: 0.723218	valid_1's l2: 3.57123	valid_1's l1: 1.32964
# [1000]	training's l2: 1.07962	training's l1: 0.686877	valid_1's l2: 3.55035	valid_1's l1: 1.3236
# [1100]	training's l2: 1.01893	training's l1: 0.662668	valid_1's l2: 3.53909	valid_1's l1: 1.32042
# [1200]	training's l2: 0.975877	training's l1: 0.646029	valid_1's l2: 3.53836	valid_1's l1: 1.31931
# [1300]	training's l2: 0.937543	training's l1: 0.630162	valid_1's l2: 3.53541	valid_1's l1: 1.31832
# [1400]	training's l2: 0.906037	training's l1: 0.617223	valid_1's l2: 3.53298	valid_1's l1: 1.31728
# [1500]	training's l2: 0.878242	training's l1: 0.605958	valid_1's l2: 3.53134	valid_1's l1: 1.31642
# [1600]	training's l2: 0.853891	training's l1: 0.595878	valid_1's l2: 3.53458	valid_1's l1: 1.31671
# [1700]	training's l2: 0.828186	training's l1: 0.585487	valid_1's l2: 3.53582	valid_1's l1: 1.31653
# Early stopping, best iteration is:
# [1505]	training's l2: 0.877192	training's l1: 0.605505	valid_1's l2: 3.53077	valid_1's l1: 1.31632
# Training until validation scores don't improve for 200 rounds.
# [100]	training's l2: 50.9561	training's l1: 5.62451	valid_1's l2: 47.713	valid_1's l1: 5.37482
# [200]	training's l2: 20.2643	training's l1: 3.54237	valid_1's l2: 19.4235	valid_1's l1: 3.41315
# [300]	training's l2: 8.59337	training's l1: 2.28827	valid_1's l2: 8.80495	valid_1's l1: 2.26966
# [400]	training's l2: 4.08122	training's l1: 1.54423	valid_1's l2: 4.78901	valid_1's l1: 1.6446
# [500]	training's l2: 2.27529	training's l1: 1.10692	valid_1's l2: 3.24922	valid_1's l1: 1.3337
# [600]	training's l2: 1.51096	training's l1: 0.85198	valid_1's l2: 2.64926	valid_1's l1: 1.17582
# [700]	training's l2: 1.15289	training's l1: 0.70285	valid_1's l2: 2.41073	valid_1's l1: 1.09756
# [800]	training's l2: 0.966445	training's l1: 0.614255	valid_1's l2: 2.31124	valid_1's l1: 1.06053
# [900]	training's l2: 0.853264	training's l1: 0.559086	valid_1's l2: 2.26926	valid_1's l1: 1.04346
# [1000]	training's l2: 0.776629	training's l1: 0.524833	valid_1's l2: 2.25387	valid_1's l1: 1.03717
# [1100]	training's l2: 0.725376	training's l1: 0.503171	valid_1's l2: 2.24848	valid_1's l1: 1.03498
# [1200]	training's l2: 0.690562	training's l1: 0.48911	valid_1's l2: 2.24596	valid_1's l1: 1.03391
# [1300]	training's l2: 0.660409	training's l1: 0.476917	valid_1's l2: 2.24494	valid_1's l1: 1.03297
# [1400]	training's l2: 0.638855	training's l1: 0.468177	valid_1's l2: 2.2419	valid_1's l1: 1.03231
# [1500]	training's l2: 0.617711	training's l1: 0.459459	valid_1's l2: 2.24066	valid_1's l1: 1.03161
# [1600]	training's l2: 0.599569	training's l1: 0.451871	valid_1's l2: 2.23644	valid_1's l1: 1.03016
# [1700]	training's l2: 0.582749	training's l1: 0.444666	valid_1's l2: 2.23507	valid_1's l1: 1.02979
# [1800]	training's l2: 0.567251	training's l1: 0.437996	valid_1's l2: 2.23247	valid_1's l1: 1.02942
# [1900]	training's l2: 0.552041	training's l1: 0.431253	valid_1's l2: 2.23539	valid_1's l1: 1.02984
# [2000]	training's l2: 0.538214	training's l1: 0.425098	valid_1's l2: 2.23539	valid_1's l1: 1.02953
# Early stopping, best iteration is:
# [1819]	training's l2: 0.564503	training's l1: 0.436738	valid_1's l2: 2.23189	valid_1's l1: 1.02912
# 1.9191896203225614
# fold: 2
# Training until validation scores don't improve for 200 rounds.
# [100]	training's l2: 41.3996	training's l1: 4.90949	valid_1's l2: 33.3091	valid_1's l1: 4.17728
# [200]	training's l2: 17.3387	training's l1: 3.21483	valid_1's l2: 15.2854	valid_1's l1: 2.89196
# [300]	training's l2: 7.9842	training's l1: 2.19606	valid_1's l2: 8.14205	valid_1's l1: 2.14715
# [400]	training's l2: 4.24642	training's l1: 1.58534	valid_1's l2: 5.26311	valid_1's l1: 1.73342
# [500]	training's l2: 2.6534	training's l1: 1.21942	valid_1's l2: 4.05072	valid_1's l1: 1.50797
# [600]	training's l2: 1.91708	training's l1: 1.00079	valid_1's l2: 3.50986	valid_1's l1: 1.38342
# [700]	training's l2: 1.5503	training's l1: 0.87149	valid_1's l2: 3.2707	valid_1's l1: 1.32275
# [800]	training's l2: 1.33407	training's l1: 0.788058	valid_1's l2: 3.15405	valid_1's l1: 1.29244
# [900]	training's l2: 1.19222	training's l1: 0.733073	valid_1's l2: 3.09523	valid_1's l1: 1.2751
# [1000]	training's l2: 1.09571	training's l1: 0.695272	valid_1's l2: 3.06023	valid_1's l1: 1.26361
# [1100]	training's l2: 1.03025	training's l1: 0.670901	valid_1's l2: 3.06146	valid_1's l1: 1.25982
# [1200]	training's l2: 0.98707	training's l1: 0.655758	valid_1's l2: 3.06403	valid_1's l1: 1.25703
# Early stopping, best iteration is:
# [1045]	training's l2: 1.0625	training's l1: 0.682866	valid_1's l2: 3.05637	valid_1's l1: 1.2611
# Training until validation scores don't improve for 200 rounds.
# [100]	training's l2: 48.6646	training's l1: 5.44333	valid_1's l2: 59.6692	valid_1's l1: 6.26036
# [200]	training's l2: 19.2958	training's l1: 3.43092	valid_1's l2: 25.2842	valid_1's l1: 4.00661
# [300]	training's l2: 8.1197	training's l1: 2.2124	valid_1's l2: 12.283	valid_1's l1: 2.66119
# [400]	training's l2: 3.81807	training's l1: 1.49258	valid_1's l2: 7.33639	valid_1's l1: 1.88544
# [500]	training's l2: 2.09975	training's l1: 1.07256	valid_1's l2: 5.36706	valid_1's l1: 1.46986
# [600]	training's l2: 1.37604	training's l1: 0.830363	valid_1's l2: 4.52902	valid_1's l1: 1.25697
# [700]	training's l2: 1.0405	training's l1: 0.687303	valid_1's l2: 4.16983	valid_1's l1: 1.15705
# [800]	training's l2: 0.861963	training's l1: 0.598985	valid_1's l2: 3.97648	valid_1's l1: 1.10576
# [900]	training's l2: 0.753791	training's l1: 0.542755	valid_1's l2: 3.8646	valid_1's l1: 1.08228
# [1000]	training's l2: 0.680447	training's l1: 0.5053	valid_1's l2: 3.81769	valid_1's l1: 1.07278
# [1100]	training's l2: 0.629715	training's l1: 0.481732	valid_1's l2: 3.75983	valid_1's l1: 1.06768
# [1200]	training's l2: 0.596614	training's l1: 0.467235	valid_1's l2: 3.7189	valid_1's l1: 1.06525
# [1300]	training's l2: 0.56981	training's l1: 0.455285	valid_1's l2: 3.70801	valid_1's l1: 1.06475
# [1400]	training's l2: 0.545645	training's l1: 0.444521	valid_1's l2: 3.69207	valid_1's l1: 1.06346
# [1500]	training's l2: 0.524764	training's l1: 0.43519	valid_1's l2: 3.67075	valid_1's l1: 1.06272
# [1600]	training's l2: 0.507006	training's l1: 0.427068	valid_1's l2: 3.66397	valid_1's l1: 1.06203
# [1700]	training's l2: 0.490232	training's l1: 0.419485	valid_1's l2: 3.64991	valid_1's l1: 1.06129
# [1800]	training's l2: 0.475181	training's l1: 0.412336	valid_1's l2: 3.63651	valid_1's l1: 1.06069
# [1900]	training's l2: 0.460066	training's l1: 0.404523	valid_1's l2: 3.63333	valid_1's l1: 1.06015
# [2000]	training's l2: 0.445162	training's l1: 0.39732	valid_1's l2: 3.62358	valid_1's l1: 1.05991
# [2100]	training's l2: 0.433746	training's l1: 0.391633	valid_1's l2: 3.60676	valid_1's l1: 1.0598
# [2200]	training's l2: 0.422023	training's l1: 0.385502	valid_1's l2: 3.59834	valid_1's l1: 1.05993
# [2300]	training's l2: 0.409335	training's l1: 0.378317	valid_1's l2: 3.59738	valid_1's l1: 1.05993
# [2400]	training's l2: 0.398822	training's l1: 0.372631	valid_1's l2: 3.58757	valid_1's l1: 1.06004
# Early stopping, best iteration is:
# [2236]	training's l2: 0.417888	training's l1: 0.38311	valid_1's l2: 3.59885	valid_1's l1: 1.05956
# 1.8907256108894293
# fold: 3
# Training until validation scores don't improve for 200 rounds.
# [100]	training's l2: 39.4228	training's l1: 4.71012	valid_1's l2: 43.6958	valid_1's l1: 5.039
# [200]	training's l2: 16.6417	training's l1: 3.11002	valid_1's l2: 19.0767	valid_1's l1: 3.3667
# [300]	training's l2: 7.74173	training's l1: 2.13673	valid_1's l2: 9.51192	valid_1's l1: 2.38657
# [400]	training's l2: 4.15962	training's l1: 1.55188	valid_1's l2: 5.71371	valid_1's l1: 1.83076
# [500]	training's l2: 2.64685	training's l1: 1.20461	valid_1's l2: 4.17846	valid_1's l1: 1.54066
# [600]	training's l2: 1.94262	training's l1: 0.996535	valid_1's l2: 3.52564	valid_1's l1: 1.39517
# [700]	training's l2: 1.58246	training's l1: 0.870217	valid_1's l2: 3.23308	valid_1's l1: 1.32085
# [800]	training's l2: 1.37496	training's l1: 0.792245	valid_1's l2: 3.0998	valid_1's l1: 1.28705
# [900]	training's l2: 1.23925	training's l1: 0.741914	valid_1's l2: 3.03114	valid_1's l1: 1.26999
# [1000]	training's l2: 1.14562	training's l1: 0.706371	valid_1's l2: 2.99547	valid_1's l1: 1.2605
# [1100]	training's l2: 1.08057	training's l1: 0.682139	valid_1's l2: 2.97571	valid_1's l1: 1.25547
# [1200]	training's l2: 1.02747	training's l1: 0.662226	valid_1's l2: 2.96449	valid_1's l1: 1.25197
# [1300]	training's l2: 0.987342	training's l1: 0.646448	valid_1's l2: 2.95584	valid_1's l1: 1.24926
# [1400]	training's l2: 0.952546	training's l1: 0.633389	valid_1's l2: 2.94956	valid_1's l1: 1.2471
# [1500]	training's l2: 0.921205	training's l1: 0.62185	valid_1's l2: 2.94948	valid_1's l1: 1.247
# [1600]	training's l2: 0.893859	training's l1: 0.611207	valid_1's l2: 2.95126	valid_1's l1: 1.24633
# Early stopping, best iteration is:
# [1454]	training's l2: 0.935165	training's l1: 0.626917	valid_1's l2: 2.94891	valid_1's l1: 1.24704
# Training until validation scores don't improve for 200 rounds.
# [100]	training's l2: 50.2809	training's l1: 5.52434	valid_1's l2: 50.7198	valid_1's l1: 5.61443
# [200]	training's l2: 19.937	training's l1: 3.48018	valid_1's l2: 20.8473	valid_1's l1: 3.59198
# [300]	training's l2: 8.40399	training's l1: 2.24922	valid_1's l2: 9.58912	valid_1's l1: 2.39581
# [400]	training's l2: 3.9626	training's l1: 1.51871	valid_1's l2: 5.32123	valid_1's l1: 1.72003
# [500]	training's l2: 2.18451	training's l1: 1.08771	valid_1's l2: 3.65934	valid_1's l1: 1.36079
# [600]	training's l2: 1.43654	training's l1: 0.838788	valid_1's l2: 3.00741	valid_1's l1: 1.17981
# [700]	training's l2: 1.08895	training's l1: 0.694444	valid_1's l2: 2.735	valid_1's l1: 1.08577
# [800]	training's l2: 0.907318	training's l1: 0.606727	valid_1's l2: 2.61813	valid_1's l1: 1.04184
# [900]	training's l2: 0.797205	training's l1: 0.552445	valid_1's l2: 2.56252	valid_1's l1: 1.01891
# [1000]	training's l2: 0.72477	training's l1: 0.516953	valid_1's l2: 2.53357	valid_1's l1: 1.00739
# [1100]	training's l2: 0.677523	training's l1: 0.494427	valid_1's l2: 2.5181	valid_1's l1: 1.0016
# [1200]	training's l2: 0.641389	training's l1: 0.47847	valid_1's l2: 2.50959	valid_1's l1: 0.998099
# [1300]	training's l2: 0.615592	training's l1: 0.466594	valid_1's l2: 2.5028	valid_1's l1: 0.995813
# [1400]	training's l2: 0.594282	training's l1: 0.457074	valid_1's l2: 2.49755	valid_1's l1: 0.994641
# [1500]	training's l2: 0.575138	training's l1: 0.448578	valid_1's l2: 2.49272	valid_1's l1: 0.993493
# [1600]	training's l2: 0.559314	training's l1: 0.44114	valid_1's l2: 2.4908	valid_1's l1: 0.992896
# [1700]	training's l2: 0.543576	training's l1: 0.433463	valid_1's l2: 2.48856	valid_1's l1: 0.992092
# [1800]	training's l2: 0.527795	training's l1: 0.426001	valid_1's l2: 2.48685	valid_1's l1: 0.991815
# [1900]	training's l2: 0.513323	training's l1: 0.419034	valid_1's l2: 2.48569	valid_1's l1: 0.991692
# [2000]	training's l2: 0.498446	training's l1: 0.411486	valid_1's l2: 2.48244	valid_1's l1: 0.99069
# [2100]	training's l2: 0.486037	training's l1: 0.404925	valid_1's l2: 2.48165	valid_1's l1: 0.990572
# [2200]	training's l2: 0.472546	training's l1: 0.397607	valid_1's l2: 2.47979	valid_1's l1: 0.990271
# [2300]	training's l2: 0.462587	training's l1: 0.391861	valid_1's l2: 2.47888	valid_1's l1: 0.989796
# [2400]	training's l2: 0.452189	training's l1: 0.386383	valid_1's l2: 2.47812	valid_1's l1: 0.989595
# [2500]	training's l2: 0.441747	training's l1: 0.379971	valid_1's l2: 2.47723	valid_1's l1: 0.98933
# [2600]	training's l2: 0.431561	training's l1: 0.373895	valid_1's l2: 2.47548	valid_1's l1: 0.989022
# [2700]	training's l2: 0.422181	training's l1: 0.368302	valid_1's l2: 2.4746	valid_1's l1: 0.989011
# [2800]	training's l2: 0.412617	training's l1: 0.362395	valid_1's l2: 2.47397	valid_1's l1: 0.988866
# [2900]	training's l2: 0.403643	training's l1: 0.356939	valid_1's l2: 2.47434	valid_1's l1: 0.98901
# [3000]	training's l2: 0.396013	training's l1: 0.351769	valid_1's l2: 2.47337	valid_1's l1: 0.988381
# [3100]	training's l2: 0.387813	training's l1: 0.346483	valid_1's l2: 2.47381	valid_1's l1: 0.988293
# [3200]	training's l2: 0.380215	training's l1: 0.341356	valid_1's l2: 2.47337	valid_1's l1: 0.98812
# Early stopping, best iteration is:
# [3056]	training's l2: 0.391221	training's l1: 0.348685	valid_1's l2: 2.47242	valid_1's l1: 0.988159
# 1.8272521096554142
# fold: 4
# Training until validation scores don't improve for 200 rounds.
# [100]	training's l2: 39.5679	training's l1: 4.73449	valid_1's l2: 42.4188	valid_1's l1: 4.97419
# [200]	training's l2: 16.5658	training's l1: 3.11786	valid_1's l2: 18.8095	valid_1's l1: 3.31541
# [300]	training's l2: 7.58237	training's l1: 2.13434	valid_1's l2: 9.83671	valid_1's l1: 2.37336
# [400]	training's l2: 3.98281	training's l1: 1.54584	valid_1's l2: 6.41234	valid_1's l1: 1.85602
# [500]	training's l2: 2.45526	training's l1: 1.19187	valid_1's l2: 5.07591	valid_1's l1: 1.57931
# [600]	training's l2: 1.75433	training's l1: 0.97971	valid_1's l2: 4.53265	valid_1's l1: 1.4368
# [700]	training's l2: 1.40147	training's l1: 0.85053	valid_1's l2: 4.30307	valid_1's l1: 1.36439
# [800]	training's l2: 1.20145	training's l1: 0.76977	valid_1's l2: 4.19098	valid_1's l1: 1.3293
# [900]	training's l2: 1.07093	training's l1: 0.715415	valid_1's l2: 4.14071	valid_1's l1: 1.31083
# [1000]	training's l2: 0.983159	training's l1: 0.678736	valid_1's l2: 4.10609	valid_1's l1: 1.29932
# [1100]	training's l2: 0.925698	training's l1: 0.655177	valid_1's l2: 4.09052	valid_1's l1: 1.29324
# [1200]	training's l2: 0.880873	training's l1: 0.636398	valid_1's l2: 4.07643	valid_1's l1: 1.28894
# [1300]	training's l2: 0.843362	training's l1: 0.619823	valid_1's l2: 4.06897	valid_1's l1: 1.2865
# [1400]	training's l2: 0.813168	training's l1: 0.606983	valid_1's l2: 4.05952	valid_1's l1: 1.28444
# [1500]	training's l2: 0.785836	training's l1: 0.594666	valid_1's l2: 4.05201	valid_1's l1: 1.28292
# [1600]	training's l2: 0.761958	training's l1: 0.584353	valid_1's l2: 4.0489	valid_1's l1: 1.28206
# [1700]	training's l2: 0.735593	training's l1: 0.572371	valid_1's l2: 4.04478	valid_1's l1: 1.28076
# [1800]	training's l2: 0.712263	training's l1: 0.561771	valid_1's l2: 4.04075	valid_1's l1: 1.27999
# [1900]	training's l2: 0.692146	training's l1: 0.552133	valid_1's l2: 4.03751	valid_1's l1: 1.27956
# [2000]	training's l2: 0.671081	training's l1: 0.541976	valid_1's l2: 4.03456	valid_1's l1: 1.27899
# [2100]	training's l2: 0.654331	training's l1: 0.533979	valid_1's l2: 4.03266	valid_1's l1: 1.27855
# [2200]	training's l2: 0.635391	training's l1: 0.524307	valid_1's l2: 4.03219	valid_1's l1: 1.27822
# [2300]	training's l2: 0.617899	training's l1: 0.515394	valid_1's l2: 4.03057	valid_1's l1: 1.27772
# [2400]	training's l2: 0.599846	training's l1: 0.505965	valid_1's l2: 4.0299	valid_1's l1: 1.27749
# [2500]	training's l2: 0.586452	training's l1: 0.499131	valid_1's l2: 4.02687	valid_1's l1: 1.27725
# [2600]	training's l2: 0.571412	training's l1: 0.491415	valid_1's l2: 4.02699	valid_1's l1: 1.27706
# [2700]	training's l2: 0.556913	training's l1: 0.483691	valid_1's l2: 4.02738	valid_1's l1: 1.27721
# Early stopping, best iteration is:
# [2539]	training's l2: 0.581252	training's l1: 0.496424	valid_1's l2: 4.02668	valid_1's l1: 1.27685
# Training until validation scores don't improve for 200 rounds.
# [100]	training's l2: 50.1672	training's l1: 5.53886	valid_1's l2: 51.2304	valid_1's l1: 5.67908
# [200]	training's l2: 19.9751	training's l1: 3.48662	valid_1's l2: 20.8821	valid_1's l1: 3.62536
# [300]	training's l2: 8.48993	training's l1: 2.25205	valid_1's l2: 9.32226	valid_1's l1: 2.40067
# [400]	training's l2: 4.0376	training's l1: 1.52269	valid_1's l2: 4.87183	valid_1's l1: 1.70196
# [500]	training's l2: 2.26066	training's l1: 1.09584	valid_1's l2: 3.1379	valid_1's l1: 1.31317
# [600]	training's l2: 1.50691	training's l1: 0.849448	valid_1's l2: 2.44507	valid_1's l1: 1.10993
# [700]	training's l2: 1.15464	training's l1: 0.706323	valid_1's l2: 2.15821	valid_1's l1: 1.00748
# [800]	training's l2: 0.965136	training's l1: 0.619148	valid_1's l2: 2.02958	valid_1's l1: 0.952255
# [900]	training's l2: 0.854064	training's l1: 0.566302	valid_1's l2: 1.97267	valid_1's l1: 0.924153
# [1000]	training's l2: 0.780366	training's l1: 0.532818	valid_1's l2: 1.9446	valid_1's l1: 0.908934
# [1100]	training's l2: 0.727696	training's l1: 0.509598	valid_1's l2: 1.93038	valid_1's l1: 0.901183
# [1200]	training's l2: 0.690356	training's l1: 0.493996	valid_1's l2: 1.92355	valid_1's l1: 0.897618
# [1300]	training's l2: 0.663623	training's l1: 0.483401	valid_1's l2: 1.91922	valid_1's l1: 0.896072
# [1400]	training's l2: 0.640564	training's l1: 0.474295	valid_1's l2: 1.91831	valid_1's l1: 0.89553
# [1500]	training's l2: 0.618287	training's l1: 0.464883	valid_1's l2: 1.91817	valid_1's l1: 0.895147
# Early stopping, best iteration is:
# [1356]	training's l2: 0.649851	training's l1: 0.477959	valid_1's l2: 1.91696	valid_1's l1: 0.895377
# 1.7981609732435042
# mean validation error, 5-fold 1.8877751137348302
# we have  423  unique paths
# fold: 0
# Training until validation scores don't improve for 200 rounds.
# [100]	training's l2: 36.9147	training's l1: 4.63066	valid_1's l2: 42.0572	valid_1's l1: 4.93305
# [200]	training's l2: 15.8905	training's l1: 3.10039	valid_1's l2: 18.7836	valid_1's l1: 3.365
# [300]	training's l2: 7.65374	training's l1: 2.16626	valid_1's l2: 9.70347	valid_1's l1: 2.45834
# [400]	training's l2: 4.30301	training's l1: 1.61259	valid_1's l2: 6.11756	valid_1's l1: 1.943
# [500]	training's l2: 2.8403	training's l1: 1.27885	valid_1's l2: 4.66834	valid_1's l1: 1.6546
# [600]	training's l2: 2.13368	training's l1: 1.07225	valid_1's l2: 4.05274	valid_1's l1: 1.50353
# [700]	training's l2: 1.76052	training's l1: 0.941547	valid_1's l2: 3.77903	valid_1's l1: 1.41767
# [800]	training's l2: 1.5381	training's l1: 0.854349	valid_1's l2: 3.65171	valid_1's l1: 1.37394
# [900]	training's l2: 1.38787	training's l1: 0.795438	valid_1's l2: 3.58129	valid_1's l1: 1.3515
# [1000]	training's l2: 1.2832	training's l1: 0.755019	valid_1's l2: 3.54492	valid_1's l1: 1.3389
# [1100]	training's l2: 1.21181	training's l1: 0.728637	valid_1's l2: 3.52794	valid_1's l1: 1.33357
# [1200]	training's l2: 1.1605	training's l1: 0.710007	valid_1's l2: 3.51526	valid_1's l1: 1.32934
# [1300]	training's l2: 1.11915	training's l1: 0.695523	valid_1's l2: 3.51475	valid_1's l1: 1.32887
# [1400]	training's l2: 1.08331	training's l1: 0.681847	valid_1's l2: 3.51088	valid_1's l1: 1.32776
# [1500]	training's l2: 1.05053	training's l1: 0.669469	valid_1's l2: 3.50629	valid_1's l1: 1.3263
# [1600]	training's l2: 1.02188	training's l1: 0.659088	valid_1's l2: 3.50579	valid_1's l1: 1.32597
# [1700]	training's l2: 0.99625	training's l1: 0.649308	valid_1's l2: 3.50546	valid_1's l1: 1.3256
# [1800]	training's l2: 0.973771	training's l1: 0.641261	valid_1's l2: 3.50606	valid_1's l1: 1.32491
# Early stopping, best iteration is:
# [1620]	training's l2: 1.0157	training's l1: 0.656612	valid_1's l2: 3.50414	valid_1's l1: 1.32574
# Training until validation scores don't improve for 200 rounds.
# [100]	training's l2: 51.2788	training's l1: 5.61287	valid_1's l2: 48.6183	valid_1's l1: 5.25056
# [200]	training's l2: 20.2289	training's l1: 3.50997	valid_1's l2: 20.29	valid_1's l1: 3.37531
# [300]	training's l2: 8.44675	training's l1: 2.25885	valid_1's l2: 9.50617	valid_1's l1: 2.30696
# [400]	training's l2: 3.90069	training's l1: 1.51694	valid_1's l2: 5.39268	valid_1's l1: 1.71231
# [500]	training's l2: 2.10202	training's l1: 1.08055	valid_1's l2: 3.79279	valid_1's l1: 1.38658
# [600]	training's l2: 1.35172	training's l1: 0.82734	valid_1's l2: 3.16556	valid_1's l1: 1.21397
# [700]	training's l2: 1.01493	training's l1: 0.681826	valid_1's l2: 2.9043	valid_1's l1: 1.12152
# [800]	training's l2: 0.838405	training's l1: 0.593469	valid_1's l2: 2.79082	valid_1's l1: 1.0746
# [900]	training's l2: 0.731543	training's l1: 0.537648	valid_1's l2: 2.73851	valid_1's l1: 1.05006
# [1000]	training's l2: 0.66469	training's l1: 0.50383	valid_1's l2: 2.71295	valid_1's l1: 1.03763
# [1100]	training's l2: 0.61974	training's l1: 0.482467	valid_1's l2: 2.70099	valid_1's l1: 1.03199
# [1200]	training's l2: 0.587525	training's l1: 0.468447	valid_1's l2: 2.69436	valid_1's l1: 1.02902
# [1300]	training's l2: 0.564005	training's l1: 0.458088	valid_1's l2: 2.69039	valid_1's l1: 1.02666
# [1400]	training's l2: 0.545305	training's l1: 0.449149	valid_1's l2: 2.68566	valid_1's l1: 1.02396
# [1500]	training's l2: 0.52827	training's l1: 0.441762	valid_1's l2: 2.68253	valid_1's l1: 1.02194
# [1600]	training's l2: 0.513817	training's l1: 0.435945	valid_1's l2: 2.68066	valid_1's l1: 1.02104
# [1700]	training's l2: 0.501114	training's l1: 0.430648	valid_1's l2: 2.68183	valid_1's l1: 1.02081
# [1800]	training's l2: 0.486558	training's l1: 0.423497	valid_1's l2: 2.6808	valid_1's l1: 1.01993
# [1900]	training's l2: 0.475487	training's l1: 0.418411	valid_1's l2: 2.68141	valid_1's l1: 1.02017
# Early stopping, best iteration is:
# [1773]	training's l2: 0.490434	training's l1: 0.425336	valid_1's l2: 2.67955	valid_1's l1: 1.01982
# 1.9253374364631421
# fold: 1
# Training until validation scores don't improve for 200 rounds.
# [100]	training's l2: 37.4151	training's l1: 4.65112	valid_1's l2: 38.319	valid_1's l1: 4.79405
# [200]	training's l2: 15.9496	training's l1: 3.09518	valid_1's l2: 17.5198	valid_1's l1: 3.31114
# [300]	training's l2: 7.56864	training's l1: 2.14942	valid_1's l2: 9.65699	valid_1's l1: 2.45206
# [400]	training's l2: 4.16764	training's l1: 1.58939	valid_1's l2: 6.65601	valid_1's l1: 1.98711
# [500]	training's l2: 2.70642	training's l1: 1.25388	valid_1's l2: 5.48417	valid_1's l1: 1.74624
# [600]	training's l2: 2.01128	training's l1: 1.04589	valid_1's l2: 5.01185	valid_1's l1: 1.61877
# [700]	training's l2: 1.645	training's l1: 0.912958	valid_1's l2: 4.81961	valid_1's l1: 1.55215
# [800]	training's l2: 1.43257	training's l1: 0.825393	valid_1's l2: 4.72939	valid_1's l1: 1.51635
# [900]	training's l2: 1.29238	training's l1: 0.766729	valid_1's l2: 4.6858	valid_1's l1: 1.4968
# [1000]	training's l2: 1.18935	training's l1: 0.725102	valid_1's l2: 4.65669	valid_1's l1: 1.4863
# [1100]	training's l2: 1.11655	training's l1: 0.696072	valid_1's l2: 4.63831	valid_1's l1: 1.47964
# [1200]	training's l2: 1.06868	training's l1: 0.677207	valid_1's l2: 4.62473	valid_1's l1: 1.477
# [1300]	training's l2: 1.03102	training's l1: 0.663341	valid_1's l2: 4.61341	valid_1's l1: 1.4738
# [1400]	training's l2: 0.993441	training's l1: 0.649249	valid_1's l2: 4.60234	valid_1's l1: 1.47185
# [1500]	training's l2: 0.96356	training's l1: 0.637956	valid_1's l2: 4.59487	valid_1's l1: 1.46966
# [1600]	training's l2: 0.934851	training's l1: 0.626747	valid_1's l2: 4.58502	valid_1's l1: 1.46756
# [1700]	training's l2: 0.907973	training's l1: 0.61602	valid_1's l2: 4.57822	valid_1's l1: 1.46684
# [1800]	training's l2: 0.883485	training's l1: 0.606508	valid_1's l2: 4.57237	valid_1's l1: 1.46544
# [1900]	training's l2: 0.857742	training's l1: 0.596469	valid_1's l2: 4.56941	valid_1's l1: 1.46453
# [2000]	training's l2: 0.83457	training's l1: 0.587362	valid_1's l2: 4.56285	valid_1's l1: 1.46301
# [2100]	training's l2: 0.815585	training's l1: 0.579849	valid_1's l2: 4.55647	valid_1's l1: 1.46234
# [2200]	training's l2: 0.795077	training's l1: 0.571819	valid_1's l2: 4.55046	valid_1's l1: 1.46145
# [2300]	training's l2: 0.777158	training's l1: 0.564349	valid_1's l2: 4.54844	valid_1's l1: 1.4608
# [2400]	training's l2: 0.756781	training's l1: 0.555336	valid_1's l2: 4.54308	valid_1's l1: 1.45993
# [2500]	training's l2: 0.738838	training's l1: 0.547528	valid_1's l2: 4.53833	valid_1's l1: 1.45889
# [2600]	training's l2: 0.722964	training's l1: 0.54075	valid_1's l2: 4.53631	valid_1's l1: 1.4582
# [2700]	training's l2: 0.707476	training's l1: 0.533976	valid_1's l2: 4.53084	valid_1's l1: 1.45744
# [2800]	training's l2: 0.691707	training's l1: 0.527346	valid_1's l2: 4.52713	valid_1's l1: 1.45695
# [2900]	training's l2: 0.676398	training's l1: 0.520272	valid_1's l2: 4.52205	valid_1's l1: 1.45588
# [3000]	training's l2: 0.660361	training's l1: 0.512906	valid_1's l2: 4.51693	valid_1's l1: 1.45503
# [3100]	training's l2: 0.645255	training's l1: 0.505773	valid_1's l2: 4.51406	valid_1's l1: 1.45446
# [3200]	training's l2: 0.630207	training's l1: 0.498536	valid_1's l2: 4.51294	valid_1's l1: 1.45414
# [3300]	training's l2: 0.614592	training's l1: 0.490723	valid_1's l2: 4.50859	valid_1's l1: 1.45331
# [3400]	training's l2: 0.600421	training's l1: 0.48372	valid_1's l2: 4.50535	valid_1's l1: 1.45311
# [3500]	training's l2: 0.588401	training's l1: 0.477821	valid_1's l2: 4.50483	valid_1's l1: 1.45299
# [3600]	training's l2: 0.576025	training's l1: 0.471709	valid_1's l2: 4.5025	valid_1's l1: 1.45274
# [3700]	training's l2: 0.564219	training's l1: 0.466021	valid_1's l2: 4.49631	valid_1's l1: 1.45198
# [3800]	training's l2: 0.554315	training's l1: 0.461119	valid_1's l2: 4.4961	valid_1's l1: 1.45195
# [3900]	training's l2: 0.543316	training's l1: 0.455464	valid_1's l2: 4.4935	valid_1's l1: 1.45159
# [4000]	training's l2: 0.531761	training's l1: 0.449434	valid_1's l2: 4.49182	valid_1's l1: 1.45148
# [4100]	training's l2: 0.521261	training's l1: 0.443774	valid_1's l2: 4.48889	valid_1's l1: 1.45113
# [4200]	training's l2: 0.511182	training's l1: 0.438421	valid_1's l2: 4.48978	valid_1's l1: 1.45109
# [4300]	training's l2: 0.501128	training's l1: 0.433189	valid_1's l2: 4.48724	valid_1's l1: 1.4508
# [4400]	training's l2: 0.491071	training's l1: 0.427843	valid_1's l2: 4.48751	valid_1's l1: 1.45078
# Early stopping, best iteration is:
# [4270]	training's l2: 0.504539	training's l1: 0.4352	valid_1's l2: 4.48589	valid_1's l1: 1.45049
# Training until validation scores don't improve for 200 rounds.
# [100]	training's l2: 50.9185	training's l1: 5.4847	valid_1's l2: 50.8396	valid_1's l1: 5.51933
# [200]	training's l2: 20.1017	training's l1: 3.46053	valid_1's l2: 21.0905	valid_1's l1: 3.55757
# [300]	training's l2: 8.38702	training's l1: 2.24468	valid_1's l2: 9.88026	valid_1's l1: 2.41235
# [400]	training's l2: 3.86322	training's l1: 1.51581	valid_1's l2: 5.65181	valid_1's l1: 1.76961
# [500]	training's l2: 2.07207	training's l1: 1.08236	valid_1's l2: 4.04583	valid_1's l1: 1.41774
# [600]	training's l2: 1.31569	training's l1: 0.826468	valid_1's l2: 3.41302	valid_1's l1: 1.23021
# [700]	training's l2: 0.969794	training's l1: 0.676598	valid_1's l2: 3.15833	valid_1's l1: 1.13623
# [800]	training's l2: 0.790266	training's l1: 0.586496	valid_1's l2: 3.05216	valid_1's l1: 1.08762
# [900]	training's l2: 0.685538	training's l1: 0.52999	valid_1's l2: 3.00782	valid_1's l1: 1.06114
# [1000]	training's l2: 0.618981	training's l1: 0.495488	valid_1's l2: 2.98378	valid_1's l1: 1.04756
# [1100]	training's l2: 0.571046	training's l1: 0.471362	valid_1's l2: 2.97125	valid_1's l1: 1.04112
# [1200]	training's l2: 0.536272	training's l1: 0.455139	valid_1's l2: 2.96914	valid_1's l1: 1.03801
# [1300]	training's l2: 0.512353	training's l1: 0.443589	valid_1's l2: 2.9657	valid_1's l1: 1.03612
# [1400]	training's l2: 0.495	training's l1: 0.436186	valid_1's l2: 2.96301	valid_1's l1: 1.03502
# [1500]	training's l2: 0.478106	training's l1: 0.42864	valid_1's l2: 2.96206	valid_1's l1: 1.03454
# [1600]	training's l2: 0.462653	training's l1: 0.421367	valid_1's l2: 2.96175	valid_1's l1: 1.03407
# [1700]	training's l2: 0.446366	training's l1: 0.413105	valid_1's l2: 2.96115	valid_1's l1: 1.03356
# Early stopping, best iteration is:
# [1542]	training's l2: 0.471336	training's l1: 0.425277	valid_1's l2: 2.96035	valid_1's l1: 1.03417
# 2.0499091006159578
# fold: 2
# Training until validation scores don't improve for 200 rounds.
# [100]	training's l2: 38.2209	training's l1: 4.71769	valid_1's l2: 36.0847	valid_1's l1: 4.49403
# [200]	training's l2: 16.3102	training's l1: 3.13632	valid_1's l2: 16.7839	valid_1's l1: 3.09911
# [300]	training's l2: 7.76488	training's l1: 2.18131	valid_1's l2: 9.20029	valid_1's l1: 2.2984
# [400]	training's l2: 4.30153	training's l1: 1.61562	valid_1's l2: 6.09786	valid_1's l1: 1.86102
# [500]	training's l2: 2.81256	training's l1: 1.27734	valid_1's l2: 4.77928	valid_1's l1: 1.6244
# [600]	training's l2: 2.10087	training's l1: 1.06786	valid_1's l2: 4.1778	valid_1's l1: 1.49886
# [700]	training's l2: 1.72813	training's l1: 0.935293	valid_1's l2: 3.8968	valid_1's l1: 1.43069
# [800]	training's l2: 1.4981	training's l1: 0.846022	valid_1's l2: 3.73733	valid_1's l1: 1.39364
# [900]	training's l2: 1.34646	training's l1: 0.7859	valid_1's l2: 3.64865	valid_1's l1: 1.3713
# [1000]	training's l2: 1.24213	training's l1: 0.745483	valid_1's l2: 3.59717	valid_1's l1: 1.35928
# [1100]	training's l2: 1.16987	training's l1: 0.718275	valid_1's l2: 3.56871	valid_1's l1: 1.35331
# [1200]	training's l2: 1.1137	training's l1: 0.697708	valid_1's l2: 3.54972	valid_1's l1: 1.34847
# [1300]	training's l2: 1.07293	training's l1: 0.683097	valid_1's l2: 3.53773	valid_1's l1: 1.34609
# [1400]	training's l2: 1.03411	training's l1: 0.668887	valid_1's l2: 3.53062	valid_1's l1: 1.34525
# [1500]	training's l2: 0.99941	training's l1: 0.656577	valid_1's l2: 3.52829	valid_1's l1: 1.34472
# [1600]	training's l2: 0.968481	training's l1: 0.644767	valid_1's l2: 3.52554	valid_1's l1: 1.34383
# [1700]	training's l2: 0.937595	training's l1: 0.633328	valid_1's l2: 3.52599	valid_1's l1: 1.3435
# [1800]	training's l2: 0.910507	training's l1: 0.622822	valid_1's l2: 3.52699	valid_1's l1: 1.34369
# [1900]	training's l2: 0.886822	training's l1: 0.613682	valid_1's l2: 3.5321	valid_1's l1: 1.34461
# Early stopping, best iteration is:
# [1742]	training's l2: 0.926294	training's l1: 0.629015	valid_1's l2: 3.52421	valid_1's l1: 1.34317
# Training until validation scores don't improve for 200 rounds.
# [100]	training's l2: 49.4507	training's l1: 5.48324	valid_1's l2: 56.5689	valid_1's l1: 5.99334
# [200]	training's l2: 19.5359	training's l1: 3.43007	valid_1's l2: 23.2061	valid_1's l1: 3.80786
# [300]	training's l2: 8.19284	training's l1: 2.21399	valid_1's l2: 10.6451	valid_1's l1: 2.53745
# [400]	training's l2: 3.81864	training's l1: 1.49799	valid_1's l2: 5.8664	valid_1's l1: 1.81189
# [500]	training's l2: 2.08297	training's l1: 1.07787	valid_1's l2: 4.01781	valid_1's l1: 1.41988
# [600]	training's l2: 1.35303	training's l1: 0.833292	valid_1's l2: 3.26884	valid_1's l1: 1.22018
# [700]	training's l2: 1.01664	training's l1: 0.688172	valid_1's l2: 2.95798	valid_1's l1: 1.11924
# [800]	training's l2: 0.837654	training's l1: 0.599183	valid_1's l2: 2.80724	valid_1's l1: 1.06537
# [900]	training's l2: 0.73131	training's l1: 0.542607	valid_1's l2: 2.73202	valid_1's l1: 1.03851
# [1000]	training's l2: 0.661664	training's l1: 0.505841	valid_1's l2: 2.6862	valid_1's l1: 1.02543
# [1100]	training's l2: 0.61392	training's l1: 0.482964	valid_1's l2: 2.65439	valid_1's l1: 1.01958
# [1200]	training's l2: 0.578379	training's l1: 0.466419	valid_1's l2: 2.63816	valid_1's l1: 1.01704
# [1300]	training's l2: 0.555405	training's l1: 0.456422	valid_1's l2: 2.62502	valid_1's l1: 1.01691
# [1400]	training's l2: 0.535284	training's l1: 0.447613	valid_1's l2: 2.6126	valid_1's l1: 1.01621
# [1500]	training's l2: 0.519289	training's l1: 0.440475	valid_1's l2: 2.6033	valid_1's l1: 1.01544
# [1600]	training's l2: 0.501858	training's l1: 0.432627	valid_1's l2: 2.59544	valid_1's l1: 1.01484
# [1700]	training's l2: 0.48551	training's l1: 0.424745	valid_1's l2: 2.58775	valid_1's l1: 1.01395
# [1800]	training's l2: 0.471539	training's l1: 0.417999	valid_1's l2: 2.5782	valid_1's l1: 1.0129
# [1900]	training's l2: 0.459227	training's l1: 0.412401	valid_1's l2: 2.56852	valid_1's l1: 1.01243
# [2000]	training's l2: 0.44454	training's l1: 0.404646	valid_1's l2: 2.55954	valid_1's l1: 1.01111
# [2100]	training's l2: 0.432881	training's l1: 0.398622	valid_1's l2: 2.55182	valid_1's l1: 1.01026
# [2200]	training's l2: 0.421118	training's l1: 0.39246	valid_1's l2: 2.54451	valid_1's l1: 1.0094
# [2300]	training's l2: 0.410955	training's l1: 0.386918	valid_1's l2: 2.54228	valid_1's l1: 1.00979
# [2400]	training's l2: 0.400758	training's l1: 0.381384	valid_1's l2: 2.53561	valid_1's l1: 1.00925
# [2500]	training's l2: 0.390153	training's l1: 0.375346	valid_1's l2: 2.52819	valid_1's l1: 1.00835
# [2600]	training's l2: 0.380267	training's l1: 0.369693	valid_1's l2: 2.52191	valid_1's l1: 1.00804
# [2700]	training's l2: 0.370376	training's l1: 0.363833	valid_1's l2: 2.5156	valid_1's l1: 1.00769
# [2800]	training's l2: 0.361223	training's l1: 0.358226	valid_1's l2: 2.50888	valid_1's l1: 1.0073
# [2900]	training's l2: 0.352214	training's l1: 0.352571	valid_1's l2: 2.50286	valid_1's l1: 1.00643
# [3000]	training's l2: 0.343576	training's l1: 0.347187	valid_1's l2: 2.4968	valid_1's l1: 1.00626
# [3100]	training's l2: 0.335507	training's l1: 0.341803	valid_1's l2: 2.49312	valid_1's l1: 1.00601
# [3200]	training's l2: 0.327334	training's l1: 0.336052	valid_1's l2: 2.48668	valid_1's l1: 1.00485
# [3300]	training's l2: 0.320512	training's l1: 0.331597	valid_1's l2: 2.48152	valid_1's l1: 1.00398
# [3400]	training's l2: 0.313226	training's l1: 0.326236	valid_1's l2: 2.4779	valid_1's l1: 1.00369
# [3500]	training's l2: 0.305607	training's l1: 0.320722	valid_1's l2: 2.47069	valid_1's l1: 1.0027
# [3600]	training's l2: 0.298926	training's l1: 0.315785	valid_1's l2: 2.4667	valid_1's l1: 1.00248
# [3700]	training's l2: 0.292754	training's l1: 0.311272	valid_1's l2: 2.46134	valid_1's l1: 1.00208
# [3800]	training's l2: 0.286575	training's l1: 0.306688	valid_1's l2: 2.45411	valid_1's l1: 1.00144
# [3900]	training's l2: 0.280674	training's l1: 0.302131	valid_1's l2: 2.4474	valid_1's l1: 1.00014
# [4000]	training's l2: 0.275478	training's l1: 0.29803	valid_1's l2: 2.44419	valid_1's l1: 1.00003
# [4100]	training's l2: 0.270377	training's l1: 0.294033	valid_1's l2: 2.43963	valid_1's l1: 0.999879
# [4200]	training's l2: 0.26543	training's l1: 0.289803	valid_1's l2: 2.43459	valid_1's l1: 0.999376
# [4300]	training's l2: 0.261094	training's l1: 0.286286	valid_1's l2: 2.42983	valid_1's l1: 0.998885
# [4400]	training's l2: 0.256857	training's l1: 0.282688	valid_1's l2: 2.42451	valid_1's l1: 0.998267
# [4500]	training's l2: 0.253104	training's l1: 0.279374	valid_1's l2: 2.42116	valid_1's l1: 0.998176
# [4600]	training's l2: 0.249236	training's l1: 0.275978	valid_1's l2: 2.41601	valid_1's l1: 0.997421
# [4700]	training's l2: 0.245642	training's l1: 0.272604	valid_1's l2: 2.41111	valid_1's l1: 0.996648
# [4800]	training's l2: 0.24221	training's l1: 0.269352	valid_1's l2: 2.40689	valid_1's l1: 0.995959
# [4900]	training's l2: 0.238365	training's l1: 0.265605	valid_1's l2: 2.40302	valid_1's l1: 0.995765
# [5000]	training's l2: 0.235091	training's l1: 0.262463	valid_1's l2: 2.40096	valid_1's l1: 0.99616
# Early stopping, best iteration is:
# [4840]	training's l2: 0.240617	training's l1: 0.267757	valid_1's l2: 2.40502	valid_1's l1: 0.995612
# 1.89997409720585
# fold: 3
# Training until validation scores don't improve for 200 rounds.
# [100]	training's l2: 37.0867	training's l1: 4.63803	valid_1's l2: 40.3931	valid_1's l1: 4.89622
# [200]	training's l2: 15.9738	training's l1: 3.10413	valid_1's l2: 17.6666	valid_1's l1: 3.27733
# [300]	training's l2: 7.70711	training's l1: 2.16925	valid_1's l2: 9.00396	valid_1's l1: 2.35582
# [400]	training's l2: 4.3276	training's l1: 1.61251	valid_1's l2: 5.6356	valid_1's l1: 1.85898
# [500]	training's l2: 2.86946	training's l1: 1.27997	valid_1's l2: 4.30833	valid_1's l1: 1.5912
# [600]	training's l2: 2.17398	training's l1: 1.07778	valid_1's l2: 3.76435	valid_1's l1: 1.44555
# [700]	training's l2: 1.79933	training's l1: 0.948003	valid_1's l2: 3.52567	valid_1's l1: 1.36776
# [800]	training's l2: 1.56705	training's l1: 0.858393	valid_1's l2: 3.41275	valid_1's l1: 1.32654
# [900]	training's l2: 1.41776	training's l1: 0.799361	valid_1's l2: 3.35376	valid_1's l1: 1.30387
# [1000]	training's l2: 1.31062	training's l1: 0.75817	valid_1's l2: 3.32195	valid_1's l1: 1.29212
# [1100]	training's l2: 1.23382	training's l1: 0.72914	valid_1's l2: 3.30769	valid_1's l1: 1.28656
# [1200]	training's l2: 1.1803	training's l1: 0.709067	valid_1's l2: 3.29454	valid_1's l1: 1.28289
# [1300]	training's l2: 1.1368	training's l1: 0.69248	valid_1's l2: 3.28603	valid_1's l1: 1.28103
# [1400]	training's l2: 1.09474	training's l1: 0.676721	valid_1's l2: 3.27645	valid_1's l1: 1.27765
# [1500]	training's l2: 1.06307	training's l1: 0.665253	valid_1's l2: 3.26832	valid_1's l1: 1.27594
# [1600]	training's l2: 1.0302	training's l1: 0.652804	valid_1's l2: 3.26114	valid_1's l1: 1.27384
# [1700]	training's l2: 0.99896	training's l1: 0.640877	valid_1's l2: 3.25431	valid_1's l1: 1.27236
# [1800]	training's l2: 0.972243	training's l1: 0.630596	valid_1's l2: 3.24878	valid_1's l1: 1.27057
# [1900]	training's l2: 0.946703	training's l1: 0.620302	valid_1's l2: 3.24435	valid_1's l1: 1.26953
# [2000]	training's l2: 0.922628	training's l1: 0.610836	valid_1's l2: 3.24118	valid_1's l1: 1.26859
# [2100]	training's l2: 0.899947	training's l1: 0.601746	valid_1's l2: 3.23612	valid_1's l1: 1.26764
# [2200]	training's l2: 0.879434	training's l1: 0.593527	valid_1's l2: 3.23184	valid_1's l1: 1.26635
# [2300]	training's l2: 0.859254	training's l1: 0.585025	valid_1's l2: 3.22917	valid_1's l1: 1.26539
# [2400]	training's l2: 0.838842	training's l1: 0.576419	valid_1's l2: 3.2247	valid_1's l1: 1.26447
# [2500]	training's l2: 0.821599	training's l1: 0.569359	valid_1's l2: 3.22033	valid_1's l1: 1.26345
# [2600]	training's l2: 0.803107	training's l1: 0.56185	valid_1's l2: 3.21396	valid_1's l1: 1.26232
# [2700]	training's l2: 0.785401	training's l1: 0.554283	valid_1's l2: 3.21099	valid_1's l1: 1.26178
# [2800]	training's l2: 0.770192	training's l1: 0.547691	valid_1's l2: 3.21071	valid_1's l1: 1.26122
# [2900]	training's l2: 0.75527	training's l1: 0.54083	valid_1's l2: 3.20859	valid_1's l1: 1.26078
# [3000]	training's l2: 0.737966	training's l1: 0.533299	valid_1's l2: 3.20654	valid_1's l1: 1.26046
# [3100]	training's l2: 0.723797	training's l1: 0.526712	valid_1's l2: 3.20631	valid_1's l1: 1.26017
# [3200]	training's l2: 0.709227	training's l1: 0.519989	valid_1's l2: 3.20179	valid_1's l1: 1.25906
# [3300]	training's l2: 0.694257	training's l1: 0.512622	valid_1's l2: 3.20079	valid_1's l1: 1.25868
# [3400]	training's l2: 0.681027	training's l1: 0.506602	valid_1's l2: 3.19833	valid_1's l1: 1.258
# [3500]	training's l2: 0.670749	training's l1: 0.50169	valid_1's l2: 3.19697	valid_1's l1: 1.2576
# [3600]	training's l2: 0.658288	training's l1: 0.495239	valid_1's l2: 3.19396	valid_1's l1: 1.25686
# [3700]	training's l2: 0.645602	training's l1: 0.488959	valid_1's l2: 3.19273	valid_1's l1: 1.25662
# [3800]	training's l2: 0.633112	training's l1: 0.482711	valid_1's l2: 3.19165	valid_1's l1: 1.25627
# [3900]	training's l2: 0.620739	training's l1: 0.476392	valid_1's l2: 3.18838	valid_1's l1: 1.25559
# [4000]	training's l2: 0.609879	training's l1: 0.47072	valid_1's l2: 3.18694	valid_1's l1: 1.25551
# [4100]	training's l2: 0.598908	training's l1: 0.465228	valid_1's l2: 3.18578	valid_1's l1: 1.25539
# [4200]	training's l2: 0.589434	training's l1: 0.46035	valid_1's l2: 3.18494	valid_1's l1: 1.25545
# [4300]	training's l2: 0.579536	training's l1: 0.455146	valid_1's l2: 3.1833	valid_1's l1: 1.25517
# [4400]	training's l2: 0.56985	training's l1: 0.449841	valid_1's l2: 3.18118	valid_1's l1: 1.25469
# [4500]	training's l2: 0.560787	training's l1: 0.44498	valid_1's l2: 3.18045	valid_1's l1: 1.25449
# [4600]	training's l2: 0.551637	training's l1: 0.440111	valid_1's l2: 3.17983	valid_1's l1: 1.25441
# [4700]	training's l2: 0.543953	training's l1: 0.436105	valid_1's l2: 3.17856	valid_1's l1: 1.25409
# [4800]	training's l2: 0.5344	training's l1: 0.430516	valid_1's l2: 3.17772	valid_1's l1: 1.25401
# [4900]	training's l2: 0.524659	training's l1: 0.424833	valid_1's l2: 3.17601	valid_1's l1: 1.25358
# [5000]	training's l2: 0.516818	training's l1: 0.420549	valid_1's l2: 3.17476	valid_1's l1: 1.25328
# [5100]	training's l2: 0.508681	training's l1: 0.415733	valid_1's l2: 3.17288	valid_1's l1: 1.25282
# [5200]	training's l2: 0.500625	training's l1: 0.410715	valid_1's l2: 3.17346	valid_1's l1: 1.25308
# [5300]	training's l2: 0.492039	training's l1: 0.405508	valid_1's l2: 3.17302	valid_1's l1: 1.25297
# Early stopping, best iteration is:
# [5120]	training's l2: 0.506626	training's l1: 0.414333	valid_1's l2: 3.1731	valid_1's l1: 1.2528
# Training until validation scores don't improve for 200 rounds.
# [100]	training's l2: 50.6253	training's l1: 5.53887	valid_1's l2: 52.149	valid_1's l1: 5.65912
# [200]	training's l2: 20.0802	training's l1: 3.47523	valid_1's l2: 21.0764	valid_1's l1: 3.5939
# [300]	training's l2: 8.45534	training's l1: 2.24798	valid_1's l2: 9.30954	valid_1's l1: 2.38201
# [400]	training's l2: 3.96759	training's l1: 1.52254	valid_1's l2: 4.81379	valid_1's l1: 1.69488
# [500]	training's l2: 2.18093	training's l1: 1.09629	valid_1's l2: 3.0645	valid_1's l1: 1.32582
# [600]	training's l2: 1.41839	training's l1: 0.843778	valid_1's l2: 2.36567	valid_1's l1: 1.12828
# [700]	training's l2: 1.06167	training's l1: 0.694848	valid_1's l2: 2.08133	valid_1's l1: 1.02509
# [800]	training's l2: 0.879561	training's l1: 0.608041	valid_1's l2: 1.96532	valid_1's l1: 0.975339
# [900]	training's l2: 0.767673	training's l1: 0.553226	valid_1's l2: 1.91154	valid_1's l1: 0.94891
# [1000]	training's l2: 0.69733	training's l1: 0.519385	valid_1's l2: 1.88589	valid_1's l1: 0.936935
# [1100]	training's l2: 0.649059	training's l1: 0.496747	valid_1's l2: 1.87522	valid_1's l1: 0.931523
# [1200]	training's l2: 0.614681	training's l1: 0.481307	valid_1's l2: 1.87343	valid_1's l1: 0.929718
# [1300]	training's l2: 0.589712	training's l1: 0.470712	valid_1's l2: 1.87516	valid_1's l1: 0.929387
# Early stopping, best iteration is:
# [1151]	training's l2: 0.629	training's l1: 0.487576	valid_1's l2: 1.8727	valid_1's l1: 0.930126
# 1.7911918885964826
# fold: 4
# Training until validation scores don't improve for 200 rounds.
# [100]	training's l2: 37.8777	training's l1: 4.68563	valid_1's l2: 37.0824	valid_1's l1: 4.6085
# [200]	training's l2: 16.1534	training's l1: 3.11575	valid_1's l2: 17.1835	valid_1's l1: 3.18728
# [300]	training's l2: 7.66311	training's l1: 2.16216	valid_1's l2: 9.51334	valid_1's l1: 2.37588
# [400]	training's l2: 4.21753	training's l1: 1.59537	valid_1's l2: 6.48031	valid_1's l1: 1.93293
# [500]	training's l2: 2.7388	training's l1: 1.26001	valid_1's l2: 5.24123	valid_1's l1: 1.69227
# [600]	training's l2: 2.03256	training's l1: 1.05117	valid_1's l2: 4.71139	valid_1's l1: 1.56143
# [700]	training's l2: 1.65696	training's l1: 0.918179	valid_1's l2: 4.47734	valid_1's l1: 1.49172
# [800]	training's l2: 1.44044	training's l1: 0.831485	valid_1's l2: 4.34549	valid_1's l1: 1.44751
# [900]	training's l2: 1.29808	training's l1: 0.774815	valid_1's l2: 4.27324	valid_1's l1: 1.42445
# [1000]	training's l2: 1.19349	training's l1: 0.734411	valid_1's l2: 4.22682	valid_1's l1: 1.41091
# [1100]	training's l2: 1.12011	training's l1: 0.706681	valid_1's l2: 4.19286	valid_1's l1: 1.4018
# [1200]	training's l2: 1.06905	training's l1: 0.687043	valid_1's l2: 4.16624	valid_1's l1: 1.39456
# [1300]	training's l2: 1.03195	training's l1: 0.673013	valid_1's l2: 4.15226	valid_1's l1: 1.39047
# [1400]	training's l2: 0.997131	training's l1: 0.659749	valid_1's l2: 4.14113	valid_1's l1: 1.3872
# [1500]	training's l2: 0.96476	training's l1: 0.646979	valid_1's l2: 4.13146	valid_1's l1: 1.3846
# [1600]	training's l2: 0.934273	training's l1: 0.63536	valid_1's l2: 4.12424	valid_1's l1: 1.38302
# [1700]	training's l2: 0.907041	training's l1: 0.624693	valid_1's l2: 4.11858	valid_1's l1: 1.38159
# [1800]	training's l2: 0.882609	training's l1: 0.614808	valid_1's l2: 4.11321	valid_1's l1: 1.3801
# [1900]	training's l2: 0.859168	training's l1: 0.605324	valid_1's l2: 4.10679	valid_1's l1: 1.37858
# [2000]	training's l2: 0.835288	training's l1: 0.595638	valid_1's l2: 4.10267	valid_1's l1: 1.37709
# [2100]	training's l2: 0.813091	training's l1: 0.585823	valid_1's l2: 4.09337	valid_1's l1: 1.37498
# [2200]	training's l2: 0.793146	training's l1: 0.577691	valid_1's l2: 4.08815	valid_1's l1: 1.37395
# [2300]	training's l2: 0.772807	training's l1: 0.568965	valid_1's l2: 4.08401	valid_1's l1: 1.37309
# [2400]	training's l2: 0.752965	training's l1: 0.560377	valid_1's l2: 4.07989	valid_1's l1: 1.37215
# [2500]	training's l2: 0.7374	training's l1: 0.553526	valid_1's l2: 4.07466	valid_1's l1: 1.37085
# [2600]	training's l2: 0.718349	training's l1: 0.544507	valid_1's l2: 4.07437	valid_1's l1: 1.37042
# [2700]	training's l2: 0.702354	training's l1: 0.537424	valid_1's l2: 4.07348	valid_1's l1: 1.37018
# [2800]	training's l2: 0.68424	training's l1: 0.52874	valid_1's l2: 4.0712	valid_1's l1: 1.36929
# [2900]	training's l2: 0.668082	training's l1: 0.520895	valid_1's l2: 4.06719	valid_1's l1: 1.36844
# [3000]	training's l2: 0.650193	training's l1: 0.511939	valid_1's l2: 4.06784	valid_1's l1: 1.36785
# [3100]	training's l2: 0.634908	training's l1: 0.504977	valid_1's l2: 4.06704	valid_1's l1: 1.36705
# [3200]	training's l2: 0.621567	training's l1: 0.498254	valid_1's l2: 4.06365	valid_1's l1: 1.36638
# [3300]	training's l2: 0.607929	training's l1: 0.491595	valid_1's l2: 4.06156	valid_1's l1: 1.3658
# [3400]	training's l2: 0.595486	training's l1: 0.485005	valid_1's l2: 4.06124	valid_1's l1: 1.366
# [3500]	training's l2: 0.581496	training's l1: 0.477539	valid_1's l2: 4.0622	valid_1's l1: 1.36544
# [3600]	training's l2: 0.569818	training's l1: 0.47106	valid_1's l2: 4.06226	valid_1's l1: 1.36523
# Early stopping, best iteration is:
# [3433]	training's l2: 0.591019	training's l1: 0.48261	valid_1's l2: 4.06068	valid_1's l1: 1.36588
# Training until validation scores don't improve for 200 rounds.
# [100]	training's l2: 50.8753	training's l1: 5.49784	valid_1's l2: 51.5771	valid_1's l1: 5.48959
# [200]	training's l2: 20.1324	training's l1: 3.47126	valid_1's l2: 21.1488	valid_1's l1: 3.49546
# [300]	training's l2: 8.46176	training's l1: 2.25863	valid_1's l2: 9.58944	valid_1's l1: 2.33364
# [400]	training's l2: 3.95273	training's l1: 1.53418	valid_1's l2: 5.13774	valid_1's l1: 1.66965
# [500]	training's l2: 2.16651	training's l1: 1.10446	valid_1's l2: 3.40496	valid_1's l1: 1.31087
# [600]	training's l2: 1.4076	training's l1: 0.849468	valid_1's l2: 2.7049	valid_1's l1: 1.12626
# [700]	training's l2: 1.05359	training's l1: 0.697411	valid_1's l2: 2.40856	valid_1's l1: 1.02794
# [800]	training's l2: 0.870892	training's l1: 0.608039	valid_1's l2: 2.28094	valid_1's l1: 0.978201
# [900]	training's l2: 0.760825	training's l1: 0.552582	valid_1's l2: 2.21819	valid_1's l1: 0.952474
# [1000]	training's l2: 0.691891	training's l1: 0.518905	valid_1's l2: 2.18556	valid_1's l1: 0.939143
# [1100]	training's l2: 0.644131	training's l1: 0.497076	valid_1's l2: 2.1723	valid_1's l1: 0.932314
# [1200]	training's l2: 0.610532	training's l1: 0.482457	valid_1's l2: 2.16147	valid_1's l1: 0.928212
# [1300]	training's l2: 0.585613	training's l1: 0.471754	valid_1's l2: 2.15638	valid_1's l1: 0.926537
# [1400]	training's l2: 0.566743	training's l1: 0.464005	valid_1's l2: 2.15418	valid_1's l1: 0.925573
# [1500]	training's l2: 0.549622	training's l1: 0.4566	valid_1's l2: 2.15154	valid_1's l1: 0.924395
# [1600]	training's l2: 0.533029	training's l1: 0.449446	valid_1's l2: 2.14747	valid_1's l1: 0.923326
# [1700]	training's l2: 0.517775	training's l1: 0.442305	valid_1's l2: 2.1466	valid_1's l1: 0.922848
# [1800]	training's l2: 0.503344	training's l1: 0.435474	valid_1's l2: 2.14518	valid_1's l1: 0.922517
# [1900]	training's l2: 0.490928	training's l1: 0.429599	valid_1's l2: 2.14291	valid_1's l1: 0.9217
# [2000]	training's l2: 0.478196	training's l1: 0.42309	valid_1's l2: 2.1421	valid_1's l1: 0.920876
# [2100]	training's l2: 0.464707	training's l1: 0.415829	valid_1's l2: 2.14068	valid_1's l1: 0.920059
# [2200]	training's l2: 0.453243	training's l1: 0.409887	valid_1's l2: 2.14006	valid_1's l1: 0.920031
# [2300]	training's l2: 0.441821	training's l1: 0.403583	valid_1's l2: 2.13926	valid_1's l1: 0.919645
# [2400]	training's l2: 0.430591	training's l1: 0.397387	valid_1's l2: 2.1377	valid_1's l1: 0.919024
# [2500]	training's l2: 0.420309	training's l1: 0.391351	valid_1's l2: 2.13573	valid_1's l1: 0.918499
# [2600]	training's l2: 0.410837	training's l1: 0.385515	valid_1's l2: 2.13428	valid_1's l1: 0.917685
# [2700]	training's l2: 0.40142	training's l1: 0.379835	valid_1's l2: 2.13374	valid_1's l1: 0.9171
# [2800]	training's l2: 0.391559	training's l1: 0.373683	valid_1's l2: 2.13295	valid_1's l1: 0.916669
# [2900]	training's l2: 0.383308	training's l1: 0.368477	valid_1's l2: 2.13245	valid_1's l1: 0.916051
# [3000]	training's l2: 0.374311	training's l1: 0.362646	valid_1's l2: 2.13244	valid_1's l1: 0.91594
# [3100]	training's l2: 0.365561	training's l1: 0.356996	valid_1's l2: 2.12977	valid_1's l1: 0.915151
# [3200]	training's l2: 0.357299	training's l1: 0.351464	valid_1's l2: 2.12907	valid_1's l1: 0.91476
# [3300]	training's l2: 0.350159	training's l1: 0.346729	valid_1's l2: 2.12804	valid_1's l1: 0.914391
# [3400]	training's l2: 0.343338	training's l1: 0.341877	valid_1's l2: 2.12572	valid_1's l1: 0.913821
# [3500]	training's l2: 0.336595	training's l1: 0.337196	valid_1's l2: 2.1255	valid_1's l1: 0.913337
# [3600]	training's l2: 0.330572	training's l1: 0.332575	valid_1's l2: 2.1262	valid_1's l1: 0.913269
# Early stopping, best iteration is:
# [3418]	training's l2: 0.342103	training's l1: 0.341003	valid_1's l2: 2.12506	valid_1's l1: 0.913684
# 1.874233523125074
# mean validation error, 5-fold 1.908833228779687
# average splits score 1.8983041712572586

# %%
unpaths_other_split[-10:]
# Out:
# array(['record_2021_10_15_07_28_17', 'record_2021_10_26_07_32_04',
#        'record_2021_10_26_07_48_26', 'record_2021_10_22_07_23_13',
#        'record_2021_10_06_11_10_37', 'record_2021_10_14_07_57_55',
#        'record_2021_10_15_07_57_56', 'record_2021_10_13_07_52_19',
#        'record_2021_10_11_07_48_43', 'record_2021_10_22_07_57_10'],
#       dtype=object)

# %%
unpaths[-10:]
# Out:
# array(['record_2021_10_14_07_57_55', 'record_2021_10_20_07_20_45',
#        'record_2021_10_22_07_23_46', 'record_2021_10_14_07_36_45',
#        'record_2021_10_22_07_22_39', 'record_2021_10_13_07_52_19',
#        'record_2021_10_13_07_32_11', 'record_2021_10_15_07_28_17',
#        'record_2021_10_22_07_23_13', 'record_2021_10_15_07_57_56'],
#       dtype=object)

# %%
print('mean validation error, 5-fold', split_score,np.mean(split_score))
# Out:
# mean validation error, 5-fold [1.8763517602678847, 1.8978450351657778] 1.8870983977168314

# %%
print('mean validation error, 5-fold', split_score,np.mean(split_score))
# Out:
# mean validation error, 5-fold [1.8877751137348302, 1.908833228779687] 1.8983041712572586

# %%
pd.DataFrame(all_predsV,columns=['x', 'y']).to_csv('/gdrive/My Drive/Colab Notebooks/'+name+'_oof2.csv.gz', index=False, compression='gzip')
pd.DataFrame(all_targetsV,columns=['x', 'y']).to_csv('/gdrive/My Drive/Colab Notebooks/all_targetsV2.csv.gz', index=False, compression='gzip')

# %%
# CROSS VALIDATION

name='lgbm'+version


split_score=[]
split_score_othersplit=[]
for split in [1,2]:
    data=dataA.loc[dataA.setNum==split,:]
    data_other_split = dataA.loc[dataA.setNum==(3-split),:]
    unpaths_other_split=data_other_split.path.unique()
    data.shape
    unpaths=data.path.unique()
    print('we have ',len(unpaths),' unique paths')
    score_df = pd.DataFrame()
    oof = list()
    predictions = list()

    oof_x, oof_y = np.zeros(data.shape[0]), np.zeros(data.shape[0])
    preds_x, preds_y = 0, 0

    oof_x_othersplit, oof_y_othersplit = np.zeros(data_other_split.shape[0]), np.zeros(data_other_split.shape[0])
    preds_x_othersplit, preds_y_othersplit = 0, 0

    scores_per_fold=[]

    all_preds=[]
    all_targets=[]
    all_preds_othersplit=[]
    all_targets_othersplit=[]

    np.random.seed(42)
    sh=np.random.permutation(unpaths)


    k=5
    val_size=int(len(sh)/k)
    for f in range(k):
        print('fold:', f)

        if f<(k-1):
            val_paths=sh[val_size*f:val_size*(f+1)]
        else:
            val_paths=sh[val_size*f:]

        train_paths=[x for x in unpaths if x not in val_paths]
        
        val_paths=np.array(val_paths)
        train_paths=np.array(train_paths)
        
        X_train = data.loc[data.path.isin(train_paths), TRAIN_FEATS ].reset_index(drop=True)

        y_trainXY =  data.loc[data.path.isin(train_paths), ['x', 'y'] ].reset_index(drop=True).values

        X_val = data.loc[data.path.isin(val_paths), TRAIN_FEATS ].reset_index(drop=True)
        y_valXY = data.loc[data.path.isin(val_paths), ['x', 'y'] ].reset_index(drop=True).values

        # val_paths = np.concatenate((val_paths,unpaths_other_split))
        # X_val = dataA.loc[dataA.path.isin(val_paths), TRAIN_FEATS ].reset_index(drop=True)
        # y_valXY = dataA.loc[dataA.path.isin(val_paths), ['x', 'y'] ].reset_index(drop=True).values
        
        X_val_othersplit = data_other_split.loc[:, TRAIN_FEATS ].reset_index(drop=True)
        y_valXY_othersplit = data_other_split.loc[:, ['x', 'y'] ].reset_index(drop=True).values


        val_predsXY=[]
        val_predsXY_othersplit=[]
        
        for i in range(2):
            y_train = y_trainXY[:,i]
            y_val = y_valXY[:,i]

            # gbm = lgb.LGBMRegressor(**hyper_params)
            # model = gbm.fit(X_train, y_train,
            #     eval_set=[(X_train, y_train), (X_val, y_val)],
            #     eval_metric='l1',
            #     verbose=100,
            #     early_stopping_rounds=200)
            
            # joblib.dump(model, weights_path+'fold_'+str(f)+['x','y'][i]+'_v2')
            model = joblib.load( weights_path+name+'split'+str(split)+'fold_'+str(f)+['x','y'][i]+'_v2')

            val_predsXY.append(model.predict(X_val, num_iteration=model.best_iteration_) )
            val_predsXY_othersplit.append(model.predict(X_val_othersplit, num_iteration=model.best_iteration_) )
        val_predsXY=np.stack(val_predsXY).T
        val_predsXY_othersplit=np.stack(val_predsXY_othersplit).T
        
        print(euclidean_distance(val_predsXY[:,0], val_predsXY[:,1], y_valXY[:,0], y_valXY[:,1]))
        print(euclidean_distance(val_predsXY_othersplit[:,0], val_predsXY_othersplit[:,1], y_valXY_othersplit[:,0], y_valXY_othersplit[:,1]))

        all_preds.append(val_predsXY)
        all_preds_othersplit.append(val_predsXY_othersplit)
        all_targets.append(y_valXY)
        all_targets_othersplit.append(y_valXY_othersplit)
            

    all_predsV=np.vstack(all_preds)
    all_targetsV=np.vstack(all_targets)    

    all_predsV_othersplit=np.vstack(all_preds_othersplit)
    all_targetsV_othersplit=np.vstack(all_targets_othersplit)    

    print('mean validation error, 5-fold', euclidean_distance(all_targetsV[:,0], all_targetsV[:,1], all_predsV[:,0], all_predsV[:,1]))
    split_score.append(euclidean_distance(all_targetsV[:,0], all_targetsV[:,1], all_predsV[:,0], all_predsV[:,1]))
    print('mean validation error othersplit, 5-fold', euclidean_distance(all_targetsV_othersplit[:,0], all_targetsV_othersplit[:,1], all_predsV_othersplit[:,0], all_predsV_othersplit[:,1]))
    split_score_othersplit.append(euclidean_distance(all_targetsV_othersplit[:,0], all_targetsV_othersplit[:,1], all_predsV_othersplit[:,0], all_predsV_othersplit[:,1]))
print('average splits score', np.mean(split_score))       
print('average splits othersplit score', np.mean(split_score_othersplit))
# Out:
# we have  423  unique paths
# fold: 0
# 1.9999615183915267
# 2.2116324577122977
# fold: 1
# 1.9191896203225614
# 2.1824189442118462
# fold: 2
# 1.8907256108894293
# 2.1717313209137297
# fold: 3
# 1.8272521096554142
# 2.1905308075927743
# fold: 4
# 1.7981609732435042
# 2.190962044899518
# mean validation error, 5-fold 1.8877751137348302
# mean validation error othersplit, 5-fold 2.1894551150660333
# we have  423  unique paths
# fold: 0
# 1.9253374364631421
# 2.116516027238999
# fold: 1
# 2.0499091006159578
# 2.1999876338768285
# fold: 2
# 1.89997409720585
# 2.160435444820439
# fold: 3
# 1.7911918885964826
# 2.1499930947987522
# fold: 4
# 1.874233523125074
# 2.1563012880379144
# mean validation error, 5-fold 1.908833228779687
# mean validation error othersplit, 5-fold 2.1566466977545864
# average splits score 1.8983041712572586
# average splits othersplit score 2.17305090641031

# %%
( np.mean(split_score)+np.mean(split_score_othersplit))/2
# 2.0356775388337844
# Out:
# 2.0356775388337844

# %%
pd.DataFrame(all_predsV_othersplit,columns=['x', 'y']).to_csv('/gdrive/My Drive/Colab Notebooks/'+name+'_othersplit_oof2.csv.gz', index=False, compression='gzip')
pd.DataFrame(all_targetsV_othersplit,columns=['x', 'y']).to_csv('/gdrive/My Drive/Colab Notebooks/all_targetsV2_othersplit.csv.gz', index=False, compression='gzip')

# %%
# '/gdrive/My Drive/Colab Notebooks/'+name+'_oof.csv.gz'

# %% [markdown]
# ## EVALUATION - PLOTS

# %%
import matplotlib.pyplot as plt
plt.plot(all_predsV[:,0],all_predsV[:,1],'.')
plt.show()

# %%
all_targetsV.shape
# Out:
# (7369, 2)

# %% [markdown]
# **5 FOLD CV PREDICTIONS OVER TARGET GRID**
# With blue dots are the true checkpoints
# Orange dots for predictions

# %%
plt.figure(figsize=(10,10))
plt.title('XY scatter plot of Predicted positions over target grid')


plt.plot(all_predsV[:,0],all_predsV[:,1],'.', label='Predicted position', color='orange')
# plt.plot(all_targetsV[:,0],all_targetsV[:,1],'o', label='half target grid')

plt.plot(uniquePoints.loc[uniquePoints.setNum==2,'x'].values,uniquePoints.loc[uniquePoints.setNum==2,'y'].values,'o', label='used target grid', color='blue')
plt.plot(uniquePoints.loc[uniquePoints.setNum==1,'x'].values,uniquePoints.loc[uniquePoints.setNum==1,'y'].values,'o', label='missing target grid', color='red')
# plt.plot(uniquePoints.iloc[:,0].values,uniquePoints.iloc[:,1].values,'o', label='missing target grid', color='r')
plt.legend()
plt.xlabel('X Axis')
plt.ylabel('Y Axis')

plt.axis([34, 87, 53, 0])
plt.show()
print('mean validation error, 5-fold', euclidean_distance(all_targetsV[:,0], all_targetsV[:,1], all_predsV[:,0], all_predsV[:,1]))
# Out:
# mean validation error, 5-fold 1.908833228779687

# %%
scoreperrow=[]
for row in range(len(all_targetsV)):
    scoreperrow.append(euclidean_distance(all_targetsV[row,0], all_targetsV[row,1], all_predsV[row,0], all_predsV[row,1]))

# %%
plt.figure(figsize=(10,10))
plt.title('XY scatter plot of Predicted positions over target grid')
plt.plot(all_targetsV[:,0],all_targetsV[:,1],'o', color="orange", label='target grid')
plt.scatter(all_predsV[:,0],all_predsV[:,1],s=0.5*np.array(scoreperrow)**2, label='Predicted position')
plt.legend()
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.show()
print('mean validation error, 5-fold', euclidean_distance(all_targetsV[:,0], all_targetsV[:,1], all_predsV[:,0], all_predsV[:,1]))
# Out:
# mean validation error, 5-fold 1.908833228779687

# %%
plt.figure(figsize=(10,10))
plt.title('XY scatter plot of Predicted positions over target grid with error magnitude')
# plt.plot(all_targetsV[:,0],all_targetsV[:,1],'o', color="orange", label='target grid')
plt.scatter(all_predsV[:,0],all_predsV[:,1],s=0.5*np.array(scoreperrow)**2, label='Predicted position',color='orange')

plt.plot(uniquePoints.loc[uniquePoints.setNum==2,'x'].values,uniquePoints.loc[uniquePoints.setNum==2,'y'].values,'o', label='used target grid', color='blue')
plt.plot(uniquePoints.loc[uniquePoints.setNum==1,'x'].values,uniquePoints.loc[uniquePoints.setNum==1,'y'].values,'o', label='missing target grid', color='red')

plt.legend()
plt.xlabel('X Axis')
plt.ylabel('Y Axis')

plt.axis([34, 87, 53, 0])
plt.show()
print('mean validation error, 5-fold', euclidean_distance(all_targetsV[:,0], all_targetsV[:,1], all_predsV[:,0], all_predsV[:,1]))
# Out:
# mean validation error, 5-fold 1.908833228779687

# %%
scoreperrow_othersplit=[]
for row in range(len(all_targetsV_othersplit)):
    scoreperrow_othersplit.append(euclidean_distance(all_targetsV_othersplit[row,0], all_targetsV_othersplit[row,1], all_predsV_othersplit[row,0], all_predsV_othersplit[row,1]))

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
plt.title('XY scatter plot of Predicted positions over OTHER target grid with error magnitude')
# plt.plot(all_targetsV[:,0],all_targetsV[:,1],'o', color="orange", label='target grid')
plt.scatter(all_predsV_othersplit[:,0],all_predsV_othersplit[:,1],s=0.25*np.array(scoreperrow_othersplit)**2, label='Predicted position',color='orange')

plt.plot(uniquePoints.loc[uniquePoints.setNum==2,'x'].values,uniquePoints.loc[uniquePoints.setNum==2,'y'].values,'o', label='used target grid', color='blue')
plt.plot(uniquePoints.loc[uniquePoints.setNum==1,'x'].values,uniquePoints.loc[uniquePoints.setNum==1,'y'].values,'o', label='missing target grid', color='red')

plt.legend()
plt.xlabel('X Axis')
plt.ylabel('Y Axis')

plt.axis([34, 87, 53, 0])
plt.show()
print('mean validation error, 5-fold', euclidean_distance(all_targetsV[:,0], all_targetsV[:,1], all_predsV[:,0], all_predsV[:,1]))
# Out:
# mean validation error, 5-fold 1.908833228779687

# %%
version
# Out:
# 'forPdata423_halfgrid'

# %% [markdown]
# ## Full train

# %%
# hyper_params["num_iterations"]= 2500

# %%
# name=version+'lgbm'

# train_paths=unpaths[:]

# train_paths=np.array(train_paths)

# X_train = data.loc[data.path.isin(train_paths), TRAIN_FEATS ].reset_index(drop=True)

# y_trainXY =  data.loc[data.path.isin(train_paths), ['x', 'y'] ].reset_index(drop=True).values

# train_predsXY=[]
# all_train_targets=[]
# xy=['x', 'y']
# for i in range(2):
#     y_train = y_trainXY[:,i]

#     gbm = lgb.LGBMRegressor(**hyper_params)


#     model = gbm.fit(X_train, y_train,
#         eval_set=[(X_train, y_train)],
#         eval_metric='l1',
#         verbose=100
#         )
    
#     # joblib.dump(model, weights_path+'FullTrain_'+['x','y'][i])
#     joblib.dump(model,'/gdrive/My Drive/Colab Notebooks/weights/'+name+'_model'+xy[i])

#     train_predsXY.append(gbm.predict(X_train, num_iteration=gbm.best_iteration_) )

# train_predsXY=np.stack(train_predsXY).T

# print('train error',euclidean_distance(train_predsXY[:,0], train_predsXY[:,1], y_trainXY[:,0], y_trainXY[:,1]))

# %%
# print('Save LightGBM model fully trained')
# joblib.dump(model,'/gdrive/My Drive/Colab Notebooks/weights/'+name+'_model')
