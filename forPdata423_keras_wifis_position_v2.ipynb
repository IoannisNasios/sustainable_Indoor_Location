# %%
print('Connect to google drive')
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Connect to google drive
# Mounted at /gdrive

# %%
print('Import necessary libraries')

import numpy as np
import pandas as pd
import scipy.stats as stats
from pathlib import Path
import glob
import pickle

import warnings
warnings.filterwarnings("ignore")

import random
import os
# os.environ["CUDA_VISIBLE_DEVICES"]="0"
import gc
import tqdm

from sklearn.model_selection import StratifiedKFold, GroupKFold
from sklearn.preprocessing import StandardScaler, LabelEncoder

import joblib

import tensorflow as tf
import tensorflow.keras.layers as L
import tensorflow.keras.models as M
import tensorflow.keras.backend as K
from tensorflow.keras.callbacks import ReduceLROnPlateau, ModelCheckpoint, EarlyStopping, LearningRateScheduler
# Out:
# Import necessary libraries

# %%
base_path='/gdrive/My Drive/Colab Notebooks/'
weights_path='/gdrive/My Drive/Colab Notebooks/weights/'

# %%
def euclidean_distance(x_true,y_true, x_pred, y_pred):
    return np.mean(((x_true-x_pred)**2+(y_true-y_pred)**2)**0.5)

# %%
version='forPdata423'

# %%
data=pd.read_csv('/gdrive/My Drive/Colab Notebooks/data423.csv.zip') #
data.shape
# Out:
# (14373, 316)

# %%
data.head()
# Out:
#    rsid1  rsid2  rsid3  ...      y      timestamp                        path
# 0    -93   -999    -81  ...  25.89  1633934464983  record_2021_10_11_07_41_02
# 1    -93   -999    -81  ...  25.89  1633934467125  record_2021_10_11_07_41_02
# 2   -999   -999   -999  ...  25.89  1633934469251  record_2021_10_11_07_41_02
# 3   -999   -999   -999  ...  25.89  1633934471370  record_2021_10_11_07_41_02
# 4    -78   -999   -999  ...  25.74  1633934473508  record_2021_10_11_07_41_02
#
# [5 rows x 316 columns]

# %%
# print('split path-timestamp in 2 columns')
# data[['path','timestamp']]=data['path-timestamp'].str.split('-',expand=True)
# print('remove path-timestamp column')
# data.drop('path-timestamp', axis=1,inplace=True)

# %%
# data.head()

# %%
num_of_lines=len(data)
data2=[]
for i in range(num_of_lines):
    if i % 1000 == 0:
        print(f'current:{i}')

    tmp=data.iloc[i,:-4].astype(int).reset_index(drop=False)
    tmp.columns=['BSSID','Signal_Strength']
    tmp=tmp.sort_values(['Signal_Strength', 'BSSID'],ascending=False)
    target = data.iloc[i,-4:]

    line = pd.concat([pd.Series(tmp.BSSID.astype(str)), tmp.Signal_Strength.astype(int), target])

    line.index = [str(i) for i in range(2*len(tmp)+4)]

    data2.append(line.values)
data2 = pd.DataFrame(np.stack(data2))

data2.columns = [f'BSSID{str(i)}' for i in range(len(tmp))] + [f'Signal_Strength_{str(i)}' for i in range(len(tmp))] + ['x','y', 'timestamp', 'path']
# data.to_csv(SAVEDIR+file_name, index=False)
# Out:
# current:0
# current:1000
# current:2000
# current:3000
# current:4000
# current:5000
# current:6000
# current:7000
# current:8000
# current:9000
# current:10000
# current:11000
# current:12000
# current:13000
# current:14000

# %%
target
# Out:
# x                                 43.49
# y                                 22.71
# timestamp                 1634711047366
# path         record_2021_10_20_07_23_22
# Name: 14372, dtype: object

# %%
data=data2.copy()

# %%
data.head()
# Out:
#    BSSID0  BSSID1  BSSID2  ...      y      timestamp                        path
# 0  rsid34  rsid33  rsid32  ...  25.89  1633934464983  record_2021_10_11_07_41_02
# 1  rsid34  rsid33  rsid32  ...  25.89  1633934467125  record_2021_10_11_07_41_02
# 2  rsid32  rsid34  rsid33  ...  25.89  1633934469251  record_2021_10_11_07_41_02
# 3  rsid32  rsid34  rsid33  ...  25.89  1633934471370  record_2021_10_11_07_41_02
# 4  rsid32  rsid34  rsid33  ...  25.74  1633934473508  record_2021_10_11_07_41_02
#
# [5 rows x 628 columns]

# %%
a=data.loc[:,[x for x in data.columns if x.startswith('Signal_Strength')]].max().values
MAX_NUM_WIFIS=np.where(a[a>-999])[0].max()
MAX_NUM_WIFIS
# Out:
# 86

# %%
BSSID_FEATS=[x for x in data.columns if x.startswith('BSSID')]
RSSI_FEATS=[x for x in data.columns if x.startswith('Signal_Strength')]

len(BSSID_FEATS),len(RSSI_FEATS)
# Out:
# (312, 312)

# %%
wifi_bssids = []
for i in range(len(BSSID_FEATS)):
    wifi_bssids.extend(data.iloc[:,i].values.tolist())
wifi_bssids = list(set(wifi_bssids))

wifi_bssids = np.unique(wifi_bssids)
wifi_bssids_size = len(wifi_bssids)
print(wifi_bssids_size)

wifi_bssids_dict={}
counter = 0               #<-------------  1 not 0
for wf in wifi_bssids:
    wifi_bssids_dict[wf]=counter
    counter+=1
# import joblib
# joblib.dump(wifi_bssids_dict,'wifi_bssids_dict2')
# Out:
# 312

# %%
# for i in BSSID_FEATS[:MAX_NUM_WIFIS]:
for i in BSSID_FEATS:
    data.loc[:,i] = data.loc[:,i] .apply(lambda x: wifi_bssids_dict[x])

# %%
data.loc[:,BSSID_FEATS[:MAX_NUM_WIFIS]]=data.loc[:,BSSID_FEATS[:MAX_NUM_WIFIS]].astype('float32')

# %%
Ms=np.mean(data.loc[:,RSSI_FEATS[:MAX_NUM_WIFIS]].values.astype('float32'),axis=0)
Ss=np.std(data.loc[:,RSSI_FEATS[:MAX_NUM_WIFIS]].values.astype('float32'),axis=0)
# joblib.dump(Ms,'means_of_rssids2')
# joblib.dump(Ss,'stds_of_rssids2')
Ms[:5],Ss[:5]
# Out:
# (array([-51.815975, -53.653725, -54.69721 , -57.28261 , -60.02574 ],
#        dtype=float32),
#  array([6.1781244, 6.213863 , 6.278394 , 5.765399 , 6.2344913],
#        dtype=float32))

# %%
for i in range(MAX_NUM_WIFIS):
    data.loc[:,RSSI_FEATS[i]] = ((data.loc[:,RSSI_FEATS[i]] - Ms[i])/(Ss[i]+1)).astype('float32')

# %%
data.loc[:,RSSI_FEATS].head()
# Out:
#    Signal_Strength_0  ...  Signal_Strength_311
# 0           1.228173  ...                 -999
# 1           1.228173  ...                 -999
# 2           1.785421  ...                 -999
# 3           1.785421  ...                 -999
# 4           1.228173  ...                 -999
#
# [5 rows x 312 columns]

# %%
# TRAIN_FEATS=[x for x in data.columns if x not in ['x', 'y', 'path', 'timestamp']]
# len(TRAIN_FEATS)

# %%
# d2=data.loc[:,TRAIN_FEATS].copy()
# d2[d2==-999]=0
# d2[d2!=0]=1

# %%
# d2.head()

# %%
# import matplotlib.pyplot as plt
# plt.hist(np.sum(d2,0),50)
# plt.show()

# %%
# Ms=np.mean(data.loc[:,TRAIN_FEATS].values,axis=0)
# Ss=np.std(data.loc[:,TRAIN_FEATS].values,axis=0)

# # joblib.dump(Ms,'means_of_rssids2')
# # joblib.dump(Ss,'stds_of_rssids2')

# for i in range(len(TRAIN_FEATS)):
#     data.loc[:,TRAIN_FEATS[i]] = (data.loc[:,TRAIN_FEATS[i]] - Ms[i])/(Ss[i]+1)

# %%
unpaths=data.path.unique()

# %%
print('we have ',len(unpaths),' unique paths')
# Out:
# we have  423  unique paths

# %%
# USE_FEATS=TRAIN_FEATS[:]
# # USE_FEATS=np.array(TRAIN_FEATS)[np.where((np.sum(d2,0))>200)[0]]
# USE_FEATS.shape

# %% [markdown]
# ### CV TRAIN

# %%
def create_model(bssid_size1, rssi_size):

    def myFunc(x,size=bssid_size1):
        return x[:,:size]
    def myFunc2(x,size=bssid_size1):
        return x[:,size:]
            
    input_layer_all = L.Input(shape=(bssid_size1+ rssi_size,), name='inputL', dtype='float32')
    # input_layer_all = L.Dropout(0.1, name='do1')(input_layer_all)    
    input_embd_layer = L.Lambda(myFunc )(input_layer_all)
    x1 = L.Embedding(wifi_bssids_size, 4, name='emb_bssid')(input_embd_layer)
#     x1 = L.Dropout(0.1)(x1)
    x1 = L.Flatten( name='fl_bssid')(x1)
    # print(x1.shape)
    
    
    # rssi feats
    # input_layer = L.Input((rssi_size, ), name='input_rsid', dtype='float32')
    input_layer = L.Lambda(myFunc2)(input_layer_all)
    x2 = L.BatchNormalization(name='bn1')(input_layer)
    x2 = L.Dense(rssi_size * 1, name='dn1')(x2)
    x2 = L.Dropout(0.1, name='do1')(x2)    
#     x2 = L.Dense(NUM_FEATS * 4, activation='relu')(x2)
    # print(x2.shape)
    

    
    # main stream
    x = L.Concatenate(axis=1, name='concat')([x1, x2])
    # print(x.shape)
#     x = L.Flatten()(x)
    x = L.BatchNormalization(name='bn2')(x)
    x = L.Dropout(0.5, name='do2')(x)
    x = L.Dense(256, name='dn2')(x)
#     x = L.Dropout(0.1)(x)
#     x = L.Dense(256, activation='relu')(x)

    x = L.Reshape((1 , 256), name='resh')(x)
#     x = L.Reshape((1 , -1))(x)
    # print(x.shape)
    x = L.BatchNormalization(name='bn3')(x)
    x = L.LSTM(128, return_sequences=True, name='lstm1')(x)
    x = L.Dropout(0.2, name='do3')(x)
    x = L.BatchNormalization(name='bn4')(x)    
    x = L.LSTM(64, return_sequences=True, name='lstm2')(x)
    x = L.Dropout(0.2, name='do4')(x)
#     x = L.Bidirectional(L.LSTM(512, return_sequences=True))(x)
#     x = L.BatchNormalization()(x)    
#     x = L.Bidirectional(L.LSTM(256, return_sequences=True))(x)    
    x = L.BatchNormalization(name='bn5')(x)
    x = L.LSTM(32, return_sequences=False, name='lstm3')(x)
    # x = L.LSTM(128, return_sequences=False, name='lstm3')(x)
#     x = L.Dropout(0.1)(x)
    # print(x.shape)
    
    
    
    x = L.BatchNormalization(name='bn6')(x)
#     x = L.Dropout(0.1)(x)
#     x = L.Dense(64)(x)
# #     x = L.Dropout(0.1)(x)
#     x = L.Dense(128)(x)
# #     x = L.Dense(64, activation='relu')(x)

    
    
    output_layer_1 = L.Dense(2, name='xy')(x)
#     output_layer_2 = L.Dense(1, activation='softmax', name='floor')(x)

    model = M.Model(inputs=input_layer_all, 
#     model = M.Model([input_embd_layer, input_embd_layerb, input_layer, input_site_layer], 
                    outputs=output_layer_1)
#                     [output_layer_1, output_layer_2])

    model.compile(optimizer=tf.keras.optimizers.Adam(lr=0.001),
                  loss='mse', metrics=['mse'])

    return model    
model =  create_model(bssid_size1=MAX_NUM_WIFIS, rssi_size=MAX_NUM_WIFIS )
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  inputL (InputLayer)            [(None, 172)]        0           []
#
#  lambda_1 (Lambda)              (None, 86)           0           ['inputL[0][0]']
#
#  lambda (Lambda)                (None, 86)           0           ['inputL[0][0]']
#
#  bn1 (BatchNormalization)       (None, 86)           344         ['lambda_1[0][0]']
#
#  emb_bssid (Embedding)          (None, 86, 4)        1248        ['lambda[0][0]']
#
#  dn1 (Dense)                    (None, 86)           7482        ['bn1[0][0]']
#
#  fl_bssid (Flatten)             (None, 344)          0           ['emb_bssid[0][0]']
#
#  do1 (Dropout)                  (None, 86)           0           ['dn1[0][0]']
#
#  concat (Concatenate)           (None, 430)          0           ['fl_bssid[0][0]',
#                                                                   'do1[0][0]']
#
#  bn2 (BatchNormalization)       (None, 430)          1720        ['concat[0][0]']
#
#  do2 (Dropout)                  (None, 430)          0           ['bn2[0][0]']
#
#  dn2 (Dense)                    (None, 256)          110336      ['do2[0][0]']
#
#  resh (Reshape)                 (None, 1, 256)       0           ['dn2[0][0]']
#
#  bn3 (BatchNormalization)       (None, 1, 256)       1024        ['resh[0][0]']
#
#  lstm1 (LSTM)                   (None, 1, 128)       197120      ['bn3[0][0]']
#
#  do3 (Dropout)                  (None, 1, 128)       0           ['lstm1[0][0]']
#
#  bn4 (BatchNormalization)       (None, 1, 128)       512         ['do3[0][0]']
#
#  lstm2 (LSTM)                   (None, 1, 64)        49408       ['bn4[0][0]']
#
#  do4 (Dropout)                  (None, 1, 64)        0           ['lstm2[0][0]']
#
#  bn5 (BatchNormalization)       (None, 1, 64)        256         ['do4[0][0]']
#
#  lstm3 (LSTM)                   (None, 32)           12416       ['bn5[0][0]']
#
#  bn6 (BatchNormalization)       (None, 32)           128         ['lstm3[0][0]']
#
#  xy (Dense)                     (None, 2)            66          ['bn6[0][0]']
#
# ==================================================================================================
# Total params: 382,060
# Trainable params: 380,068
# Non-trainable params: 1,992
# __________________________________________________________________________________________________

# %%
# def create_model(bssid_size1, rssi_size):

#     def myFunc(x,size=bssid_size1):
#         return x[:,:size]
#     def myFunc2(x,size=bssid_size1):
#         return x[:,size:]
            
#     input_layer_all = L.Input(shape=(bssid_size1+ rssi_size,), name='inputL', dtype='float32')
#     # input_layer_all = L.Dropout(0.1, name='do1')(input_layer_all)    
#     input_embd_layer = L.Lambda(myFunc )(input_layer_all)
#     x1 = L.Embedding(wifi_bssids_size, 4, name='emb_bssid')(input_embd_layer)
# #     x1 = L.Dropout(0.1)(x1)
#     x1 = L.Flatten( name='fl_bssid')(x1)
#     # print(x1.shape)
    
    
#     # rssi feats
#     # input_layer = L.Input((rssi_size, ), name='input_rsid', dtype='float32')
#     input_layer = L.Lambda(myFunc2)(input_layer_all)
#     x2 = L.BatchNormalization(name='bn1')(input_layer)
#     x2 = L.Dense(rssi_size * 1, name='dn1')(x2)
#     x2 = L.Dropout(0.1, name='do1')(x2)    
# #     x2 = L.Dense(NUM_FEATS * 4, activation='relu')(x2)
#     # print(x2.shape)
    

    
#     # main stream
#     x = L.Concatenate(axis=1, name='concat')([x1, x2])
#     # print(x.shape)
# #     x = L.Flatten()(x)
#     x = L.BatchNormalization(name='bn2')(x)
#     x = L.Dropout(0.5, name='do2')(x)
#     x = L.Dense(256, name='dn2')(x)
# #     x = L.Dropout(0.1)(x)
# #     x = L.Dense(256, activation='relu')(x)

#     x = L.Reshape((1 , 256), name='resh')(x)
# #     x = L.Reshape((1 , -1))(x)
#     # print(x.shape)
#     x = L.BatchNormalization(name='bn3')(x)
#     x = L.Bidirectional(L.LSTM(128, return_sequences=True, name='lstm1'))(x)
#     # x = L.LSTM(128, return_sequences=True, name='lstm1')(x)
#     x = L.Dropout(0.3, name='do3')(x)
#     x = L.BatchNormalization(name='bn4')(x)    
#     x = L.Bidirectional(L.LSTM(64, return_sequences=True, name='lstm2'))(x)
#     # x = L.LSTM(64, return_sequences=True, name='lstm2')(x)
#     x = L.Dropout(0.1, name='do4')(x)
# #     x = L.Bidirectional(L.LSTM(512, return_sequences=True))(x)
# #     x = L.BatchNormalization()(x)    
# #     x = L.Bidirectional(L.LSTM(256, return_sequences=True))(x)    
#     x = L.BatchNormalization(name='bn5')(x)
#     x = L.Bidirectional(L.LSTM(32, return_sequences=False, name='lstm3'))(x)
#     # x = L.LSTM(32, return_sequences=False, name='lstm3')(x)
#     # x = L.LSTM(128, return_sequences=False, name='lstm3')(x)
# #     x = L.Dropout(0.1)(x)
#     # print(x.shape)
    
    
    
#     x = L.BatchNormalization(name='bn6')(x)
# #     x = L.Dropout(0.1)(x)
# #     x = L.Dense(64)(x)
# # #     x = L.Dropout(0.1)(x)
# #     x = L.Dense(128)(x)
# # #     x = L.Dense(64, activation='relu')(x)

    
    
#     output_layer_1 = L.Dense(2, name='xy')(x)
# #     output_layer_2 = L.Dense(1, activation='softmax', name='floor')(x)

#     model = M.Model(inputs=input_layer_all, 
# #     model = M.Model([input_embd_layer, input_embd_layerb, input_layer, input_site_layer], 
#                     outputs=output_layer_1)
# #                     [output_layer_1, output_layer_2])

#     model.compile(optimizer=tf.keras.optimizers.Adam(lr=0.001),
#                   loss='mse', metrics=['mse'])

#     return model    
# model =  create_model(bssid_size1=MAX_NUM_WIFIS, rssi_size=MAX_NUM_WIFIS )
# model.summary()

# %%
def _cosine_anneal_schedule(t):
    cos_inner = np.pi * (t % (epochs // snapshots))
    cos_inner /= epochs // snapshots
    cos_out = np.cos(cos_inner) + 1
    return float(lr_0 / 2 * cos_out)

# %%
NUM_FEATS=MAX_NUM_WIFIS
NUM_FEATS
# Out:
# 86

# %%
# data.loc[:, ['x', 'y'] ]=data.loc[:, ['x', 'y'] ].values.astype('float32')
# data.loc[:, ['x'] ]=data.loc[:, ['x'] ].values.astype('float32')
# data.loc[:, ['y'] ]=data.loc[:, ['y'] ].values.astype('float32')
data.x=data.x.values.astype('float32')
data.y=data.y.values.astype('float32')
data.loc[:, ['x', 'y'] ].dtypes
# Out:
# x    float32
# y    float32
# dtype: object

# %%
# X_train.min().values

# %%
# X_train.loc[:,RSSI_FEATS[:NUM_FEATS]].astype('float32').values
# X_train.loc[:,RSSI_FEATS[:NUM_FEATS]].values
# X_train.loc[:,RSSI_FEATS[NUM_FEATS-1]].values
# np.concatenate((X_train.loc[:,BSSID_FEATS[:NUM_FEATS]].values, X_train.loc[:,RSSI_FEATS[:NUM_FEATS]].values),1).shape
# np.concatenate((X_val.loc[:,BSSID_FEATS[:NUM_FEATS]].values, X_val.loc[:,RSSI_FEATS[:NUM_FEATS]].values),1).max()
# data.loc[:, ['x', 'y'] ].reset_index(drop=True).values

# %%
NUM_FEATS=60

# %%
# CROSS VALIDATION

name='keras'+version


score_df = pd.DataFrame()
oof = list()
predictions = list()

oof_x, oof_y = np.zeros(data.shape[0]), np.zeros(data.shape[0])
preds_x, preds_y = 0, 0

scores_per_fold=[]

all_preds=[]
all_targets=[]

np.random.seed(42)
sh=np.random.permutation(unpaths)


k=5
val_size=int(len(sh)/k)
for f in range(k):
    print('fold:', f)

    if f<(k-1):
        val_paths=sh[val_size*f:val_size*(f+1)]
    else:
        val_paths=sh[val_size*f:]

    train_paths=[x for x in unpaths if x not in val_paths]
    
    val_paths=np.array(val_paths)
    train_paths=np.array(train_paths)

    X_train = data.loc[data.path.isin(train_paths), BSSID_FEATS + RSSI_FEATS ].reset_index(drop=True)

    y_train =  data.loc[data.path.isin(train_paths), ['x', 'y'] ].reset_index(drop=True).values

    X_val = data.loc[data.path.isin(val_paths), BSSID_FEATS + RSSI_FEATS ].reset_index(drop=True)
    y_val = data.loc[data.path.isin(val_paths), ['x', 'y'] ].reset_index(drop=True).values


    model = create_model(bssid_size1=NUM_FEATS, rssi_size=NUM_FEATS  )
    epochs=140
    snapshots = 7
    lr_0 = 0.01
    lr_anneal1 = LearningRateScheduler(schedule=_cosine_anneal_schedule, verbose=False)

    h = model.fit(np.concatenate((X_train.loc[:,BSSID_FEATS[:NUM_FEATS]].values, X_train.loc[:,RSSI_FEATS[:NUM_FEATS]].values),1),
                  y_train, 
                  batch_size=128*8, epochs=epochs, verbose=1,
                  validation_data=(np.concatenate((X_val.loc[:,BSSID_FEATS[:NUM_FEATS]].values, X_val.loc[:,RSSI_FEATS[:NUM_FEATS]].values),1),
                  y_val),
                callbacks=[ lr_anneal1])
        
    epochs=140
    snapshots = 7
    lr_0 = 0.001
    lr_anneal1 = LearningRateScheduler(schedule=_cosine_anneal_schedule, verbose=False)

    h = model.fit(np.concatenate((X_train.loc[:,BSSID_FEATS[:NUM_FEATS]].values, X_train.loc[:,RSSI_FEATS[:NUM_FEATS]].values),1),
                  y_train, 
                  batch_size=128*8, epochs=epochs, verbose=1,
                  validation_data=(np.concatenate((X_val.loc[:,BSSID_FEATS[:NUM_FEATS]].values, X_val.loc[:,RSSI_FEATS[:NUM_FEATS]].values),1),
                  y_val),
                callbacks=[ lr_anneal1])

    model.save_weights(weights_path+name+'_fold'+str(f)+'.hdf5')
    val_predsXY = model.predict(np.concatenate((X_val.loc[:,BSSID_FEATS[:NUM_FEATS]].values, X_val.loc[:,RSSI_FEATS[:NUM_FEATS]].values),1)) 

    
    print(euclidean_distance(val_predsXY[:,0], val_predsXY[:,1], y_val[:,0], y_val[:,1]))

    all_preds.append(val_predsXY)
    all_targets.append(y_val)
        

all_predsV=np.vstack(all_preds)
all_targetsV=np.vstack(all_targets)
# Out:
# fold: 0
# Epoch 1/140
# 11/11 [==============================] - 9s 223ms/step - loss: 2175.3538 - mse: 2175.3538 - val_loss: 2221.7554 - val_mse: 2221.7554 - lr: 0.0100
# Epoch 2/140
# 11/11 [==============================] - 1s 87ms/step - loss: 2016.3556 - mse: 2016.3556 - val_loss: 1987.7935 - val_mse: 1987.7935 - lr: 0.0099
# Epoch 3/140
# 11/11 [==============================] - 1s 86ms/step - loss: 1822.5972 - mse: 1822.5972 - val_loss: 1719.4635 - val_mse: 1719.4635 - lr: 0.0098
# Epoch 4/140
# 11/11 [==============================] - 1s 85ms/step - loss: 1559.2045 - mse: 1559.2045 - val_loss: 1412.5817 - val_mse: 1412.5817 - lr: 0.0095
# Epoch 5/140
# 11/11 [==============================] - 1s 85ms/step - loss: 1246.3988 - mse: 1246.3988 - val_loss: 1078.1567 - val_mse: 1078.1567 - lr: 0.0090
# Epoch 6/140
# 11/11 [==============================] - 1s 86ms/step - loss: 926.1333 - mse: 926.1333 - val_loss: 779.4073 - val_mse: 779.4073 - lr: 0.0085
# Epoch 7/140
# 11/11 [==============================] - 1s 86ms/step - loss: 642.6859 - mse: 642.6859 - val_loss: 538.4144 - val_mse: 538.4144 - lr: 0.0079
# Epoch 8/140
# 11/11 [==============================] - 1s 86ms/step - loss: 424.5139 - mse: 424.5139 - val_loss: 371.2732 - val_mse: 371.2732 - lr: 0.0073
# Epoch 9/140
# 11/11 [==============================] - 1s 86ms/step - loss: 274.2845 - mse: 274.2845 - val_loss: 259.8809 - val_mse: 259.8809 - lr: 0.0065
# Epoch 10/140
# 11/11 [==============================] - 1s 86ms/step - loss: 177.6550 - mse: 177.6550 - val_loss: 187.6773 - val_mse: 187.6773 - lr: 0.0058
# Epoch 11/140
# 11/11 [==============================] - 1s 85ms/step - loss: 117.1257 - mse: 117.1257 - val_loss: 137.8479 - val_mse: 137.8479 - lr: 0.0050
# Epoch 12/140
# 11/11 [==============================] - 1s 87ms/step - loss: 79.3594 - mse: 79.3594 - val_loss: 109.0037 - val_mse: 109.0037 - lr: 0.0042
# Epoch 13/140
# 11/11 [==============================] - 1s 86ms/step - loss: 56.1385 - mse: 56.1385 - val_loss: 92.1876 - val_mse: 92.1876 - lr: 0.0035
# Epoch 14/140
# 11/11 [==============================] - 1s 87ms/step - loss: 41.9267 - mse: 41.9267 - val_loss: 80.2818 - val_mse: 80.2818 - lr: 0.0027
# Epoch 15/140
# 11/11 [==============================] - 1s 86ms/step - loss: 33.3464 - mse: 33.3464 - val_loss: 71.5901 - val_mse: 71.5901 - lr: 0.0021
# Epoch 16/140
# 11/11 [==============================] - 1s 84ms/step - loss: 28.0984 - mse: 28.0984 - val_loss: 65.8008 - val_mse: 65.8008 - lr: 0.0015
# Epoch 17/140
# 11/11 [==============================] - 1s 85ms/step - loss: 25.2098 - mse: 25.2098 - val_loss: 59.9696 - val_mse: 59.9696 - lr: 9.5492e-04
# Epoch 18/140
# 11/11 [==============================] - 1s 87ms/step - loss: 23.2553 - mse: 23.2553 - val_loss: 54.7569 - val_mse: 54.7569 - lr: 5.4497e-04
# Epoch 19/140
# 11/11 [==============================] - 1s 86ms/step - loss: 22.4766 - mse: 22.4766 - val_loss: 51.0924 - val_mse: 51.0924 - lr: 2.4472e-04
# Epoch 20/140
# 11/11 [==============================] - 1s 86ms/step - loss: 22.0577 - mse: 22.0577 - val_loss: 47.6143 - val_mse: 47.6143 - lr: 6.1558e-05
# Epoch 21/140
# 11/11 [==============================] - 1s 86ms/step - loss: 15.1758 - mse: 15.1758 - val_loss: 38.2806 - val_mse: 38.2806 - lr: 0.0100
# Epoch 22/140
# 11/11 [==============================] - 1s 87ms/step - loss: 6.3550 - mse: 6.3550 - val_loss: 28.0000 - val_mse: 28.0000 - lr: 0.0099
# Epoch 23/140
# 11/11 [==============================] - 1s 86ms/step - loss: 4.9578 - mse: 4.9578 - val_loss: 19.6732 - val_mse: 19.6732 - lr: 0.0098
# Epoch 24/140
# 11/11 [==============================] - 1s 88ms/step - loss: 4.9972 - mse: 4.9972 - val_loss: 16.3580 - val_mse: 16.3580 - lr: 0.0095
# Epoch 25/140
# 11/11 [==============================] - 1s 90ms/step - loss: 4.7561 - mse: 4.7561 - val_loss: 14.1677 - val_mse: 14.1677 - lr: 0.0090
# Epoch 26/140
# 11/11 [==============================] - 1s 86ms/step - loss: 4.4799 - mse: 4.4799 - val_loss: 12.3493 - val_mse: 12.3493 - lr: 0.0085
# Epoch 27/140
# 11/11 [==============================] - 1s 86ms/step - loss: 4.3286 - mse: 4.3286 - val_loss: 10.5611 - val_mse: 10.5611 - lr: 0.0079
# Epoch 28/140
# 11/11 [==============================] - 1s 86ms/step - loss: 4.3454 - mse: 4.3454 - val_loss: 9.4687 - val_mse: 9.4687 - lr: 0.0073
# Epoch 29/140
# 11/11 [==============================] - 1s 87ms/step - loss: 4.2820 - mse: 4.2820 - val_loss: 7.8123 - val_mse: 7.8123 - lr: 0.0065
# Epoch 30/140
# 11/11 [==============================] - 1s 88ms/step - loss: 3.9835 - mse: 3.9835 - val_loss: 7.3353 - val_mse: 7.3353 - lr: 0.0058
# Epoch 31/140
# 11/11 [==============================] - 1s 87ms/step - loss: 3.9129 - mse: 3.9129 - val_loss: 6.6948 - val_mse: 6.6948 - lr: 0.0050
# Epoch 32/140
# 11/11 [==============================] - 1s 86ms/step - loss: 3.8448 - mse: 3.8448 - val_loss: 6.0727 - val_mse: 6.0727 - lr: 0.0042
# Epoch 33/140
# 11/11 [==============================] - 1s 88ms/step - loss: 3.8307 - mse: 3.8307 - val_loss: 5.8237 - val_mse: 5.8237 - lr: 0.0035
# Epoch 34/140
# 11/11 [==============================] - 1s 86ms/step - loss: 3.7585 - mse: 3.7585 - val_loss: 5.4692 - val_mse: 5.4692 - lr: 0.0027
# Epoch 35/140
# 11/11 [==============================] - 1s 88ms/step - loss: 3.7386 - mse: 3.7386 - val_loss: 5.0319 - val_mse: 5.0319 - lr: 0.0021
# Epoch 36/140
# 11/11 [==============================] - 1s 86ms/step - loss: 3.6304 - mse: 3.6304 - val_loss: 4.9013 - val_mse: 4.9013 - lr: 0.0015
# Epoch 37/140
# 11/11 [==============================] - 1s 87ms/step - loss: 3.6375 - mse: 3.6375 - val_loss: 4.7672 - val_mse: 4.7672 - lr: 9.5492e-04
# Epoch 38/140
# 11/11 [==============================] - 1s 88ms/step - loss: 3.6125 - mse: 3.6125 - val_loss: 4.5961 - val_mse: 4.5961 - lr: 5.4497e-04
# Epoch 39/140
# 11/11 [==============================] - 1s 85ms/step - loss: 3.6194 - mse: 3.6194 - val_loss: 4.4896 - val_mse: 4.4896 - lr: 2.4472e-04
# Epoch 40/140
# 11/11 [==============================] - 1s 88ms/step - loss: 3.5695 - mse: 3.5695 - val_loss: 4.4009 - val_mse: 4.4009 - lr: 6.1558e-05
# Epoch 41/140
# 11/11 [==============================] - 1s 87ms/step - loss: 3.8521 - mse: 3.8521 - val_loss: 4.5431 - val_mse: 4.5431 - lr: 0.0100
# Epoch 42/140
# 11/11 [==============================] - 1s 87ms/step - loss: 3.9058 - mse: 3.9058 - val_loss: 4.4559 - val_mse: 4.4559 - lr: 0.0099
# Epoch 43/140
# 11/11 [==============================] - 1s 89ms/step - loss: 4.1002 - mse: 4.1002 - val_loss: 4.4494 - val_mse: 4.4494 - lr: 0.0098
# Epoch 44/140
# 11/11 [==============================] - 1s 86ms/step - loss: 3.9364 - mse: 3.9364 - val_loss: 4.3424 - val_mse: 4.3424 - lr: 0.0095
# Epoch 45/140
# 11/11 [==============================] - 1s 87ms/step - loss: 3.7999 - mse: 3.7999 - val_loss: 4.5467 - val_mse: 4.5467 - lr: 0.0090
# Epoch 46/140
# 11/11 [==============================] - 1s 86ms/step - loss: 3.8690 - mse: 3.8690 - val_loss: 4.2860 - val_mse: 4.2860 - lr: 0.0085
# Epoch 47/140
# 11/11 [==============================] - 1s 87ms/step - loss: 3.8256 - mse: 3.8256 - val_loss: 4.3652 - val_mse: 4.3652 - lr: 0.0079
# Epoch 48/140
# 11/11 [==============================] - 1s 87ms/step - loss: 3.7318 - mse: 3.7318 - val_loss: 4.2980 - val_mse: 4.2980 - lr: 0.0073
# Epoch 49/140
# 11/11 [==============================] - 1s 86ms/step - loss: 3.6995 - mse: 3.6995 - val_loss: 4.1318 - val_mse: 4.1318 - lr: 0.0065
# Epoch 50/140
# 11/11 [==============================] - 1s 85ms/step - loss: 3.5774 - mse: 3.5774 - val_loss: 4.1567 - val_mse: 4.1567 - lr: 0.0058
# Epoch 51/140
# 11/11 [==============================] - 1s 88ms/step - loss: 3.5993 - mse: 3.5993 - val_loss: 4.0637 - val_mse: 4.0637 - lr: 0.0050
# Epoch 52/140
# 11/11 [==============================] - 1s 87ms/step - loss: 3.4278 - mse: 3.4278 - val_loss: 4.1328 - val_mse: 4.1328 - lr: 0.0042
# Epoch 53/140
# 11/11 [==============================] - 1s 86ms/step - loss: 3.4386 - mse: 3.4386 - val_loss: 4.1082 - val_mse: 4.1082 - lr: 0.0035
# Epoch 54/140
# 11/11 [==============================] - 1s 86ms/step - loss: 3.3822 - mse: 3.3822 - val_loss: 4.0346 - val_mse: 4.0346 - lr: 0.0027
# Epoch 55/140
# 11/11 [==============================] - 1s 88ms/step - loss: 3.3318 - mse: 3.3318 - val_loss: 3.9867 - val_mse: 3.9867 - lr: 0.0021
# Epoch 56/140
# 11/11 [==============================] - 1s 89ms/step - loss: 3.5247 - mse: 3.5247 - val_loss: 4.0128 - val_mse: 4.0128 - lr: 0.0015
# Epoch 57/140
# 11/11 [==============================] - 1s 87ms/step - loss: 3.2319 - mse: 3.2319 - val_loss: 3.9905 - val_mse: 3.9905 - lr: 9.5492e-04
# Epoch 58/140
# 11/11 [==============================] - 1s 86ms/step - loss: 3.2198 - mse: 3.2198 - val_loss: 3.9565 - val_mse: 3.9565 - lr: 5.4497e-04
# Epoch 59/140
# 11/11 [==============================] - 1s 86ms/step - loss: 3.2352 - mse: 3.2352 - val_loss: 3.9511 - val_mse: 3.9511 - lr: 2.4472e-04
# Epoch 60/140
# 11/11 [==============================] - 1s 88ms/step - loss: 3.2855 - mse: 3.2855 - val_loss: 3.9481 - val_mse: 3.9481 - lr: 6.1558e-05
# Epoch 61/140
# 11/11 [==============================] - 1s 88ms/step - loss: 3.5374 - mse: 3.5374 - val_loss: 4.2867 - val_mse: 4.2867 - lr: 0.0100
# Epoch 62/140
# 11/11 [==============================] - 1s 85ms/step - loss: 3.8915 - mse: 3.8915 - val_loss: 4.5102 - val_mse: 4.5102 - lr: 0.0099
# Epoch 63/140
# 11/11 [==============================] - 1s 86ms/step - loss: 3.8171 - mse: 3.8171 - val_loss: 4.3682 - val_mse: 4.3682 - lr: 0.0098
# Epoch 64/140
# 11/11 [==============================] - 1s 88ms/step - loss: 3.8249 - mse: 3.8249 - val_loss: 4.3206 - val_mse: 4.3206 - lr: 0.0095
# Epoch 65/140
# 11/11 [==============================] - 1s 90ms/step - loss: 3.8019 - mse: 3.8019 - val_loss: 4.3243 - val_mse: 4.3243 - lr: 0.0090
# Epoch 66/140
# 11/11 [==============================] - 1s 87ms/step - loss: 3.7596 - mse: 3.7596 - val_loss: 4.5389 - val_mse: 4.5389 - lr: 0.0085
# Epoch 67/140
# 11/11 [==============================] - 1s 88ms/step - loss: 3.7816 - mse: 3.7816 - val_loss: 4.5089 - val_mse: 4.5089 - lr: 0.0079
# Epoch 68/140
# 11/11 [==============================] - 1s 87ms/step - loss: 3.7079 - mse: 3.7079 - val_loss: 4.1960 - val_mse: 4.1960 - lr: 0.0073
# Epoch 69/140
# 11/11 [==============================] - 1s 88ms/step - loss: 3.6840 - mse: 3.6840 - val_loss: 4.2829 - val_mse: 4.2829 - lr: 0.0065
# Epoch 70/140
# 11/11 [==============================] - 1s 87ms/step - loss: 3.6497 - mse: 3.6497 - val_loss: 4.3607 - val_mse: 4.3607 - lr: 0.0058
# Epoch 71/140
# 11/11 [==============================] - 1s 89ms/step - loss: 3.4728 - mse: 3.4728 - val_loss: 4.2446 - val_mse: 4.2446 - lr: 0.0050
# Epoch 72/140
# 11/11 [==============================] - 1s 86ms/step - loss: 3.3870 - mse: 3.3870 - val_loss: 4.0775 - val_mse: 4.0775 - lr: 0.0042
# Epoch 73/140
# 11/11 [==============================] - 1s 85ms/step - loss: 3.3743 - mse: 3.3743 - val_loss: 4.0741 - val_mse: 4.0741 - lr: 0.0035
# Epoch 74/140
# 11/11 [==============================] - 1s 86ms/step - loss: 3.3199 - mse: 3.3199 - val_loss: 4.0259 - val_mse: 4.0259 - lr: 0.0027
# Epoch 75/140
# 11/11 [==============================] - 1s 87ms/step - loss: 3.3620 - mse: 3.3620 - val_loss: 4.0291 - val_mse: 4.0291 - lr: 0.0021
# Epoch 76/140
# 11/11 [==============================] - 1s 86ms/step - loss: 3.2064 - mse: 3.2064 - val_loss: 3.9701 - val_mse: 3.9701 - lr: 0.0015
# Epoch 77/140
# 11/11 [==============================] - 1s 87ms/step - loss: 3.1720 - mse: 3.1720 - val_loss: 3.9590 - val_mse: 3.9590 - lr: 9.5492e-04
# Epoch 78/140
# 11/11 [==============================] - 1s 88ms/step - loss: 3.1813 - mse: 3.1813 - val_loss: 3.9437 - val_mse: 3.9437 - lr: 5.4497e-04
# Epoch 79/140
# 11/11 [==============================] - 1s 86ms/step - loss: 3.1853 - mse: 3.1853 - val_loss: 3.9384 - val_mse: 3.9384 - lr: 2.4472e-04
# Epoch 80/140
# 11/11 [==============================] - 1s 88ms/step - loss: 3.2576 - mse: 3.2576 - val_loss: 3.9334 - val_mse: 3.9334 - lr: 6.1558e-05
# Epoch 81/140
# 11/11 [==============================] - 1s 87ms/step - loss: 3.2961 - mse: 3.2961 - val_loss: 4.1894 - val_mse: 4.1894 - lr: 0.0100
# Epoch 82/140
# 11/11 [==============================] - 1s 88ms/step - loss: 3.5058 - mse: 3.5058 - val_loss: 4.2021 - val_mse: 4.2021 - lr: 0.0099
# Epoch 83/140
# 11/11 [==============================] - 1s 88ms/step - loss: 3.6043 - mse: 3.6043 - val_loss: 4.1460 - val_mse: 4.1460 - lr: 0.0098
# Epoch 84/140
# 11/11 [==============================] - 1s 88ms/step - loss: 3.7125 - mse: 3.7125 - val_loss: 4.3549 - val_mse: 4.3549 - lr: 0.0095
# Epoch 85/140
# 11/11 [==============================] - 1s 89ms/step - loss: 3.7574 - mse: 3.7574 - val_loss: 4.2795 - val_mse: 4.2795 - lr: 0.0090
# Epoch 86/140
# 11/11 [==============================] - 1s 89ms/step - loss: 3.7620 - mse: 3.7620 - val_loss: 4.4400 - val_mse: 4.4400 - lr: 0.0085
# Epoch 87/140
# 11/11 [==============================] - 1s 87ms/step - loss: 3.6880 - mse: 3.6880 - val_loss: 4.1806 - val_mse: 4.1806 - lr: 0.0079
# Epoch 88/140
# 11/11 [==============================] - 1s 90ms/step - loss: 3.5657 - mse: 3.5657 - val_loss: 4.2005 - val_mse: 4.2005 - lr: 0.0073
# Epoch 89/140
# 11/11 [==============================] - 1s 86ms/step - loss: 3.5036 - mse: 3.5036 - val_loss: 4.1559 - val_mse: 4.1559 - lr: 0.0065
# Epoch 90/140
# 11/11 [==============================] - 1s 86ms/step - loss: 3.4466 - mse: 3.4466 - val_loss: 4.2208 - val_mse: 4.2208 - lr: 0.0058
# Epoch 91/140
# 11/11 [==============================] - 1s 87ms/step - loss: 3.4861 - mse: 3.4861 - val_loss: 4.1154 - val_mse: 4.1154 - lr: 0.0050
# Epoch 92/140
# 11/11 [==============================] - 1s 88ms/step - loss: 3.2633 - mse: 3.2633 - val_loss: 4.1914 - val_mse: 4.1914 - lr: 0.0042
# Epoch 93/140
# 11/11 [==============================] - 1s 89ms/step - loss: 3.3043 - mse: 3.3043 - val_loss: 4.0492 - val_mse: 4.0492 - lr: 0.0035
# Epoch 94/140
# 11/11 [==============================] - 1s 87ms/step - loss: 3.1701 - mse: 3.1701 - val_loss: 4.1012 - val_mse: 4.1012 - lr: 0.0027
# Epoch 95/140
# 11/11 [==============================] - 1s 88ms/step - loss: 3.2534 - mse: 3.2534 - val_loss: 3.9920 - val_mse: 3.9920 - lr: 0.0021
# Epoch 96/140
# 11/11 [==============================] - 1s 88ms/step - loss: 3.1836 - mse: 3.1836 - val_loss: 3.9818 - val_mse: 3.9818 - lr: 0.0015
# Epoch 97/140
# 11/11 [==============================] - 1s 89ms/step - loss: 3.1106 - mse: 3.1106 - val_loss: 3.9396 - val_mse: 3.9396 - lr: 9.5492e-04
# Epoch 98/140
# 11/11 [==============================] - 1s 87ms/step - loss: 3.0527 - mse: 3.0527 - val_loss: 3.9508 - val_mse: 3.9508 - lr: 5.4497e-04
# Epoch 99/140
# 11/11 [==============================] - 1s 89ms/step - loss: 3.1091 - mse: 3.1091 - val_loss: 3.9415 - val_mse: 3.9415 - lr: 2.4472e-04
# Epoch 100/140
# 11/11 [==============================] - 1s 87ms/step - loss: 3.0869 - mse: 3.0869 - val_loss: 3.9368 - val_mse: 3.9368 - lr: 6.1558e-05
# Epoch 101/140
# 11/11 [==============================] - 1s 87ms/step - loss: 3.2401 - mse: 3.2401 - val_loss: 4.0640 - val_mse: 4.0640 - lr: 0.0100
# Epoch 102/140
# 11/11 [==============================] - 1s 86ms/step - loss: 3.4110 - mse: 3.4110 - val_loss: 4.3328 - val_mse: 4.3328 - lr: 0.0099
# Epoch 103/140
# 11/11 [==============================] - 1s 86ms/step - loss: 3.4310 - mse: 3.4310 - val_loss: 4.1809 - val_mse: 4.1809 - lr: 0.0098
# Epoch 104/140
# 11/11 [==============================] - 1s 86ms/step - loss: 3.3389 - mse: 3.3389 - val_loss: 4.1738 - val_mse: 4.1738 - lr: 0.0095
# Epoch 105/140
# 11/11 [==============================] - 1s 87ms/step - loss: 3.3792 - mse: 3.3792 - val_loss: 4.1313 - val_mse: 4.1313 - lr: 0.0090
# Epoch 106/140
# 11/11 [==============================] - 1s 87ms/step - loss: 3.4709 - mse: 3.4709 - val_loss: 4.2892 - val_mse: 4.2892 - lr: 0.0085
# Epoch 107/140
# 11/11 [==============================] - 1s 87ms/step - loss: 3.3731 - mse: 3.3731 - val_loss: 4.1308 - val_mse: 4.1308 - lr: 0.0079
# Epoch 108/140
# 11/11 [==============================] - 1s 89ms/step - loss: 3.3616 - mse: 3.3616 - val_loss: 4.2750 - val_mse: 4.2750 - lr: 0.0073
# Epoch 109/140
# 11/11 [==============================] - 1s 86ms/step - loss: 3.2878 - mse: 3.2878 - val_loss: 4.1561 - val_mse: 4.1561 - lr: 0.0065
# Epoch 110/140
# 11/11 [==============================] - 1s 88ms/step - loss: 3.2253 - mse: 3.2253 - val_loss: 4.0520 - val_mse: 4.0520 - lr: 0.0058
# Epoch 111/140
# 11/11 [==============================] - 1s 88ms/step - loss: 3.2124 - mse: 3.2124 - val_loss: 4.1645 - val_mse: 4.1645 - lr: 0.0050
# Epoch 112/140
# 11/11 [==============================] - 1s 87ms/step - loss: 3.1379 - mse: 3.1379 - val_loss: 4.0569 - val_mse: 4.0569 - lr: 0.0042
# Epoch 113/140
# 11/11 [==============================] - 1s 87ms/step - loss: 3.1177 - mse: 3.1177 - val_loss: 4.0402 - val_mse: 4.0402 - lr: 0.0035
# Epoch 114/140
# 11/11 [==============================] - 1s 86ms/step - loss: 3.0198 - mse: 3.0198 - val_loss: 4.0134 - val_mse: 4.0134 - lr: 0.0027
# Epoch 115/140
# 11/11 [==============================] - 1s 85ms/step - loss: 3.0767 - mse: 3.0767 - val_loss: 4.0252 - val_mse: 4.0252 - lr: 0.0021
# Epoch 116/140
# 11/11 [==============================] - 1s 88ms/step - loss: 2.9356 - mse: 2.9356 - val_loss: 4.0192 - val_mse: 4.0192 - lr: 0.0015
# Epoch 117/140
# 11/11 [==============================] - 1s 88ms/step - loss: 2.9677 - mse: 2.9677 - val_loss: 4.0115 - val_mse: 4.0115 - lr: 9.5492e-04
# Epoch 118/140
# 11/11 [==============================] - 1s 89ms/step - loss: 2.9141 - mse: 2.9141 - val_loss: 4.0015 - val_mse: 4.0015 - lr: 5.4497e-04
# Epoch 119/140
# 11/11 [==============================] - 1s 87ms/step - loss: 2.8757 - mse: 2.8757 - val_loss: 3.9947 - val_mse: 3.9947 - lr: 2.4472e-04
# Epoch 120/140
# 11/11 [==============================] - 1s 87ms/step - loss: 2.8576 - mse: 2.8576 - val_loss: 3.9930 - val_mse: 3.9930 - lr: 6.1558e-05
# Epoch 121/140
# 11/11 [==============================] - 1s 87ms/step - loss: 2.9636 - mse: 2.9636 - val_loss: 4.0465 - val_mse: 4.0465 - lr: 0.0100
# Epoch 122/140
# 11/11 [==============================] - 1s 89ms/step - loss: 3.1282 - mse: 3.1282 - val_loss: 3.9971 - val_mse: 3.9971 - lr: 0.0099
# Epoch 123/140
# 11/11 [==============================] - 1s 88ms/step - loss: 3.2691 - mse: 3.2691 - val_loss: 4.1213 - val_mse: 4.1213 - lr: 0.0098
# Epoch 124/140
# 11/11 [==============================] - 1s 88ms/step - loss: 3.3790 - mse: 3.3790 - val_loss: 4.2078 - val_mse: 4.2078 - lr: 0.0095
# Epoch 125/140
# 11/11 [==============================] - 1s 88ms/step - loss: 3.3483 - mse: 3.3483 - val_loss: 4.2564 - val_mse: 4.2564 - lr: 0.0090
# Epoch 126/140
# 11/11 [==============================] - 1s 88ms/step - loss: 3.4121 - mse: 3.4121 - val_loss: 4.2518 - val_mse: 4.2518 - lr: 0.0085
# Epoch 127/140
# 11/11 [==============================] - 1s 89ms/step - loss: 3.6527 - mse: 3.6527 - val_loss: 4.1806 - val_mse: 4.1806 - lr: 0.0079
# Epoch 128/140
# 11/11 [==============================] - 1s 87ms/step - loss: 3.3589 - mse: 3.3589 - val_loss: 4.2002 - val_mse: 4.2002 - lr: 0.0073
# Epoch 129/140
# 11/11 [==============================] - 1s 86ms/step - loss: 3.2870 - mse: 3.2870 - val_loss: 4.2158 - val_mse: 4.2158 - lr: 0.0065
# Epoch 130/140
# 11/11 [==============================] - 1s 88ms/step - loss: 3.2886 - mse: 3.2886 - val_loss: 4.2026 - val_mse: 4.2026 - lr: 0.0058
# Epoch 131/140
# 11/11 [==============================] - 1s 88ms/step - loss: 3.2649 - mse: 3.2649 - val_loss: 4.0852 - val_mse: 4.0852 - lr: 0.0050
# Epoch 132/140
# 11/11 [==============================] - 1s 88ms/step - loss: 3.1804 - mse: 3.1804 - val_loss: 3.9962 - val_mse: 3.9962 - lr: 0.0042
# Epoch 133/140
# 11/11 [==============================] - 1s 89ms/step - loss: 3.0563 - mse: 3.0563 - val_loss: 4.0474 - val_mse: 4.0474 - lr: 0.0035
# Epoch 134/140
# 11/11 [==============================] - 1s 91ms/step - loss: 3.0808 - mse: 3.0808 - val_loss: 3.9149 - val_mse: 3.9149 - lr: 0.0027
# Epoch 135/140
# 11/11 [==============================] - 1s 87ms/step - loss: 3.0234 - mse: 3.0234 - val_loss: 3.8854 - val_mse: 3.8854 - lr: 0.0021
# Epoch 136/140
# 11/11 [==============================] - 1s 86ms/step - loss: 2.9203 - mse: 2.9203 - val_loss: 3.8945 - val_mse: 3.8945 - lr: 0.0015
# Epoch 137/140
# 11/11 [==============================] - 1s 85ms/step - loss: 2.9510 - mse: 2.9510 - val_loss: 3.8936 - val_mse: 3.8936 - lr: 9.5492e-04
# Epoch 138/140
# 11/11 [==============================] - 1s 86ms/step - loss: 2.9764 - mse: 2.9764 - val_loss: 3.8799 - val_mse: 3.8799 - lr: 5.4497e-04
# Epoch 139/140
# 11/11 [==============================] - 1s 89ms/step - loss: 2.9453 - mse: 2.9453 - val_loss: 3.8717 - val_mse: 3.8717 - lr: 2.4472e-04
# Epoch 140/140
# 11/11 [==============================] - 1s 89ms/step - loss: 2.8844 - mse: 2.8844 - val_loss: 3.8680 - val_mse: 3.8680 - lr: 6.1558e-05
# Epoch 1/140
# 11/11 [==============================] - 1s 91ms/step - loss: 2.8919 - mse: 2.8919 - val_loss: 3.8955 - val_mse: 3.8955 - lr: 0.0010
# Epoch 2/140
# 11/11 [==============================] - 1s 90ms/step - loss: 2.9106 - mse: 2.9106 - val_loss: 3.8994 - val_mse: 3.8994 - lr: 9.9384e-04
# Epoch 3/140
# 11/11 [==============================] - 1s 89ms/step - loss: 2.8679 - mse: 2.8679 - val_loss: 3.8671 - val_mse: 3.8671 - lr: 9.7553e-04
# Epoch 4/140
# 11/11 [==============================] - 1s 88ms/step - loss: 2.9804 - mse: 2.9804 - val_loss: 3.8661 - val_mse: 3.8661 - lr: 9.4550e-04
# Epoch 5/140
# 11/11 [==============================] - 1s 90ms/step - loss: 2.7608 - mse: 2.7608 - val_loss: 3.8643 - val_mse: 3.8643 - lr: 9.0451e-04
# Epoch 6/140
# 11/11 [==============================] - 1s 89ms/step - loss: 2.8828 - mse: 2.8828 - val_loss: 3.8721 - val_mse: 3.8721 - lr: 8.5355e-04
# Epoch 7/140
# 11/11 [==============================] - 1s 90ms/step - loss: 2.9363 - mse: 2.9363 - val_loss: 3.8713 - val_mse: 3.8713 - lr: 7.9389e-04
# Epoch 8/140
# 11/11 [==============================] - 1s 90ms/step - loss: 2.8068 - mse: 2.8068 - val_loss: 3.8569 - val_mse: 3.8569 - lr: 7.2700e-04
# Epoch 9/140
# 11/11 [==============================] - 1s 90ms/step - loss: 2.7716 - mse: 2.7716 - val_loss: 3.8661 - val_mse: 3.8661 - lr: 6.5451e-04
# Epoch 10/140
# 11/11 [==============================] - 1s 89ms/step - loss: 2.8332 - mse: 2.8332 - val_loss: 3.8773 - val_mse: 3.8773 - lr: 5.7822e-04
# Epoch 11/140
# 11/11 [==============================] - 1s 89ms/step - loss: 2.8729 - mse: 2.8729 - val_loss: 3.8703 - val_mse: 3.8703 - lr: 5.0000e-04
# Epoch 12/140
# 11/11 [==============================] - 1s 88ms/step - loss: 2.7506 - mse: 2.7506 - val_loss: 3.8650 - val_mse: 3.8650 - lr: 4.2178e-04
# Epoch 13/140
# 11/11 [==============================] - 1s 87ms/step - loss: 2.8791 - mse: 2.8791 - val_loss: 3.8722 - val_mse: 3.8722 - lr: 3.4549e-04
# Epoch 14/140
# 11/11 [==============================] - 1s 87ms/step - loss: 2.9143 - mse: 2.9143 - val_loss: 3.8620 - val_mse: 3.8620 - lr: 2.7300e-04
# Epoch 15/140
# 11/11 [==============================] - 1s 88ms/step - loss: 2.7543 - mse: 2.7543 - val_loss: 3.8592 - val_mse: 3.8592 - lr: 2.0611e-04
# Epoch 16/140
# 11/11 [==============================] - 1s 87ms/step - loss: 2.8794 - mse: 2.8794 - val_loss: 3.8632 - val_mse: 3.8632 - lr: 1.4645e-04
# Epoch 17/140
# 11/11 [==============================] - 1s 88ms/step - loss: 2.7784 - mse: 2.7784 - val_loss: 3.8617 - val_mse: 3.8617 - lr: 9.5492e-05
# Epoch 18/140
# 11/11 [==============================] - 1s 89ms/step - loss: 2.8351 - mse: 2.8351 - val_loss: 3.8626 - val_mse: 3.8626 - lr: 5.4497e-05
# Epoch 19/140
# 11/11 [==============================] - 1s 89ms/step - loss: 2.9068 - mse: 2.9068 - val_loss: 3.8621 - val_mse: 3.8621 - lr: 2.4472e-05
# Epoch 20/140
# 11/11 [==============================] - 1s 87ms/step - loss: 2.8169 - mse: 2.8169 - val_loss: 3.8614 - val_mse: 3.8614 - lr: 6.1558e-06
# Epoch 21/140
# 11/11 [==============================] - 1s 89ms/step - loss: 2.8630 - mse: 2.8630 - val_loss: 3.8472 - val_mse: 3.8472 - lr: 0.0010
# Epoch 22/140
# 11/11 [==============================] - 1s 89ms/step - loss: 2.7765 - mse: 2.7765 - val_loss: 3.8626 - val_mse: 3.8626 - lr: 9.9384e-04
# Epoch 23/140
# 11/11 [==============================] - 1s 89ms/step - loss: 2.8636 - mse: 2.8636 - val_loss: 3.8657 - val_mse: 3.8657 - lr: 9.7553e-04
# Epoch 24/140
# 11/11 [==============================] - 1s 88ms/step - loss: 2.8002 - mse: 2.8002 - val_loss: 3.8837 - val_mse: 3.8837 - lr: 9.4550e-04
# Epoch 25/140
# 11/11 [==============================] - 1s 90ms/step - loss: 2.7985 - mse: 2.7985 - val_loss: 3.8689 - val_mse: 3.8689 - lr: 9.0451e-04
# Epoch 26/140
# 11/11 [==============================] - 1s 90ms/step - loss: 2.7777 - mse: 2.7777 - val_loss: 3.8756 - val_mse: 3.8756 - lr: 8.5355e-04
# Epoch 27/140
# 11/11 [==============================] - 1s 91ms/step - loss: 2.9768 - mse: 2.9768 - val_loss: 3.8785 - val_mse: 3.8785 - lr: 7.9389e-04
# Epoch 28/140
# 11/11 [==============================] - 1s 88ms/step - loss: 2.7320 - mse: 2.7320 - val_loss: 3.8749 - val_mse: 3.8749 - lr: 7.2700e-04
# Epoch 29/140
# 11/11 [==============================] - 1s 90ms/step - loss: 2.8203 - mse: 2.8203 - val_loss: 3.8590 - val_mse: 3.8590 - lr: 6.5451e-04
# Epoch 30/140
# 11/11 [==============================] - 1s 91ms/step - loss: 2.7762 - mse: 2.7762 - val_loss: 3.8723 - val_mse: 3.8723 - lr: 5.7822e-04
# Epoch 31/140
# 11/11 [==============================] - 1s 91ms/step - loss: 2.7687 - mse: 2.7687 - val_loss: 3.8887 - val_mse: 3.8887 - lr: 5.0000e-04
# Epoch 32/140
# 11/11 [==============================] - 1s 89ms/step - loss: 2.7621 - mse: 2.7621 - val_loss: 3.8919 - val_mse: 3.8919 - lr: 4.2178e-04
# Epoch 33/140
# 11/11 [==============================] - 1s 89ms/step - loss: 2.7843 - mse: 2.7843 - val_loss: 3.8843 - val_mse: 3.8843 - lr: 3.4549e-04
# Epoch 34/140
# 11/11 [==============================] - 1s 88ms/step - loss: 2.6759 - mse: 2.6759 - val_loss: 3.8751 - val_mse: 3.8751 - lr: 2.7300e-04
# Epoch 35/140
# 11/11 [==============================] - 1s 87ms/step - loss: 2.6750 - mse: 2.6750 - val_loss: 3.8746 - val_mse: 3.8746 - lr: 2.0611e-04
# Epoch 36/140
# 11/11 [==============================] - 1s 89ms/step - loss: 2.7634 - mse: 2.7634 - val_loss: 3.8756 - val_mse: 3.8756 - lr: 1.4645e-04
# Epoch 37/140
# 11/11 [==============================] - 1s 87ms/step - loss: 2.7663 - mse: 2.7663 - val_loss: 3.8766 - val_mse: 3.8766 - lr: 9.5492e-05
# Epoch 38/140
# 11/11 [==============================] - 1s 91ms/step - loss: 2.7824 - mse: 2.7824 - val_loss: 3.8785 - val_mse: 3.8785 - lr: 5.4497e-05
# Epoch 39/140
# 11/11 [==============================] - 1s 88ms/step - loss: 2.7572 - mse: 2.7572 - val_loss: 3.8766 - val_mse: 3.8766 - lr: 2.4472e-05
# Epoch 40/140
# 11/11 [==============================] - 1s 91ms/step - loss: 2.7713 - mse: 2.7713 - val_loss: 3.8765 - val_mse: 3.8765 - lr: 6.1558e-06
# Epoch 41/140
# 11/11 [==============================] - 1s 88ms/step - loss: 2.7449 - mse: 2.7449 - val_loss: 3.8788 - val_mse: 3.8788 - lr: 0.0010
# Epoch 42/140
# 11/11 [==============================] - 1s 88ms/step - loss: 2.6796 - mse: 2.6796 - val_loss: 3.8730 - val_mse: 3.8730 - lr: 9.9384e-04
# Epoch 43/140
# 11/11 [==============================] - 1s 91ms/step - loss: 2.7894 - mse: 2.7894 - val_loss: 3.8647 - val_mse: 3.8647 - lr: 9.7553e-04
# Epoch 44/140
# 11/11 [==============================] - 1s 89ms/step - loss: 2.7380 - mse: 2.7380 - val_loss: 3.8549 - val_mse: 3.8549 - lr: 9.4550e-04
# Epoch 45/140
# 11/11 [==============================] - 1s 88ms/step - loss: 2.7627 - mse: 2.7627 - val_loss: 3.8513 - val_mse: 3.8513 - lr: 9.0451e-04
# Epoch 46/140
# 11/11 [==============================] - 1s 92ms/step - loss: 2.7188 - mse: 2.7188 - val_loss: 3.8720 - val_mse: 3.8720 - lr: 8.5355e-04
# Epoch 47/140
# 11/11 [==============================] - 1s 90ms/step - loss: 2.6716 - mse: 2.6716 - val_loss: 3.8853 - val_mse: 3.8853 - lr: 7.9389e-04
# Epoch 48/140
# 11/11 [==============================] - 1s 90ms/step - loss: 2.6746 - mse: 2.6746 - val_loss: 3.8636 - val_mse: 3.8636 - lr: 7.2700e-04
# Epoch 49/140
# 11/11 [==============================] - 1s 92ms/step - loss: 2.8019 - mse: 2.8019 - val_loss: 3.8787 - val_mse: 3.8787 - lr: 6.5451e-04
# Epoch 50/140
# 11/11 [==============================] - 1s 90ms/step - loss: 2.7272 - mse: 2.7272 - val_loss: 3.8694 - val_mse: 3.8694 - lr: 5.7822e-04
# Epoch 51/140
# 11/11 [==============================] - 1s 90ms/step - loss: 2.6774 - mse: 2.6774 - val_loss: 3.8941 - val_mse: 3.8941 - lr: 5.0000e-04
# Epoch 52/140
# 11/11 [==============================] - 1s 88ms/step - loss: 2.7731 - mse: 2.7731 - val_loss: 3.8844 - val_mse: 3.8844 - lr: 4.2178e-04
# Epoch 53/140
# 11/11 [==============================] - 1s 89ms/step - loss: 2.8170 - mse: 2.8170 - val_loss: 3.8745 - val_mse: 3.8745 - lr: 3.4549e-04
# Epoch 54/140
# 11/11 [==============================] - 1s 88ms/step - loss: 2.7527 - mse: 2.7527 - val_loss: 3.8728 - val_mse: 3.8728 - lr: 2.7300e-04
# Epoch 55/140
# 11/11 [==============================] - 1s 90ms/step - loss: 2.7121 - mse: 2.7121 - val_loss: 3.8701 - val_mse: 3.8701 - lr: 2.0611e-04
# Epoch 56/140
# 11/11 [==============================] - 1s 88ms/step - loss: 2.6756 - mse: 2.6756 - val_loss: 3.8663 - val_mse: 3.8663 - lr: 1.4645e-04
# Epoch 57/140
# 11/11 [==============================] - 1s 89ms/step - loss: 2.7335 - mse: 2.7335 - val_loss: 3.8689 - val_mse: 3.8689 - lr: 9.5492e-05
# Epoch 58/140
# 11/11 [==============================] - 1s 89ms/step - loss: 2.8397 - mse: 2.8397 - val_loss: 3.8692 - val_mse: 3.8692 - lr: 5.4497e-05
# Epoch 59/140
# 11/11 [==============================] - 1s 88ms/step - loss: 2.7372 - mse: 2.7372 - val_loss: 3.8694 - val_mse: 3.8694 - lr: 2.4472e-05
# Epoch 60/140
# 11/11 [==============================] - 1s 89ms/step - loss: 2.7416 - mse: 2.7416 - val_loss: 3.8695 - val_mse: 3.8695 - lr: 6.1558e-06
# Epoch 61/140
# 11/11 [==============================] - 1s 90ms/step - loss: 2.7706 - mse: 2.7706 - val_loss: 3.8755 - val_mse: 3.8755 - lr: 0.0010
# Epoch 62/140
# 11/11 [==============================] - 1s 89ms/step - loss: 2.7163 - mse: 2.7163 - val_loss: 3.9002 - val_mse: 3.9002 - lr: 9.9384e-04
# Epoch 63/140
# 11/11 [==============================] - 1s 89ms/step - loss: 2.6643 - mse: 2.6643 - val_loss: 3.8679 - val_mse: 3.8679 - lr: 9.7553e-04
# Epoch 64/140
# 11/11 [==============================] - 1s 89ms/step - loss: 2.6864 - mse: 2.6864 - val_loss: 3.8878 - val_mse: 3.8878 - lr: 9.4550e-04
# Epoch 65/140
# 11/11 [==============================] - 1s 90ms/step - loss: 2.6441 - mse: 2.6441 - val_loss: 3.8648 - val_mse: 3.8648 - lr: 9.0451e-04
# Epoch 66/140
# 11/11 [==============================] - 1s 89ms/step - loss: 2.6773 - mse: 2.6773 - val_loss: 3.8790 - val_mse: 3.8790 - lr: 8.5355e-04
# Epoch 67/140
# 11/11 [==============================] - 1s 89ms/step - loss: 2.8042 - mse: 2.8042 - val_loss: 3.8772 - val_mse: 3.8772 - lr: 7.9389e-04
# Epoch 68/140
# 11/11 [==============================] - 1s 91ms/step - loss: 2.6743 - mse: 2.6743 - val_loss: 3.8829 - val_mse: 3.8829 - lr: 7.2700e-04
# Epoch 69/140
# 11/11 [==============================] - 1s 89ms/step - loss: 2.7144 - mse: 2.7144 - val_loss: 3.8771 - val_mse: 3.8771 - lr: 6.5451e-04
# Epoch 70/140
# 11/11 [==============================] - 1s 91ms/step - loss: 2.7076 - mse: 2.7076 - val_loss: 3.8593 - val_mse: 3.8593 - lr: 5.7822e-04
# Epoch 71/140
# 11/11 [==============================] - 1s 90ms/step - loss: 2.7263 - mse: 2.7263 - val_loss: 3.8752 - val_mse: 3.8752 - lr: 5.0000e-04
# Epoch 72/140
# 11/11 [==============================] - 1s 91ms/step - loss: 2.5933 - mse: 2.5933 - val_loss: 3.8715 - val_mse: 3.8715 - lr: 4.2178e-04
# Epoch 73/140
# 11/11 [==============================] - 1s 90ms/step - loss: 2.7644 - mse: 2.7644 - val_loss: 3.8695 - val_mse: 3.8695 - lr: 3.4549e-04
# Epoch 74/140
# 11/11 [==============================] - 1s 90ms/step - loss: 2.6114 - mse: 2.6114 - val_loss: 3.8675 - val_mse: 3.8675 - lr: 2.7300e-04
# Epoch 75/140
# 11/11 [==============================] - 1s 90ms/step - loss: 2.6560 - mse: 2.6560 - val_loss: 3.8732 - val_mse: 3.8732 - lr: 2.0611e-04
# Epoch 76/140
# 11/11 [==============================] - 1s 91ms/step - loss: 2.7100 - mse: 2.7100 - val_loss: 3.8763 - val_mse: 3.8763 - lr: 1.4645e-04
# Epoch 77/140
# 11/11 [==============================] - 1s 89ms/step - loss: 2.6111 - mse: 2.6111 - val_loss: 3.8762 - val_mse: 3.8762 - lr: 9.5492e-05
# Epoch 78/140
# 11/11 [==============================] - 1s 87ms/step - loss: 2.6337 - mse: 2.6337 - val_loss: 3.8753 - val_mse: 3.8753 - lr: 5.4497e-05
# Epoch 79/140
# 11/11 [==============================] - 1s 88ms/step - loss: 2.7094 - mse: 2.7094 - val_loss: 3.8737 - val_mse: 3.8737 - lr: 2.4472e-05
# Epoch 80/140
# 11/11 [==============================] - 1s 89ms/step - loss: 2.6724 - mse: 2.6724 - val_loss: 3.8735 - val_mse: 3.8735 - lr: 6.1558e-06
# Epoch 81/140
# 11/11 [==============================] - 1s 91ms/step - loss: 2.6831 - mse: 2.6831 - val_loss: 3.8766 - val_mse: 3.8766 - lr: 0.0010
# Epoch 82/140
# 11/11 [==============================] - 1s 88ms/step - loss: 2.7103 - mse: 2.7103 - val_loss: 3.8604 - val_mse: 3.8604 - lr: 9.9384e-04
# Epoch 83/140
# 11/11 [==============================] - 1s 89ms/step - loss: 2.6842 - mse: 2.6842 - val_loss: 3.8673 - val_mse: 3.8673 - lr: 9.7553e-04
# Epoch 84/140
# 11/11 [==============================] - 1s 90ms/step - loss: 2.6906 - mse: 2.6906 - val_loss: 3.8655 - val_mse: 3.8655 - lr: 9.4550e-04
# Epoch 85/140
# 11/11 [==============================] - 1s 91ms/step - loss: 2.7309 - mse: 2.7309 - val_loss: 3.9073 - val_mse: 3.9073 - lr: 9.0451e-04
# Epoch 86/140
# 11/11 [==============================] - 1s 89ms/step - loss: 2.5883 - mse: 2.5883 - val_loss: 3.8772 - val_mse: 3.8772 - lr: 8.5355e-04
# Epoch 87/140
# 11/11 [==============================] - 1s 89ms/step - loss: 2.6192 - mse: 2.6192 - val_loss: 3.8795 - val_mse: 3.8795 - lr: 7.9389e-04
# Epoch 88/140
# 11/11 [==============================] - 1s 88ms/step - loss: 2.6892 - mse: 2.6892 - val_loss: 3.8953 - val_mse: 3.8953 - lr: 7.2700e-04
# Epoch 89/140
# 11/11 [==============================] - 1s 89ms/step - loss: 2.6910 - mse: 2.6910 - val_loss: 3.8757 - val_mse: 3.8757 - lr: 6.5451e-04
# Epoch 90/140
# 11/11 [==============================] - 1s 88ms/step - loss: 2.7203 - mse: 2.7203 - val_loss: 3.8874 - val_mse: 3.8874 - lr: 5.7822e-04
# Epoch 91/140
# 11/11 [==============================] - 1s 88ms/step - loss: 2.6442 - mse: 2.6442 - val_loss: 3.8783 - val_mse: 3.8783 - lr: 5.0000e-04
# Epoch 92/140
# 11/11 [==============================] - 1s 89ms/step - loss: 2.6967 - mse: 2.6967 - val_loss: 3.8628 - val_mse: 3.8628 - lr: 4.2178e-04
# Epoch 93/140
# 11/11 [==============================] - 1s 89ms/step - loss: 2.6749 - mse: 2.6749 - val_loss: 3.8477 - val_mse: 3.8477 - lr: 3.4549e-04
# Epoch 94/140
# 11/11 [==============================] - 1s 89ms/step - loss: 2.6288 - mse: 2.6288 - val_loss: 3.8606 - val_mse: 3.8606 - lr: 2.7300e-04
# Epoch 95/140
# 11/11 [==============================] - 1s 93ms/step - loss: 2.6367 - mse: 2.6367 - val_loss: 3.8641 - val_mse: 3.8641 - lr: 2.0611e-04
# Epoch 96/140
# 11/11 [==============================] - 1s 89ms/step - loss: 2.6692 - mse: 2.6692 - val_loss: 3.8669 - val_mse: 3.8669 - lr: 1.4645e-04
# Epoch 97/140
# 11/11 [==============================] - 1s 89ms/step - loss: 2.5971 - mse: 2.5971 - val_loss: 3.8680 - val_mse: 3.8680 - lr: 9.5492e-05
# Epoch 98/140
# 11/11 [==============================] - 1s 90ms/step - loss: 2.6933 - mse: 2.6933 - val_loss: 3.8629 - val_mse: 3.8629 - lr: 5.4497e-05
# Epoch 99/140
# 11/11 [==============================] - 1s 86ms/step - loss: 2.6314 - mse: 2.6314 - val_loss: 3.8611 - val_mse: 3.8611 - lr: 2.4472e-05
# Epoch 100/140
# 11/11 [==============================] - 1s 91ms/step - loss: 2.7062 - mse: 2.7062 - val_loss: 3.8605 - val_mse: 3.8605 - lr: 6.1558e-06
# Epoch 101/140
# 11/11 [==============================] - 1s 88ms/step - loss: 2.7185 - mse: 2.7185 - val_loss: 3.8602 - val_mse: 3.8602 - lr: 0.0010
# Epoch 102/140
# 11/11 [==============================] - 1s 90ms/step - loss: 2.6828 - mse: 2.6828 - val_loss: 3.9230 - val_mse: 3.9230 - lr: 9.9384e-04
# Epoch 103/140
# 11/11 [==============================] - 1s 89ms/step - loss: 2.6640 - mse: 2.6640 - val_loss: 3.8957 - val_mse: 3.8957 - lr: 9.7553e-04
# Epoch 104/140
# 11/11 [==============================] - 1s 88ms/step - loss: 2.6212 - mse: 2.6212 - val_loss: 3.9256 - val_mse: 3.9256 - lr: 9.4550e-04
# Epoch 105/140
# 11/11 [==============================] - 1s 90ms/step - loss: 2.7734 - mse: 2.7734 - val_loss: 3.8959 - val_mse: 3.8959 - lr: 9.0451e-04
# Epoch 106/140
# 11/11 [==============================] - 1s 90ms/step - loss: 2.5909 - mse: 2.5909 - val_loss: 3.8718 - val_mse: 3.8718 - lr: 8.5355e-04
# Epoch 107/140
# 11/11 [==============================] - 1s 90ms/step - loss: 2.6398 - mse: 2.6398 - val_loss: 3.8845 - val_mse: 3.8845 - lr: 7.9389e-04
# Epoch 108/140
# 11/11 [==============================] - 1s 90ms/step - loss: 2.6119 - mse: 2.6119 - val_loss: 3.8966 - val_mse: 3.8966 - lr: 7.2700e-04
# Epoch 109/140
# 11/11 [==============================] - 1s 88ms/step - loss: 2.6574 - mse: 2.6574 - val_loss: 3.8888 - val_mse: 3.8888 - lr: 6.5451e-04
# Epoch 110/140
# 11/11 [==============================] - 1s 93ms/step - loss: 2.5783 - mse: 2.5783 - val_loss: 3.8734 - val_mse: 3.8734 - lr: 5.7822e-04
# Epoch 111/140
# 11/11 [==============================] - 1s 92ms/step - loss: 2.6700 - mse: 2.6700 - val_loss: 3.8696 - val_mse: 3.8696 - lr: 5.0000e-04
# Epoch 112/140
# 11/11 [==============================] - 1s 94ms/step - loss: 2.5663 - mse: 2.5663 - val_loss: 3.8840 - val_mse: 3.8840 - lr: 4.2178e-04
# Epoch 113/140
# 11/11 [==============================] - 1s 91ms/step - loss: 2.6072 - mse: 2.6072 - val_loss: 3.8887 - val_mse: 3.8887 - lr: 3.4549e-04
# Epoch 114/140
# 11/11 [==============================] - 1s 90ms/step - loss: 2.6542 - mse: 2.6542 - val_loss: 3.8940 - val_mse: 3.8940 - lr: 2.7300e-04
# Epoch 115/140
# 11/11 [==============================] - 1s 91ms/step - loss: 2.6546 - mse: 2.6546 - val_loss: 3.8956 - val_mse: 3.8956 - lr: 2.0611e-04
# Epoch 116/140
# 11/11 [==============================] - 1s 92ms/step - loss: 2.7334 - mse: 2.7334 - val_loss: 3.8875 - val_mse: 3.8875 - lr: 1.4645e-04
# Epoch 117/140
# 11/11 [==============================] - 1s 92ms/step - loss: 2.5868 - mse: 2.5868 - val_loss: 3.8836 - val_mse: 3.8836 - lr: 9.5492e-05
# Epoch 118/140
# 11/11 [==============================] - 1s 91ms/step - loss: 2.5867 - mse: 2.5867 - val_loss: 3.8821 - val_mse: 3.8821 - lr: 5.4497e-05
# Epoch 119/140
# 11/11 [==============================] - 1s 89ms/step - loss: 2.6358 - mse: 2.6358 - val_loss: 3.8833 - val_mse: 3.8833 - lr: 2.4472e-05
# Epoch 120/140
# 11/11 [==============================] - 1s 89ms/step - loss: 2.5561 - mse: 2.5561 - val_loss: 3.8834 - val_mse: 3.8834 - lr: 6.1558e-06
# Epoch 121/140
# 11/11 [==============================] - 1s 88ms/step - loss: 2.6246 - mse: 2.6246 - val_loss: 3.8795 - val_mse: 3.8795 - lr: 0.0010
# Epoch 122/140
# 11/11 [==============================] - 1s 92ms/step - loss: 2.7376 - mse: 2.7376 - val_loss: 3.9005 - val_mse: 3.9005 - lr: 9.9384e-04
# Epoch 123/140
# 11/11 [==============================] - 1s 90ms/step - loss: 2.6747 - mse: 2.6747 - val_loss: 3.9050 - val_mse: 3.9050 - lr: 9.7553e-04
# Epoch 124/140
# 11/11 [==============================] - 1s 93ms/step - loss: 2.7162 - mse: 2.7162 - val_loss: 3.8768 - val_mse: 3.8768 - lr: 9.4550e-04
# Epoch 125/140
# 11/11 [==============================] - 1s 93ms/step - loss: 2.5466 - mse: 2.5466 - val_loss: 3.8930 - val_mse: 3.8930 - lr: 9.0451e-04
# Epoch 126/140
# 11/11 [==============================] - 1s 92ms/step - loss: 2.6828 - mse: 2.6828 - val_loss: 3.8774 - val_mse: 3.8774 - lr: 8.5355e-04
# Epoch 127/140
# 11/11 [==============================] - 1s 93ms/step - loss: 2.6353 - mse: 2.6353 - val_loss: 3.9057 - val_mse: 3.9057 - lr: 7.9389e-04
# Epoch 128/140
# 11/11 [==============================] - 1s 92ms/step - loss: 2.5787 - mse: 2.5787 - val_loss: 3.8865 - val_mse: 3.8865 - lr: 7.2700e-04
# Epoch 129/140
# 11/11 [==============================] - 1s 91ms/step - loss: 2.5710 - mse: 2.5710 - val_loss: 3.8875 - val_mse: 3.8875 - lr: 6.5451e-04
# Epoch 130/140
# 11/11 [==============================] - 1s 93ms/step - loss: 2.6328 - mse: 2.6328 - val_loss: 3.9080 - val_mse: 3.9080 - lr: 5.7822e-04
# Epoch 131/140
# 11/11 [==============================] - 1s 93ms/step - loss: 2.7104 - mse: 2.7104 - val_loss: 3.8907 - val_mse: 3.8907 - lr: 5.0000e-04
# Epoch 132/140
# 11/11 [==============================] - 1s 92ms/step - loss: 2.6149 - mse: 2.6149 - val_loss: 3.8863 - val_mse: 3.8863 - lr: 4.2178e-04
# Epoch 133/140
# 11/11 [==============================] - 1s 93ms/step - loss: 2.5724 - mse: 2.5724 - val_loss: 3.8762 - val_mse: 3.8762 - lr: 3.4549e-04
# Epoch 134/140
# 11/11 [==============================] - 1s 93ms/step - loss: 2.5416 - mse: 2.5416 - val_loss: 3.8858 - val_mse: 3.8858 - lr: 2.7300e-04
# Epoch 135/140
# 11/11 [==============================] - 1s 92ms/step - loss: 2.5369 - mse: 2.5369 - val_loss: 3.8871 - val_mse: 3.8871 - lr: 2.0611e-04
# Epoch 136/140
# 11/11 [==============================] - 1s 91ms/step - loss: 2.6030 - mse: 2.6030 - val_loss: 3.8836 - val_mse: 3.8836 - lr: 1.4645e-04
# Epoch 137/140
# 11/11 [==============================] - 1s 92ms/step - loss: 2.5690 - mse: 2.5690 - val_loss: 3.8813 - val_mse: 3.8813 - lr: 9.5492e-05
# Epoch 138/140
# 11/11 [==============================] - 1s 92ms/step - loss: 2.5395 - mse: 2.5395 - val_loss: 3.8798 - val_mse: 3.8798 - lr: 5.4497e-05
# Epoch 139/140
# 11/11 [==============================] - 1s 91ms/step - loss: 2.6049 - mse: 2.6049 - val_loss: 3.8793 - val_mse: 3.8793 - lr: 2.4472e-05
# Epoch 140/140
# 11/11 [==============================] - 1s 91ms/step - loss: 2.5691 - mse: 2.5691 - val_loss: 3.8788 - val_mse: 3.8788 - lr: 6.1558e-06
# 2.1472726
# fold: 1
# Epoch 1/140
# 12/12 [==============================] - 9s 209ms/step - loss: 2194.9773 - mse: 2194.9773 - val_loss: 2175.4836 - val_mse: 2175.4836 - lr: 0.0100
# Epoch 2/140
# 12/12 [==============================] - 1s 87ms/step - loss: 2031.5753 - mse: 2031.5753 - val_loss: 2001.6143 - val_mse: 2001.6143 - lr: 0.0099
# Epoch 3/140
# 12/12 [==============================] - 1s 88ms/step - loss: 1809.8035 - mse: 1809.8035 - val_loss: 1753.9453 - val_mse: 1753.9453 - lr: 0.0098
# Epoch 4/140
# 12/12 [==============================] - 1s 88ms/step - loss: 1503.4940 - mse: 1503.4940 - val_loss: 1391.1779 - val_mse: 1391.1779 - lr: 0.0095
# Epoch 5/140
# 12/12 [==============================] - 1s 89ms/step - loss: 1146.5909 - mse: 1146.5909 - val_loss: 1041.7996 - val_mse: 1041.7996 - lr: 0.0090
# Epoch 6/140
# 12/12 [==============================] - 1s 88ms/step - loss: 799.7306 - mse: 799.7306 - val_loss: 716.5948 - val_mse: 716.5948 - lr: 0.0085
# Epoch 7/140
# 12/12 [==============================] - 1s 91ms/step - loss: 517.3329 - mse: 517.3329 - val_loss: 476.9286 - val_mse: 476.9286 - lr: 0.0079
# Epoch 8/140
# 12/12 [==============================] - 1s 88ms/step - loss: 319.5783 - mse: 319.5783 - val_loss: 316.0366 - val_mse: 316.0366 - lr: 0.0073
# Epoch 9/140
# 12/12 [==============================] - 1s 88ms/step - loss: 193.0476 - mse: 193.0476 - val_loss: 214.3548 - val_mse: 214.3548 - lr: 0.0065
# Epoch 10/140
# 12/12 [==============================] - 1s 89ms/step - loss: 115.1180 - mse: 115.1180 - val_loss: 153.7183 - val_mse: 153.7183 - lr: 0.0058
# Epoch 11/140
# 12/12 [==============================] - 1s 89ms/step - loss: 68.6041 - mse: 68.6041 - val_loss: 117.4309 - val_mse: 117.4309 - lr: 0.0050
# Epoch 12/140
# 12/12 [==============================] - 1s 88ms/step - loss: 42.1017 - mse: 42.1017 - val_loss: 94.8267 - val_mse: 94.8267 - lr: 0.0042
# Epoch 13/140
# 12/12 [==============================] - 1s 88ms/step - loss: 27.6227 - mse: 27.6227 - val_loss: 81.2402 - val_mse: 81.2402 - lr: 0.0035
# Epoch 14/140
# 12/12 [==============================] - 1s 89ms/step - loss: 19.8680 - mse: 19.8680 - val_loss: 72.6898 - val_mse: 72.6898 - lr: 0.0027
# Epoch 15/140
# 12/12 [==============================] - 1s 89ms/step - loss: 15.4240 - mse: 15.4240 - val_loss: 64.2398 - val_mse: 64.2398 - lr: 0.0021
# Epoch 16/140
# 12/12 [==============================] - 1s 88ms/step - loss: 13.0087 - mse: 13.0087 - val_loss: 58.5651 - val_mse: 58.5651 - lr: 0.0015
# Epoch 17/140
# 12/12 [==============================] - 1s 88ms/step - loss: 11.6843 - mse: 11.6843 - val_loss: 53.6073 - val_mse: 53.6073 - lr: 9.5492e-04
# Epoch 18/140
# 12/12 [==============================] - 1s 89ms/step - loss: 10.7453 - mse: 10.7453 - val_loss: 48.2787 - val_mse: 48.2787 - lr: 5.4497e-04
# Epoch 19/140
# 12/12 [==============================] - 1s 89ms/step - loss: 10.4739 - mse: 10.4739 - val_loss: 43.2691 - val_mse: 43.2691 - lr: 2.4472e-04
# Epoch 20/140
# 12/12 [==============================] - 1s 89ms/step - loss: 10.2928 - mse: 10.2928 - val_loss: 38.9222 - val_mse: 38.9222 - lr: 6.1558e-05
# Epoch 21/140
# 12/12 [==============================] - 1s 89ms/step - loss: 7.9477 - mse: 7.9477 - val_loss: 31.9233 - val_mse: 31.9233 - lr: 0.0100
# Epoch 22/140
# 12/12 [==============================] - 1s 87ms/step - loss: 5.2106 - mse: 5.2106 - val_loss: 25.7374 - val_mse: 25.7374 - lr: 0.0099
# Epoch 23/140
# 12/12 [==============================] - 1s 87ms/step - loss: 5.0207 - mse: 5.0207 - val_loss: 22.4249 - val_mse: 22.4249 - lr: 0.0098
# Epoch 24/140
# 12/12 [==============================] - 1s 87ms/step - loss: 5.0897 - mse: 5.0897 - val_loss: 16.3041 - val_mse: 16.3041 - lr: 0.0095
# Epoch 25/140
# 12/12 [==============================] - 1s 88ms/step - loss: 4.8211 - mse: 4.8211 - val_loss: 12.2429 - val_mse: 12.2429 - lr: 0.0090
# Epoch 26/140
# 12/12 [==============================] - 1s 89ms/step - loss: 4.6312 - mse: 4.6312 - val_loss: 10.4707 - val_mse: 10.4707 - lr: 0.0085
# Epoch 27/140
# 12/12 [==============================] - 1s 91ms/step - loss: 4.5732 - mse: 4.5732 - val_loss: 9.8171 - val_mse: 9.8171 - lr: 0.0079
# Epoch 28/140
# 12/12 [==============================] - 1s 89ms/step - loss: 4.4700 - mse: 4.4700 - val_loss: 8.1440 - val_mse: 8.1440 - lr: 0.0073
# Epoch 29/140
# 12/12 [==============================] - 1s 90ms/step - loss: 4.3210 - mse: 4.3210 - val_loss: 6.9659 - val_mse: 6.9659 - lr: 0.0065
# Epoch 30/140
# 12/12 [==============================] - 1s 89ms/step - loss: 4.2504 - mse: 4.2504 - val_loss: 6.6439 - val_mse: 6.6439 - lr: 0.0058
# Epoch 31/140
# 12/12 [==============================] - 1s 88ms/step - loss: 4.1423 - mse: 4.1423 - val_loss: 5.8179 - val_mse: 5.8179 - lr: 0.0050
# Epoch 32/140
# 12/12 [==============================] - 1s 88ms/step - loss: 3.9866 - mse: 3.9866 - val_loss: 5.3534 - val_mse: 5.3534 - lr: 0.0042
# Epoch 33/140
# 12/12 [==============================] - 1s 89ms/step - loss: 4.1510 - mse: 4.1510 - val_loss: 4.7225 - val_mse: 4.7225 - lr: 0.0035
# Epoch 34/140
# 12/12 [==============================] - 1s 89ms/step - loss: 3.9395 - mse: 3.9395 - val_loss: 4.8199 - val_mse: 4.8199 - lr: 0.0027
# Epoch 35/140
# 12/12 [==============================] - 1s 90ms/step - loss: 3.9959 - mse: 3.9959 - val_loss: 4.6644 - val_mse: 4.6644 - lr: 0.0021
# Epoch 36/140
# 12/12 [==============================] - 1s 89ms/step - loss: 3.9197 - mse: 3.9197 - val_loss: 4.3753 - val_mse: 4.3753 - lr: 0.0015
# Epoch 37/140
# 12/12 [==============================] - 1s 88ms/step - loss: 3.7790 - mse: 3.7790 - val_loss: 4.2307 - val_mse: 4.2307 - lr: 9.5492e-04
# Epoch 38/140
# 12/12 [==============================] - 1s 87ms/step - loss: 3.8141 - mse: 3.8141 - val_loss: 4.1118 - val_mse: 4.1118 - lr: 5.4497e-04
# Epoch 39/140
# 12/12 [==============================] - 1s 90ms/step - loss: 3.7009 - mse: 3.7009 - val_loss: 4.0086 - val_mse: 4.0086 - lr: 2.4472e-04
# Epoch 40/140
# 12/12 [==============================] - 1s 88ms/step - loss: 3.7299 - mse: 3.7299 - val_loss: 3.9225 - val_mse: 3.9225 - lr: 6.1558e-05
# Epoch 41/140
# 12/12 [==============================] - 1s 90ms/step - loss: 3.8872 - mse: 3.8872 - val_loss: 3.8671 - val_mse: 3.8671 - lr: 0.0100
# Epoch 42/140
# ...
# Epoch 36/140
# 12/12 [==============================] - 1s 102ms/step - loss: 3.3071 - mse: 3.3071 - val_loss: 4.0421 - val_mse: 4.0421 - lr: 1.4645e-04
# Epoch 37/140
# 12/12 [==============================] - 1s 102ms/step - loss: 3.1994 - mse: 3.1994 - val_loss: 4.0394 - val_mse: 4.0394 - lr: 9.5492e-05
# Epoch 38/140
# 12/12 [==============================] - 1s 102ms/step - loss: 3.1694 - mse: 3.1694 - val_loss: 4.0389 - val_mse: 4.0389 - lr: 5.4497e-05
# Epoch 39/140
# 12/12 [==============================] - 1s 103ms/step - loss: 3.2220 - mse: 3.2220 - val_loss: 4.0390 - val_mse: 4.0390 - lr: 2.4472e-05
# Epoch 40/140
# 12/12 [==============================] - 1s 102ms/step - loss: 3.1738 - mse: 3.1738 - val_loss: 4.0391 - val_mse: 4.0391 - lr: 6.1558e-06
# Epoch 41/140
# 12/12 [==============================] - 1s 102ms/step - loss: 3.2190 - mse: 3.2190 - val_loss: 4.0578 - val_mse: 4.0578 - lr: 0.0010
# Epoch 42/140
# 12/12 [==============================] - 1s 101ms/step - loss: 3.2343 - mse: 3.2343 - val_loss: 4.0432 - val_mse: 4.0432 - lr: 9.9384e-04
# Epoch 43/140
# 12/12 [==============================] - 1s 109ms/step - loss: 3.1291 - mse: 3.1291 - val_loss: 4.0504 - val_mse: 4.0504 - lr: 9.7553e-04
# Epoch 44/140
# 12/12 [==============================] - 1s 103ms/step - loss: 3.2589 - mse: 3.2589 - val_loss: 4.0361 - val_mse: 4.0361 - lr: 9.4550e-04
# Epoch 45/140
# 12/12 [==============================] - 1s 102ms/step - loss: 3.1508 - mse: 3.1508 - val_loss: 4.0665 - val_mse: 4.0665 - lr: 9.0451e-04
# Epoch 46/140
# 12/12 [==============================] - 1s 103ms/step - loss: 3.1650 - mse: 3.1650 - val_loss: 4.0831 - val_mse: 4.0831 - lr: 8.5355e-04
# Epoch 47/140
# 12/12 [==============================] - 1s 103ms/step - loss: 3.2428 - mse: 3.2428 - val_loss: 4.0675 - val_mse: 4.0675 - lr: 7.9389e-04
# Epoch 48/140
# 12/12 [==============================] - 1s 101ms/step - loss: 3.2202 - mse: 3.2202 - val_loss: 4.0582 - val_mse: 4.0582 - lr: 7.2700e-04
# Epoch 49/140
# 12/12 [==============================] - 1s 101ms/step - loss: 3.1323 - mse: 3.1323 - val_loss: 4.0482 - val_mse: 4.0482 - lr: 6.5451e-04
# Epoch 50/140
# 12/12 [==============================] - 1s 103ms/step - loss: 3.1296 - mse: 3.1296 - val_loss: 4.0214 - val_mse: 4.0214 - lr: 5.7822e-04
# Epoch 51/140
# 12/12 [==============================] - 1s 103ms/step - loss: 3.2107 - mse: 3.2107 - val_loss: 4.0211 - val_mse: 4.0211 - lr: 5.0000e-04
# Epoch 52/140
# 12/12 [==============================] - 1s 103ms/step - loss: 3.2165 - mse: 3.2165 - val_loss: 4.0181 - val_mse: 4.0181 - lr: 4.2178e-04
# Epoch 53/140
# 12/12 [==============================] - 1s 103ms/step - loss: 3.1242 - mse: 3.1242 - val_loss: 4.0274 - val_mse: 4.0274 - lr: 3.4549e-04
# Epoch 54/140
# 12/12 [==============================] - 1s 102ms/step - loss: 3.1729 - mse: 3.1729 - val_loss: 4.0280 - val_mse: 4.0280 - lr: 2.7300e-04
# Epoch 55/140
# 12/12 [==============================] - 1s 103ms/step - loss: 3.1486 - mse: 3.1486 - val_loss: 4.0262 - val_mse: 4.0262 - lr: 2.0611e-04
# Epoch 56/140
# 12/12 [==============================] - 1s 102ms/step - loss: 3.2173 - mse: 3.2173 - val_loss: 4.0263 - val_mse: 4.0263 - lr: 1.4645e-04
# Epoch 57/140
# 12/12 [==============================] - 1s 102ms/step - loss: 3.1315 - mse: 3.1315 - val_loss: 4.0252 - val_mse: 4.0252 - lr: 9.5492e-05
# Epoch 58/140
# 12/12 [==============================] - 1s 103ms/step - loss: 3.2480 - mse: 3.2480 - val_loss: 4.0250 - val_mse: 4.0250 - lr: 5.4497e-05
# Epoch 59/140
# 12/12 [==============================] - 1s 103ms/step - loss: 3.1303 - mse: 3.1303 - val_loss: 4.0261 - val_mse: 4.0261 - lr: 2.4472e-05
# Epoch 60/140
# 12/12 [==============================] - 1s 103ms/step - loss: 3.1875 - mse: 3.1875 - val_loss: 4.0262 - val_mse: 4.0262 - lr: 6.1558e-06
# Epoch 61/140
# 12/12 [==============================] - 1s 103ms/step - loss: 3.2514 - mse: 3.2514 - val_loss: 4.0200 - val_mse: 4.0200 - lr: 0.0010
# Epoch 62/140
# 12/12 [==============================] - 1s 102ms/step - loss: 3.2727 - mse: 3.2727 - val_loss: 4.0247 - val_mse: 4.0247 - lr: 9.9384e-04
# Epoch 63/140
# 12/12 [==============================] - 1s 101ms/step - loss: 3.0743 - mse: 3.0743 - val_loss: 4.0457 - val_mse: 4.0457 - lr: 9.7553e-04
# Epoch 64/140
# 12/12 [==============================] - 1s 104ms/step - loss: 3.2256 - mse: 3.2256 - val_loss: 4.0231 - val_mse: 4.0231 - lr: 9.4550e-04
# Epoch 65/140
# 12/12 [==============================] - 1s 102ms/step - loss: 3.2273 - mse: 3.2273 - val_loss: 4.0418 - val_mse: 4.0418 - lr: 9.0451e-04
# Epoch 66/140
# 12/12 [==============================] - 1s 103ms/step - loss: 3.2465 - mse: 3.2465 - val_loss: 4.0073 - val_mse: 4.0073 - lr: 8.5355e-04
# Epoch 67/140
# 12/12 [==============================] - 1s 102ms/step - loss: 3.1444 - mse: 3.1444 - val_loss: 4.0114 - val_mse: 4.0114 - lr: 7.9389e-04
# Epoch 68/140
# 12/12 [==============================] - 1s 103ms/step - loss: 3.1375 - mse: 3.1375 - val_loss: 4.0001 - val_mse: 4.0001 - lr: 7.2700e-04
# Epoch 69/140
# 12/12 [==============================] - 1s 102ms/step - loss: 3.1496 - mse: 3.1496 - val_loss: 4.0511 - val_mse: 4.0511 - lr: 6.5451e-04
# Epoch 70/140
# 12/12 [==============================] - 1s 102ms/step - loss: 3.1783 - mse: 3.1783 - val_loss: 4.0764 - val_mse: 4.0764 - lr: 5.7822e-04
# Epoch 71/140
# 12/12 [==============================] - 1s 103ms/step - loss: 3.1084 - mse: 3.1084 - val_loss: 4.0667 - val_mse: 4.0667 - lr: 5.0000e-04
# Epoch 72/140
# 12/12 [==============================] - 1s 101ms/step - loss: 3.1431 - mse: 3.1431 - val_loss: 4.0530 - val_mse: 4.0530 - lr: 4.2178e-04
# Epoch 73/140
# 12/12 [==============================] - 1s 102ms/step - loss: 3.2195 - mse: 3.2195 - val_loss: 4.0582 - val_mse: 4.0582 - lr: 3.4549e-04
# Epoch 74/140
# 12/12 [==============================] - 1s 102ms/step - loss: 3.2013 - mse: 3.2013 - val_loss: 4.0645 - val_mse: 4.0645 - lr: 2.7300e-04
# Epoch 75/140
# 12/12 [==============================] - 1s 102ms/step - loss: 3.2750 - mse: 3.2750 - val_loss: 4.0612 - val_mse: 4.0612 - lr: 2.0611e-04
# Epoch 76/140
# 12/12 [==============================] - 1s 102ms/step - loss: 3.1394 - mse: 3.1394 - val_loss: 4.0554 - val_mse: 4.0554 - lr: 1.4645e-04
# Epoch 77/140
# 12/12 [==============================] - 1s 103ms/step - loss: 3.1019 - mse: 3.1019 - val_loss: 4.0513 - val_mse: 4.0513 - lr: 9.5492e-05
# Epoch 78/140
# 12/12 [==============================] - 1s 101ms/step - loss: 3.2946 - mse: 3.2946 - val_loss: 4.0491 - val_mse: 4.0491 - lr: 5.4497e-05
# Epoch 79/140
# 12/12 [==============================] - 1s 106ms/step - loss: 3.2318 - mse: 3.2318 - val_loss: 4.0531 - val_mse: 4.0531 - lr: 2.4472e-05
# Epoch 80/140
# 12/12 [==============================] - 1s 103ms/step - loss: 3.1000 - mse: 3.1000 - val_loss: 4.0524 - val_mse: 4.0524 - lr: 6.1558e-06
# Epoch 81/140
# 12/12 [==============================] - 1s 103ms/step - loss: 3.0856 - mse: 3.0856 - val_loss: 4.0691 - val_mse: 4.0691 - lr: 0.0010
# Epoch 82/140
# 12/12 [==============================] - 1s 102ms/step - loss: 3.0671 - mse: 3.0671 - val_loss: 4.0749 - val_mse: 4.0749 - lr: 9.9384e-04
# Epoch 83/140
# 12/12 [==============================] - 1s 104ms/step - loss: 3.1032 - mse: 3.1032 - val_loss: 4.0486 - val_mse: 4.0486 - lr: 9.7553e-04
# Epoch 84/140
# 12/12 [==============================] - 1s 104ms/step - loss: 3.1648 - mse: 3.1648 - val_loss: 4.0432 - val_mse: 4.0432 - lr: 9.4550e-04
# Epoch 85/140
# 12/12 [==============================] - 1s 102ms/step - loss: 3.2081 - mse: 3.2081 - val_loss: 4.0541 - val_mse: 4.0541 - lr: 9.0451e-04
# Epoch 86/140
# 12/12 [==============================] - 1s 104ms/step - loss: 3.1068 - mse: 3.1068 - val_loss: 4.0469 - val_mse: 4.0469 - lr: 8.5355e-04
# Epoch 87/140
# 12/12 [==============================] - 1s 102ms/step - loss: 3.1690 - mse: 3.1690 - val_loss: 4.0441 - val_mse: 4.0441 - lr: 7.9389e-04
# Epoch 88/140
# 12/12 [==============================] - 1s 103ms/step - loss: 3.1394 - mse: 3.1394 - val_loss: 4.0452 - val_mse: 4.0452 - lr: 7.2700e-04
# Epoch 89/140
# 12/12 [==============================] - 1s 104ms/step - loss: 3.1325 - mse: 3.1325 - val_loss: 4.0356 - val_mse: 4.0356 - lr: 6.5451e-04
# Epoch 90/140
# 12/12 [==============================] - 1s 101ms/step - loss: 3.0838 - mse: 3.0838 - val_loss: 4.0378 - val_mse: 4.0378 - lr: 5.7822e-04
# Epoch 91/140
# 12/12 [==============================] - 1s 100ms/step - loss: 3.2017 - mse: 3.2017 - val_loss: 4.0615 - val_mse: 4.0615 - lr: 5.0000e-04
# Epoch 92/140
# 12/12 [==============================] - 1s 105ms/step - loss: 3.1160 - mse: 3.1160 - val_loss: 4.0361 - val_mse: 4.0361 - lr: 4.2178e-04
# Epoch 93/140
# 12/12 [==============================] - 1s 103ms/step - loss: 3.1814 - mse: 3.1814 - val_loss: 4.0195 - val_mse: 4.0195 - lr: 3.4549e-04
# Epoch 94/140
# 12/12 [==============================] - 1s 103ms/step - loss: 3.2431 - mse: 3.2431 - val_loss: 4.0231 - val_mse: 4.0231 - lr: 2.7300e-04
# Epoch 95/140
# 12/12 [==============================] - 1s 104ms/step - loss: 3.0231 - mse: 3.0231 - val_loss: 4.0262 - val_mse: 4.0262 - lr: 2.0611e-04
# Epoch 96/140
# 12/12 [==============================] - 1s 102ms/step - loss: 2.9851 - mse: 2.9851 - val_loss: 4.0309 - val_mse: 4.0309 - lr: 1.4645e-04
# Epoch 97/140
# 12/12 [==============================] - 1s 104ms/step - loss: 3.0604 - mse: 3.0604 - val_loss: 4.0303 - val_mse: 4.0303 - lr: 9.5492e-05
# Epoch 98/140
# 12/12 [==============================] - 1s 103ms/step - loss: 3.0939 - mse: 3.0939 - val_loss: 4.0310 - val_mse: 4.0310 - lr: 5.4497e-05
# Epoch 99/140
# 12/12 [==============================] - 1s 102ms/step - loss: 3.1559 - mse: 3.1559 - val_loss: 4.0310 - val_mse: 4.0310 - lr: 2.4472e-05
# Epoch 100/140
# 12/12 [==============================] - 1s 103ms/step - loss: 3.1304 - mse: 3.1304 - val_loss: 4.0300 - val_mse: 4.0300 - lr: 6.1558e-06
# Epoch 101/140
# 12/12 [==============================] - 1s 102ms/step - loss: 3.0861 - mse: 3.0861 - val_loss: 4.0120 - val_mse: 4.0120 - lr: 0.0010
# Epoch 102/140
# 12/12 [==============================] - 1s 102ms/step - loss: 3.1061 - mse: 3.1061 - val_loss: 4.0210 - val_mse: 4.0210 - lr: 9.9384e-04
# Epoch 103/140
# 12/12 [==============================] - 1s 102ms/step - loss: 3.0527 - mse: 3.0527 - val_loss: 4.0122 - val_mse: 4.0122 - lr: 9.7553e-04
# Epoch 104/140
# 12/12 [==============================] - 1s 102ms/step - loss: 3.0280 - mse: 3.0280 - val_loss: 4.0048 - val_mse: 4.0048 - lr: 9.4550e-04
# Epoch 105/140
# 12/12 [==============================] - 1s 103ms/step - loss: 3.0824 - mse: 3.0824 - val_loss: 3.9888 - val_mse: 3.9888 - lr: 9.0451e-04
# Epoch 106/140
# 12/12 [==============================] - 1s 102ms/step - loss: 3.1663 - mse: 3.1663 - val_loss: 4.0081 - val_mse: 4.0081 - lr: 8.5355e-04
# Epoch 107/140
# 12/12 [==============================] - 1s 104ms/step - loss: 3.1201 - mse: 3.1201 - val_loss: 4.0321 - val_mse: 4.0321 - lr: 7.9389e-04
# Epoch 108/140
# 12/12 [==============================] - 1s 102ms/step - loss: 3.2144 - mse: 3.2144 - val_loss: 4.0102 - val_mse: 4.0102 - lr: 7.2700e-04
# Epoch 109/140
# 12/12 [==============================] - 1s 103ms/step - loss: 3.0658 - mse: 3.0658 - val_loss: 4.0211 - val_mse: 4.0211 - lr: 6.5451e-04
# Epoch 110/140
# 12/12 [==============================] - 1s 104ms/step - loss: 3.0934 - mse: 3.0934 - val_loss: 4.0205 - val_mse: 4.0205 - lr: 5.7822e-04
# Epoch 111/140
# 12/12 [==============================] - 1s 105ms/step - loss: 3.0322 - mse: 3.0322 - val_loss: 4.0114 - val_mse: 4.0114 - lr: 5.0000e-04
# Epoch 112/140
# 12/12 [==============================] - 1s 105ms/step - loss: 3.0490 - mse: 3.0490 - val_loss: 4.0063 - val_mse: 4.0063 - lr: 4.2178e-04
# Epoch 113/140
# 12/12 [==============================] - 1s 105ms/step - loss: 3.0843 - mse: 3.0843 - val_loss: 3.9970 - val_mse: 3.9970 - lr: 3.4549e-04
# Epoch 114/140
# 12/12 [==============================] - 1s 103ms/step - loss: 3.0850 - mse: 3.0850 - val_loss: 3.9922 - val_mse: 3.9922 - lr: 2.7300e-04
# Epoch 115/140
# 12/12 [==============================] - 1s 105ms/step - loss: 3.0187 - mse: 3.0187 - val_loss: 3.9943 - val_mse: 3.9943 - lr: 2.0611e-04
# Epoch 116/140
# 12/12 [==============================] - 1s 104ms/step - loss: 3.0858 - mse: 3.0858 - val_loss: 3.9970 - val_mse: 3.9970 - lr: 1.4645e-04
# Epoch 117/140
# 12/12 [==============================] - 1s 105ms/step - loss: 3.0761 - mse: 3.0761 - val_loss: 4.0045 - val_mse: 4.0045 - lr: 9.5492e-05
# Epoch 118/140
# 12/12 [==============================] - 1s 103ms/step - loss: 3.0003 - mse: 3.0003 - val_loss: 4.0055 - val_mse: 4.0055 - lr: 5.4497e-05
# Epoch 119/140
# 12/12 [==============================] - 1s 104ms/step - loss: 3.0852 - mse: 3.0852 - val_loss: 4.0039 - val_mse: 4.0039 - lr: 2.4472e-05
# Epoch 120/140
# 12/12 [==============================] - 1s 104ms/step - loss: 3.1128 - mse: 3.1128 - val_loss: 4.0030 - val_mse: 4.0030 - lr: 6.1558e-06
# Epoch 121/140
# 12/12 [==============================] - 1s 103ms/step - loss: 3.0360 - mse: 3.0360 - val_loss: 3.9869 - val_mse: 3.9869 - lr: 0.0010
# Epoch 122/140
# 12/12 [==============================] - 1s 105ms/step - loss: 3.1356 - mse: 3.1356 - val_loss: 3.9830 - val_mse: 3.9830 - lr: 9.9384e-04
# Epoch 123/140
# 12/12 [==============================] - 1s 105ms/step - loss: 3.0487 - mse: 3.0487 - val_loss: 3.9943 - val_mse: 3.9943 - lr: 9.7553e-04
# Epoch 124/140
# 12/12 [==============================] - 1s 104ms/step - loss: 3.0528 - mse: 3.0528 - val_loss: 4.0080 - val_mse: 4.0080 - lr: 9.4550e-04
# Epoch 125/140
# 12/12 [==============================] - 1s 105ms/step - loss: 3.0062 - mse: 3.0062 - val_loss: 4.0160 - val_mse: 4.0160 - lr: 9.0451e-04
# Epoch 126/140
# 12/12 [==============================] - 1s 104ms/step - loss: 3.0899 - mse: 3.0899 - val_loss: 3.9788 - val_mse: 3.9788 - lr: 8.5355e-04
# Epoch 127/140
# 12/12 [==============================] - 1s 103ms/step - loss: 3.0733 - mse: 3.0733 - val_loss: 3.9783 - val_mse: 3.9783 - lr: 7.9389e-04
# Epoch 128/140
# 12/12 [==============================] - 1s 103ms/step - loss: 2.9911 - mse: 2.9911 - val_loss: 3.9721 - val_mse: 3.9721 - lr: 7.2700e-04
# Epoch 129/140
# 12/12 [==============================] - 1s 103ms/step - loss: 3.0663 - mse: 3.0663 - val_loss: 3.9875 - val_mse: 3.9875 - lr: 6.5451e-04
# Epoch 130/140
# 12/12 [==============================] - 1s 103ms/step - loss: 2.9770 - mse: 2.9770 - val_loss: 3.9966 - val_mse: 3.9966 - lr: 5.7822e-04
# Epoch 131/140
# 12/12 [==============================] - 1s 104ms/step - loss: 3.0509 - mse: 3.0509 - val_loss: 4.0019 - val_mse: 4.0019 - lr: 5.0000e-04
# Epoch 132/140
# 12/12 [==============================] - 1s 105ms/step - loss: 3.1046 - mse: 3.1046 - val_loss: 4.0062 - val_mse: 4.0062 - lr: 4.2178e-04
# Epoch 133/140
# 12/12 [==============================] - 1s 103ms/step - loss: 3.0714 - mse: 3.0714 - val_loss: 3.9978 - val_mse: 3.9978 - lr: 3.4549e-04
# Epoch 134/140
# 12/12 [==============================] - 1s 105ms/step - loss: 2.9869 - mse: 2.9869 - val_loss: 3.9967 - val_mse: 3.9967 - lr: 2.7300e-04
# Epoch 135/140
# 12/12 [==============================] - 1s 104ms/step - loss: 3.0493 - mse: 3.0493 - val_loss: 4.0068 - val_mse: 4.0068 - lr: 2.0611e-04
# Epoch 136/140
# 12/12 [==============================] - 1s 104ms/step - loss: 3.0783 - mse: 3.0783 - val_loss: 4.0086 - val_mse: 4.0086 - lr: 1.4645e-04
# Epoch 137/140
# 12/12 [==============================] - 1s 104ms/step - loss: 3.0756 - mse: 3.0756 - val_loss: 4.0046 - val_mse: 4.0046 - lr: 9.5492e-05
# Epoch 138/140
# 12/12 [==============================] - 1s 104ms/step - loss: 3.0250 - mse: 3.0250 - val_loss: 4.0056 - val_mse: 4.0056 - lr: 5.4497e-05
# Epoch 139/140
# 12/12 [==============================] - 1s 103ms/step - loss: 3.0166 - mse: 3.0166 - val_loss: 4.0040 - val_mse: 4.0040 - lr: 2.4472e-05
# Epoch 140/140
# 12/12 [==============================] - 1s 104ms/step - loss: 3.0441 - mse: 3.0441 - val_loss: 4.0034 - val_mse: 4.0034 - lr: 6.1558e-06
# 2.0710042

# %%
print('mean validation error, 5-fold', euclidean_distance(all_targetsV[:,0], all_targetsV[:,1], all_predsV[:,0], all_predsV[:,1]))
# Out:
# mean validation error, 5-fold 2.0863175

# %%
print('mean validation error, 5-fold', euclidean_distance(all_targetsV[:,0], all_targetsV[:,1], all_predsV[:,0], all_predsV[:,1]))
# Out:
# mean validation error, 5-fold 2.0872567

# %%
# unp=data.path.unique()
import matplotlib.pyplot as plt
# ind=np.array(data.loc[data.path==unp[1],:].index)
X_val2 = data.loc[data.path.isin(val_paths),:].reset_index(drop=True)
ind=np.array(X_val2.loc[X_val2.path==val_paths[2],:].index)
plt.figure(figsize=(10,5))
plt.title('Sigle Path, True and Predicted')

# plt.plot(data.x.iloc[ind].values,data.y.iloc[ind].values,'-.')
plt.plot(all_targetsV[ind,0], all_targetsV[ind,1],'-o',label='target path')
plt.plot(all_predsV[ind,0], all_predsV[ind,1],'-o',label='predicted path')
plt.legend()
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %%
# for NUM_FEATS in range(46,87,4):

# %%
# # CROSS VALIDATION

# name='keras'+version


# np.random.seed(42)
# sh=np.random.permutation(unpaths)

# k=5
# val_size=int(len(sh)/k)
# alls=[]
# for NUM_FEATS in range(46,87,4):
#     print(NUM_FEATS)


#     score_df = pd.DataFrame()
#     oof = list()
#     predictions = list()

#     oof_x, oof_y = np.zeros(data.shape[0]), np.zeros(data.shape[0])
#     preds_x, preds_y = 0, 0

#     scores_per_fold=[]

#     all_preds=[]
#     all_targets=[]

#     for f in range(k):
#         print('fold:', f)

#         if f<(k-1):
#             val_paths=sh[val_size*f:val_size*(f+1)]
#         else:
#             val_paths=sh[val_size*f:]

#         train_paths=[x for x in unpaths if x not in val_paths]
        
#         val_paths=np.array(val_paths)
#         train_paths=np.array(train_paths)

#         X_train = data.loc[data.path.isin(train_paths), BSSID_FEATS + RSSI_FEATS ].reset_index(drop=True)

#         y_train =  data.loc[data.path.isin(train_paths), ['x', 'y'] ].reset_index(drop=True).values

#         X_val = data.loc[data.path.isin(val_paths), BSSID_FEATS + RSSI_FEATS ].reset_index(drop=True)
#         y_val = data.loc[data.path.isin(val_paths), ['x', 'y'] ].reset_index(drop=True).values


#         model = create_model(bssid_size1=NUM_FEATS, rssi_size=NUM_FEATS  )
#         epochs=100
#         snapshots = 5
#         lr_0 = 0.01
#         lr_anneal1 = LearningRateScheduler(schedule=_cosine_anneal_schedule, verbose=False)

#         h = model.fit(np.concatenate((X_train.loc[:,BSSID_FEATS[:NUM_FEATS]].values, X_train.loc[:,RSSI_FEATS[:NUM_FEATS]].values),1),
#                     y_train, 
#                     batch_size=128*8, epochs=epochs, verbose=0,
#                     validation_data=(np.concatenate((X_val.loc[:,BSSID_FEATS[:NUM_FEATS]].values, X_val.loc[:,RSSI_FEATS[:NUM_FEATS]].values),1),
#                     y_val),
#                     callbacks=[ lr_anneal1])
            
#         epochs=100
#         snapshots = 5
#         lr_0 = 0.001
#         lr_anneal1 = LearningRateScheduler(schedule=_cosine_anneal_schedule, verbose=False)

#         h = model.fit(np.concatenate((X_train.loc[:,BSSID_FEATS[:NUM_FEATS]].values, X_train.loc[:,RSSI_FEATS[:NUM_FEATS]].values),1),
#                     y_train, 
#                     batch_size=128*8, epochs=epochs, verbose=0,
#                     validation_data=(np.concatenate((X_val.loc[:,BSSID_FEATS[:NUM_FEATS]].values, X_val.loc[:,RSSI_FEATS[:NUM_FEATS]].values),1),
#                     y_val),
#                     callbacks=[ lr_anneal1])

#         model.save_weights(weights_path+name+'_fold'+str(f)+'.hdf5')
#         val_predsXY = model.predict(np.concatenate((X_val.loc[:,BSSID_FEATS[:NUM_FEATS]].values, X_val.loc[:,RSSI_FEATS[:NUM_FEATS]].values),1)) 

        
#         print(f,euclidean_distance(val_predsXY[:,0], val_predsXY[:,1], y_val[:,0], y_val[:,1]))

#         all_preds.append(val_predsXY)
#         all_targets.append(y_val)
            

#     all_predsV=np.vstack(all_preds)
#     all_targetsV=np.vstack(all_targets)    

#     alls.append(euclidean_distance(all_targetsV[:,0], all_targetsV[:,1], all_predsV[:,0], all_predsV[:,1]))
#     print('mean validation error, 5-fold', euclidean_distance(all_targetsV[:,0], all_targetsV[:,1], all_predsV[:,0], all_predsV[:,1]))

# %%
name
# Out:
# 'kerasforPdata423'

# %%
# plt.plot(np.array(alls))
# plt.show()

# %%
pd.DataFrame(all_predsV,columns=['x', 'y']).to_csv('/gdrive/My Drive/Colab Notebooks/'+name+'_oof.csv.gz', index=False, compression='gzip')
# pd.DataFrame(all_targetsV,columns=['x', 'y']).to_csv('/gdrive/My Drive/Colab Notebooks/all_targetsV.csv.gz', index=False, compression='gzip')

# %%
l=pd.read_csv('/gdrive/My Drive/Colab Notebooks/lgbmforPdata423_oof.csv.gz')

# %%
euclidean_distance(all_targetsV[:,0], all_targetsV[:,1], l.x.values, l.y.values)
# Out:
# 1.9529933161347668

# %%
euclidean_distance(all_targetsV[:,0], all_targetsV[:,1], (l.x.values+all_predsV[:,0])/2, (l.y.values+all_predsV[:,1])/2)
# Out:
# 1.933713321379115

# %%
euclidean_distance(all_targetsV[:,0], all_targetsV[:,1], (2*l.x.values+all_predsV[:,0])/3, (2*l.y.values+all_predsV[:,1])/3)
# Out:
# 1.9206065956477099

# %%
euclidean_distance(all_targetsV[:,0], all_targetsV[:,1], (2.5*l.x.values+all_predsV[:,0])/3.5, (2.5*l.y.values+all_predsV[:,1])/3.5)
# Out:
# 1.9205684892269967

# %%
euclidean_distance(all_targetsV[:,0], all_targetsV[:,1], (l.x.values*all_predsV[:,0])**0.5, (l.y.values*all_predsV[:,1])**0.5)
# Out:
# 1.9334018037272123

# %% [markdown]
# ## EVALUATION - PLOTS

# %%
import matplotlib.pyplot as plt
plt.plot(all_predsV[:,0],all_predsV[:,1],'.')
plt.show()

# %% [markdown]
# **5 FOLD CV PREDICTIONS OVER TARGET GRID**
# With blue dots are the true checkpoints
# Orange dots for predictions

# %%
plt.figure(figsize=(10,10))
plt.title('XY scatter plot of Predicted positions over target grid')
plt.plot(all_predsV[:,0],all_predsV[:,1],'.', label='Predicted position')
plt.plot(all_targetsV[:,0],all_targetsV[:,1],'o', label='target grid')
plt.legend()
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.show()
print('mean validation error, 5-fold', euclidean_distance(all_targetsV[:,0], all_targetsV[:,1], all_predsV[:,0], all_predsV[:,1]))
# Out:
# mean validation error, 5-fold 2.0872567

# %% [markdown]
# ## Full train

# %%
name='keras'+version

train_paths=unpaths[:]

train_paths=np.array(train_paths)
X_train = data.loc[data.path.isin(train_paths), BSSID_FEATS + RSSI_FEATS ].reset_index(drop=True)#.values

y_train =  data.loc[data.path.isin(train_paths), ['x', 'y'] ].reset_index(drop=True).values

model = create_model(bssid_size1=NUM_FEATS, rssi_size=NUM_FEATS  )
epochs=160
snapshots = 8
lr_0 = 0.01
lr_anneal1 = LearningRateScheduler(schedule=_cosine_anneal_schedule, verbose=False)

h = model.fit(np.concatenate((X_train.loc[:,BSSID_FEATS[:NUM_FEATS]].values, X_train.loc[:,RSSI_FEATS[:NUM_FEATS]].values),1),
                  y_train, 
                  batch_size=128*8, epochs=epochs, verbose=1,
                callbacks=[ lr_anneal1])

epochs=160
snapshots = 8
lr_0 = 0.001
lr_anneal1 = LearningRateScheduler(schedule=_cosine_anneal_schedule, verbose=False)

h = model.fit(np.concatenate((X_train.loc[:,BSSID_FEATS[:NUM_FEATS]].values, X_train.loc[:,RSSI_FEATS[:NUM_FEATS]].values),1),
                  y_train, 
                  batch_size=128*8, epochs=epochs, verbose=1,
                callbacks=[ lr_anneal1])
model.save_weights(weights_path+name+'_full'+'.hdf5')
train_predsXY = model.predict(np.concatenate((X_train.loc[:,BSSID_FEATS[:NUM_FEATS]].values, X_train.loc[:,RSSI_FEATS[:NUM_FEATS]].values),1))


print('train error',euclidean_distance(train_predsXY[:,0], train_predsXY[:,1], y_train[:,0], y_train[:,1]))
# Out:
# Epoch 1/160
# 15/15 [==============================] - 10s 84ms/step - loss: 2180.6851 - mse: 2180.6851 - lr: 0.0100
# Epoch 2/160
# 15/15 [==============================] - 1s 81ms/step - loss: 1966.9594 - mse: 1966.9594 - lr: 0.0099
# Epoch 3/160
# 15/15 [==============================] - 1s 84ms/step - loss: 1638.3950 - mse: 1638.3950 - lr: 0.0098
# Epoch 4/160
# 15/15 [==============================] - 1s 82ms/step - loss: 1197.9225 - mse: 1197.9225 - lr: 0.0095
# Epoch 5/160
# 15/15 [==============================] - 1s 82ms/step - loss: 752.6922 - mse: 752.6922 - lr: 0.0090
# Epoch 6/160
# 15/15 [==============================] - 1s 81ms/step - loss: 412.5598 - mse: 412.5598 - lr: 0.0085
# Epoch 7/160
# 15/15 [==============================] - 1s 80ms/step - loss: 203.5890 - mse: 203.5890 - lr: 0.0079
# Epoch 8/160
# 15/15 [==============================] - 1s 82ms/step - loss: 88.1081 - mse: 88.1081 - lr: 0.0073
# Epoch 9/160
# 15/15 [==============================] - 1s 80ms/step - loss: 34.3321 - mse: 34.3321 - lr: 0.0065
# Epoch 10/160
# 15/15 [==============================] - 1s 80ms/step - loss: 14.2801 - mse: 14.2801 - lr: 0.0058
# Epoch 11/160
# 15/15 [==============================] - 1s 81ms/step - loss: 8.1774 - mse: 8.1774 - lr: 0.0050
# Epoch 12/160
# 15/15 [==============================] - 1s 82ms/step - loss: 6.1377 - mse: 6.1377 - lr: 0.0042
# Epoch 13/160
# 15/15 [==============================] - 1s 81ms/step - loss: 5.4432 - mse: 5.4432 - lr: 0.0035
# Epoch 14/160
# 15/15 [==============================] - 1s 81ms/step - loss: 5.1176 - mse: 5.1176 - lr: 0.0027
# Epoch 15/160
# 15/15 [==============================] - 1s 80ms/step - loss: 5.0845 - mse: 5.0845 - lr: 0.0021
# Epoch 16/160
# 15/15 [==============================] - 1s 84ms/step - loss: 4.9022 - mse: 4.9022 - lr: 0.0015
# Epoch 17/160
# 15/15 [==============================] - 1s 83ms/step - loss: 4.8521 - mse: 4.8521 - lr: 9.5492e-04
# Epoch 18/160
# 15/15 [==============================] - 1s 81ms/step - loss: 4.8059 - mse: 4.8059 - lr: 5.4497e-04
# Epoch 19/160
# 15/15 [==============================] - 1s 84ms/step - loss: 4.7667 - mse: 4.7667 - lr: 2.4472e-04
# Epoch 20/160
# 15/15 [==============================] - 1s 82ms/step - loss: 4.7920 - mse: 4.7920 - lr: 6.1558e-05
# Epoch 21/160
# 15/15 [==============================] - 1s 81ms/step - loss: 5.3572 - mse: 5.3572 - lr: 0.0100
# Epoch 22/160
# 15/15 [==============================] - 1s 83ms/step - loss: 5.1326 - mse: 5.1326 - lr: 0.0099
# Epoch 23/160
# 15/15 [==============================] - 1s 85ms/step - loss: 5.5498 - mse: 5.5498 - lr: 0.0098
# Epoch 24/160
# 15/15 [==============================] - 1s 82ms/step - loss: 5.4298 - mse: 5.4298 - lr: 0.0095
# Epoch 25/160
# 15/15 [==============================] - 1s 82ms/step - loss: 5.3640 - mse: 5.3640 - lr: 0.0090
# Epoch 26/160
# 15/15 [==============================] - 1s 82ms/step - loss: 5.3459 - mse: 5.3459 - lr: 0.0085
# Epoch 27/160
# 15/15 [==============================] - 1s 82ms/step - loss: 5.1670 - mse: 5.1670 - lr: 0.0079
# Epoch 28/160
# 15/15 [==============================] - 1s 81ms/step - loss: 5.4272 - mse: 5.4272 - lr: 0.0073
# Epoch 29/160
# 15/15 [==============================] - 1s 83ms/step - loss: 5.2700 - mse: 5.2700 - lr: 0.0065
# Epoch 30/160
# 15/15 [==============================] - 1s 83ms/step - loss: 4.9228 - mse: 4.9228 - lr: 0.0058
# Epoch 31/160
# 15/15 [==============================] - 1s 86ms/step - loss: 4.8167 - mse: 4.8167 - lr: 0.0050
# Epoch 32/160
# 15/15 [==============================] - 1s 84ms/step - loss: 4.6971 - mse: 4.6971 - lr: 0.0042
# Epoch 33/160
# 15/15 [==============================] - 1s 81ms/step - loss: 4.6664 - mse: 4.6664 - lr: 0.0035
# Epoch 34/160
# 15/15 [==============================] - 1s 82ms/step - loss: 4.6622 - mse: 4.6622 - lr: 0.0027
# Epoch 35/160
# 15/15 [==============================] - 1s 84ms/step - loss: 4.4804 - mse: 4.4804 - lr: 0.0021
# Epoch 36/160
# 15/15 [==============================] - 1s 81ms/step - loss: 4.5135 - mse: 4.5135 - lr: 0.0015
# Epoch 37/160
# 15/15 [==============================] - 1s 83ms/step - loss: 4.4098 - mse: 4.4098 - lr: 9.5492e-04
# Epoch 38/160
# 15/15 [==============================] - 1s 83ms/step - loss: 4.3243 - mse: 4.3243 - lr: 5.4497e-04
# Epoch 39/160
# 15/15 [==============================] - 1s 84ms/step - loss: 4.3658 - mse: 4.3658 - lr: 2.4472e-04
# Epoch 40/160
# 15/15 [==============================] - 1s 83ms/step - loss: 4.3157 - mse: 4.3157 - lr: 6.1558e-05
# Epoch 41/160
# 15/15 [==============================] - 1s 85ms/step - loss: 4.7699 - mse: 4.7699 - lr: 0.0100
# Epoch 42/160
# 15/15 [==============================] - 1s 82ms/step - loss: 5.0427 - mse: 5.0427 - lr: 0.0099
# Epoch 43/160
# 15/15 [==============================] - 1s 95ms/step - loss: 4.9786 - mse: 4.9786 - lr: 0.0098
# Epoch 44/160
# 15/15 [==============================] - 1s 84ms/step - loss: 5.4819 - mse: 5.4819 - lr: 0.0095
# Epoch 45/160
# 15/15 [==============================] - 1s 84ms/step - loss: 5.3971 - mse: 5.3971 - lr: 0.0090
# Epoch 46/160
# 15/15 [==============================] - 1s 84ms/step - loss: 5.0940 - mse: 5.0940 - lr: 0.0085
# Epoch 47/160
# 15/15 [==============================] - 1s 83ms/step - loss: 4.9724 - mse: 4.9724 - lr: 0.0079
# Epoch 48/160
# 15/15 [==============================] - 1s 82ms/step - loss: 4.8258 - mse: 4.8258 - lr: 0.0073
# Epoch 49/160
# 15/15 [==============================] - 1s 82ms/step - loss: 4.6824 - mse: 4.6824 - lr: 0.0065
# Epoch 50/160
# 15/15 [==============================] - 1s 84ms/step - loss: 4.7064 - mse: 4.7064 - lr: 0.0058
# Epoch 51/160
# 15/15 [==============================] - 1s 90ms/step - loss: 4.7460 - mse: 4.7460 - lr: 0.0050
# Epoch 52/160
# 15/15 [==============================] - 1s 82ms/step - loss: 4.7106 - mse: 4.7106 - lr: 0.0042
# Epoch 53/160
# 15/15 [==============================] - 1s 83ms/step - loss: 4.6920 - mse: 4.6920 - lr: 0.0035
# Epoch 54/160
# 15/15 [==============================] - 1s 83ms/step - loss: 4.6084 - mse: 4.6084 - lr: 0.0027
# Epoch 55/160
# 15/15 [==============================] - 1s 84ms/step - loss: 4.4890 - mse: 4.4890 - lr: 0.0021
# Epoch 56/160
# 15/15 [==============================] - 1s 84ms/step - loss: 4.3835 - mse: 4.3835 - lr: 0.0015
# Epoch 57/160
# 15/15 [==============================] - 1s 83ms/step - loss: 4.3241 - mse: 4.3241 - lr: 9.5492e-04
# Epoch 58/160
# 15/15 [==============================] - 1s 82ms/step - loss: 4.2940 - mse: 4.2940 - lr: 5.4497e-04
# Epoch 59/160
# 15/15 [==============================] - 1s 90ms/step - loss: 4.1662 - mse: 4.1662 - lr: 2.4472e-04
# Epoch 60/160
# 15/15 [==============================] - 1s 82ms/step - loss: 4.2974 - mse: 4.2974 - lr: 6.1558e-05
# Epoch 61/160
# 15/15 [==============================] - 1s 84ms/step - loss: 4.4249 - mse: 4.4249 - lr: 0.0100
# Epoch 62/160
# 15/15 [==============================] - 1s 87ms/step - loss: 4.5171 - mse: 4.5171 - lr: 0.0099
# Epoch 63/160
# 15/15 [==============================] - 1s 85ms/step - loss: 4.8147 - mse: 4.8147 - lr: 0.0098
# Epoch 64/160
# 15/15 [==============================] - 1s 83ms/step - loss: 4.6206 - mse: 4.6206 - lr: 0.0095
# Epoch 65/160
# 15/15 [==============================] - 1s 82ms/step - loss: 4.6838 - mse: 4.6838 - lr: 0.0090
# Epoch 66/160
# 15/15 [==============================] - 1s 87ms/step - loss: 4.6512 - mse: 4.6512 - lr: 0.0085
# Epoch 67/160
# 15/15 [==============================] - 1s 84ms/step - loss: 4.4475 - mse: 4.4475 - lr: 0.0079
# Epoch 68/160
# 15/15 [==============================] - 1s 87ms/step - loss: 4.3897 - mse: 4.3897 - lr: 0.0073
# Epoch 69/160
# 15/15 [==============================] - 1s 81ms/step - loss: 4.4177 - mse: 4.4177 - lr: 0.0065
# Epoch 70/160
# 15/15 [==============================] - 1s 87ms/step - loss: 4.2842 - mse: 4.2842 - lr: 0.0058
# Epoch 71/160
# 15/15 [==============================] - 1s 88ms/step - loss: 4.1131 - mse: 4.1131 - lr: 0.0050
# Epoch 72/160
# 15/15 [==============================] - 1s 84ms/step - loss: 4.1603 - mse: 4.1603 - lr: 0.0042
# Epoch 73/160
# 15/15 [==============================] - 1s 82ms/step - loss: 4.0802 - mse: 4.0802 - lr: 0.0035
# Epoch 74/160
# 15/15 [==============================] - 1s 85ms/step - loss: 4.1272 - mse: 4.1272 - lr: 0.0027
# Epoch 75/160
# 15/15 [==============================] - 1s 82ms/step - loss: 4.1639 - mse: 4.1639 - lr: 0.0021
# Epoch 76/160
# 15/15 [==============================] - 1s 82ms/step - loss: 4.1341 - mse: 4.1341 - lr: 0.0015
# Epoch 77/160
# 15/15 [==============================] - 1s 84ms/step - loss: 3.9945 - mse: 3.9945 - lr: 9.5492e-04
# Epoch 78/160
# 15/15 [==============================] - 1s 88ms/step - loss: 3.9910 - mse: 3.9910 - lr: 5.4497e-04
# Epoch 79/160
# 15/15 [==============================] - 1s 86ms/step - loss: 4.0566 - mse: 4.0566 - lr: 2.4472e-04
# Epoch 80/160
# 15/15 [==============================] - 1s 82ms/step - loss: 3.9734 - mse: 3.9734 - lr: 6.1558e-05
# Epoch 81/160
# 15/15 [==============================] - 1s 84ms/step - loss: 4.1741 - mse: 4.1741 - lr: 0.0100
# Epoch 82/160
# 15/15 [==============================] - 1s 94ms/step - loss: 4.3250 - mse: 4.3250 - lr: 0.0099
# Epoch 83/160
# 15/15 [==============================] - 1s 84ms/step - loss: 4.4646 - mse: 4.4646 - lr: 0.0098
# Epoch 84/160
# 15/15 [==============================] - 1s 86ms/step - loss: 4.4223 - mse: 4.4223 - lr: 0.0095
# Epoch 85/160
# 15/15 [==============================] - 1s 87ms/step - loss: 4.4614 - mse: 4.4614 - lr: 0.0090
# Epoch 86/160
# 15/15 [==============================] - 1s 93ms/step - loss: 4.3861 - mse: 4.3861 - lr: 0.0085
# Epoch 87/160
# 15/15 [==============================] - 1s 83ms/step - loss: 4.2527 - mse: 4.2527 - lr: 0.0079
# Epoch 88/160
# 15/15 [==============================] - 1s 80ms/step - loss: 4.4797 - mse: 4.4797 - lr: 0.0073
# Epoch 89/160
# 15/15 [==============================] - 1s 83ms/step - loss: 4.3569 - mse: 4.3569 - lr: 0.0065
# Epoch 90/160
# 15/15 [==============================] - 1s 87ms/step - loss: 4.3303 - mse: 4.3303 - lr: 0.0058
# Epoch 91/160
# 15/15 [==============================] - 1s 84ms/step - loss: 4.3078 - mse: 4.3078 - lr: 0.0050
# Epoch 92/160
# 15/15 [==============================] - 1s 82ms/step - loss: 4.2860 - mse: 4.2860 - lr: 0.0042
# Epoch 93/160
# 15/15 [==============================] - 1s 84ms/step - loss: 4.1210 - mse: 4.1210 - lr: 0.0035
# Epoch 94/160
# 15/15 [==============================] - 1s 89ms/step - loss: 4.0369 - mse: 4.0369 - lr: 0.0027
# Epoch 95/160
# 15/15 [==============================] - 1s 88ms/step - loss: 4.0562 - mse: 4.0562 - lr: 0.0021
# Epoch 96/160
# 15/15 [==============================] - 1s 87ms/step - loss: 3.9500 - mse: 3.9500 - lr: 0.0015
# Epoch 97/160
# 15/15 [==============================] - 1s 86ms/step - loss: 3.8718 - mse: 3.8718 - lr: 9.5492e-04
# Epoch 98/160
# 15/15 [==============================] - 1s 85ms/step - loss: 3.9053 - mse: 3.9053 - lr: 5.4497e-04
# Epoch 99/160
# 15/15 [==============================] - 1s 85ms/step - loss: 3.9534 - mse: 3.9534 - lr: 2.4472e-04
# Epoch 100/160
# 15/15 [==============================] - 1s 85ms/step - loss: 3.8886 - mse: 3.8886 - lr: 6.1558e-05
# Epoch 101/160
# 15/15 [==============================] - 1s 88ms/step - loss: 4.0211 - mse: 4.0211 - lr: 0.0100
# Epoch 102/160
# 15/15 [==============================] - 1s 87ms/step - loss: 4.0945 - mse: 4.0945 - lr: 0.0099
# Epoch 103/160
# 15/15 [==============================] - 1s 84ms/step - loss: 4.3724 - mse: 4.3724 - lr: 0.0098
# Epoch 104/160
# 15/15 [==============================] - 1s 82ms/step - loss: 4.6768 - mse: 4.6768 - lr: 0.0095
# Epoch 105/160
# 15/15 [==============================] - 1s 83ms/step - loss: 4.6167 - mse: 4.6167 - lr: 0.0090
# Epoch 106/160
# 15/15 [==============================] - 1s 84ms/step - loss: 4.6445 - mse: 4.6445 - lr: 0.0085
# Epoch 107/160
# 15/15 [==============================] - 1s 82ms/step - loss: 4.6579 - mse: 4.6579 - lr: 0.0079
# Epoch 108/160
# 15/15 [==============================] - 1s 85ms/step - loss: 4.5888 - mse: 4.5888 - lr: 0.0073
# Epoch 109/160
# 15/15 [==============================] - 1s 87ms/step - loss: 4.4772 - mse: 4.4772 - lr: 0.0065
# Epoch 110/160
# 15/15 [==============================] - 1s 84ms/step - loss: 4.1710 - mse: 4.1710 - lr: 0.0058
# Epoch 111/160
# 15/15 [==============================] - 1s 83ms/step - loss: 4.4489 - mse: 4.4489 - lr: 0.0050
# Epoch 112/160
# 15/15 [==============================] - 1s 82ms/step - loss: 4.2562 - mse: 4.2562 - lr: 0.0042
# Epoch 113/160
# 15/15 [==============================] - 1s 88ms/step - loss: 4.2591 - mse: 4.2591 - lr: 0.0035
# Epoch 114/160
# 15/15 [==============================] - 1s 84ms/step - loss: 4.0711 - mse: 4.0711 - lr: 0.0027
# Epoch 115/160
# 15/15 [==============================] - 1s 81ms/step - loss: 4.0328 - mse: 4.0328 - lr: 0.0021
# Epoch 116/160
# 15/15 [==============================] - 1s 83ms/step - loss: 3.9853 - mse: 3.9853 - lr: 0.0015
# Epoch 117/160
# 15/15 [==============================] - 1s 94ms/step - loss: 3.9662 - mse: 3.9662 - lr: 9.5492e-04
# Epoch 118/160
# 15/15 [==============================] - 1s 86ms/step - loss: 3.9277 - mse: 3.9277 - lr: 5.4497e-04
# Epoch 119/160
# 15/15 [==============================] - 1s 88ms/step - loss: 3.9125 - mse: 3.9125 - lr: 2.4472e-04
# Epoch 120/160
# 15/15 [==============================] - 1s 91ms/step - loss: 3.8900 - mse: 3.8900 - lr: 6.1558e-05
# Epoch 121/160
# 15/15 [==============================] - 1s 90ms/step - loss: 4.0540 - mse: 4.0540 - lr: 0.0100
# Epoch 122/160
# 15/15 [==============================] - 1s 95ms/step - loss: 4.3342 - mse: 4.3342 - lr: 0.0099
# Epoch 123/160
# 15/15 [==============================] - 1s 88ms/step - loss: 4.2615 - mse: 4.2615 - lr: 0.0098
# Epoch 124/160
# 15/15 [==============================] - 1s 99ms/step - loss: 4.4023 - mse: 4.4023 - lr: 0.0095
# Epoch 125/160
# 15/15 [==============================] - 1s 91ms/step - loss: 4.3173 - mse: 4.3173 - lr: 0.0090
# Epoch 126/160
# 15/15 [==============================] - 1s 87ms/step - loss: 4.3953 - mse: 4.3953 - lr: 0.0085
# Epoch 127/160
# 15/15 [==============================] - 1s 84ms/step - loss: 4.8852 - mse: 4.8852 - lr: 0.0079
# Epoch 128/160
# 15/15 [==============================] - 1s 82ms/step - loss: 5.2677 - mse: 5.2677 - lr: 0.0073
# Epoch 129/160
# 15/15 [==============================] - 1s 84ms/step - loss: 4.8360 - mse: 4.8360 - lr: 0.0065
# Epoch 130/160
# 15/15 [==============================] - 1s 87ms/step - loss: 4.5932 - mse: 4.5932 - lr: 0.0058
# Epoch 131/160
# 15/15 [==============================] - 1s 86ms/step - loss: 4.5906 - mse: 4.5906 - lr: 0.0050
# Epoch 132/160
# 15/15 [==============================] - 1s 92ms/step - loss: 4.3605 - mse: 4.3605 - lr: 0.0042
# Epoch 133/160
# 15/15 [==============================] - 1s 83ms/step - loss: 4.3133 - mse: 4.3133 - lr: 0.0035
# Epoch 134/160
# 15/15 [==============================] - 1s 83ms/step - loss: 4.2731 - mse: 4.2731 - lr: 0.0027
# Epoch 135/160
# 15/15 [==============================] - 1s 83ms/step - loss: 4.1234 - mse: 4.1234 - lr: 0.0021
# Epoch 136/160
# 15/15 [==============================] - 1s 84ms/step - loss: 4.1950 - mse: 4.1950 - lr: 0.0015
# Epoch 137/160
# 15/15 [==============================] - 1s 85ms/step - loss: 4.0656 - mse: 4.0656 - lr: 9.5492e-04
# Epoch 138/160
# 15/15 [==============================] - 1s 84ms/step - loss: 4.0723 - mse: 4.0723 - lr: 5.4497e-04
# Epoch 139/160
# 15/15 [==============================] - 1s 82ms/step - loss: 4.1173 - mse: 4.1173 - lr: 2.4472e-04
# Epoch 140/160
# 15/15 [==============================] - 1s 87ms/step - loss: 4.0828 - mse: 4.0828 - lr: 6.1558e-05
# Epoch 141/160
# 15/15 [==============================] - 1s 84ms/step - loss: 4.2032 - mse: 4.2032 - lr: 0.0100
# Epoch 142/160
# 15/15 [==============================] - 1s 86ms/step - loss: 4.3240 - mse: 4.3240 - lr: 0.0099
# Epoch 143/160
# 15/15 [==============================] - 1s 88ms/step - loss: 4.4393 - mse: 4.4393 - lr: 0.0098
# Epoch 144/160
# 15/15 [==============================] - 1s 87ms/step - loss: 4.3916 - mse: 4.3916 - lr: 0.0095
# Epoch 145/160
# 15/15 [==============================] - 1s 88ms/step - loss: 4.3379 - mse: 4.3379 - lr: 0.0090
# Epoch 146/160
# 15/15 [==============================] - 1s 87ms/step - loss: 4.3106 - mse: 4.3106 - lr: 0.0085
# Epoch 147/160
# 15/15 [==============================] - 1s 86ms/step - loss: 4.3861 - mse: 4.3861 - lr: 0.0079
# Epoch 148/160
# 15/15 [==============================] - 1s 87ms/step - loss: 4.3146 - mse: 4.3146 - lr: 0.0073
# Epoch 149/160
# 15/15 [==============================] - 1s 87ms/step - loss: 4.0560 - mse: 4.0560 - lr: 0.0065
# Epoch 150/160
# 15/15 [==============================] - 1s 88ms/step - loss: 4.2018 - mse: 4.2018 - lr: 0.0058
# Epoch 151/160
# 15/15 [==============================] - 1s 89ms/step - loss: 4.1165 - mse: 4.1165 - lr: 0.0050
# Epoch 152/160
# 15/15 [==============================] - 1s 85ms/step - loss: 4.0723 - mse: 4.0723 - lr: 0.0042
# Epoch 153/160
# 15/15 [==============================] - 1s 86ms/step - loss: 3.9820 - mse: 3.9820 - lr: 0.0035
# Epoch 154/160
# 15/15 [==============================] - 1s 87ms/step - loss: 3.9914 - mse: 3.9914 - lr: 0.0027
# Epoch 155/160
# 15/15 [==============================] - 1s 93ms/step - loss: 3.9002 - mse: 3.9002 - lr: 0.0021
# Epoch 156/160
# 15/15 [==============================] - 1s 86ms/step - loss: 3.9042 - mse: 3.9042 - lr: 0.0015
# Epoch 157/160
# 15/15 [==============================] - 1s 91ms/step - loss: 3.8736 - mse: 3.8736 - lr: 9.5492e-04
# Epoch 158/160
# 15/15 [==============================] - 1s 87ms/step - loss: 3.9416 - mse: 3.9416 - lr: 5.4497e-04
# Epoch 159/160
# 15/15 [==============================] - 1s 92ms/step - loss: 3.7530 - mse: 3.7530 - lr: 2.4472e-04
# Epoch 160/160
# 15/15 [==============================] - 1s 85ms/step - loss: 3.9082 - mse: 3.9082 - lr: 6.1558e-05
# Epoch 1/160
# 15/15 [==============================] - 1s 86ms/step - loss: 3.7160 - mse: 3.7160 - lr: 0.0010
# Epoch 2/160
# 15/15 [==============================] - 1s 90ms/step - loss: 3.8674 - mse: 3.8674 - lr: 9.9384e-04
# Epoch 3/160
# 15/15 [==============================] - 1s 93ms/step - loss: 3.7247 - mse: 3.7247 - lr: 9.7553e-04
# Epoch 4/160
# 15/15 [==============================] - 1s 87ms/step - loss: 3.7653 - mse: 3.7653 - lr: 9.4550e-04
# Epoch 5/160
# 15/15 [==============================] - 1s 84ms/step - loss: 3.7744 - mse: 3.7744 - lr: 9.0451e-04
# Epoch 6/160
# 15/15 [==============================] - 1s 89ms/step - loss: 3.7914 - mse: 3.7914 - lr: 8.5355e-04
# Epoch 7/160
# 15/15 [==============================] - 1s 87ms/step - loss: 3.7877 - mse: 3.7877 - lr: 7.9389e-04
# Epoch 8/160
# 15/15 [==============================] - 1s 86ms/step - loss: 3.7689 - mse: 3.7689 - lr: 7.2700e-04
# Epoch 9/160
# 15/15 [==============================] - 1s 84ms/step - loss: 3.7886 - mse: 3.7886 - lr: 6.5451e-04
# Epoch 10/160
# 15/15 [==============================] - 1s 86ms/step - loss: 3.6795 - mse: 3.6795 - lr: 5.7822e-04
# Epoch 11/160
# 15/15 [==============================] - 1s 85ms/step - loss: 3.7273 - mse: 3.7273 - lr: 5.0000e-04
# Epoch 12/160
# 15/15 [==============================] - 1s 84ms/step - loss: 3.7067 - mse: 3.7067 - lr: 4.2178e-04
# Epoch 13/160
# 15/15 [==============================] - 1s 89ms/step - loss: 3.7138 - mse: 3.7138 - lr: 3.4549e-04
# Epoch 14/160
# 15/15 [==============================] - 1s 86ms/step - loss: 3.6888 - mse: 3.6888 - lr: 2.7300e-04
# Epoch 15/160
# 15/15 [==============================] - 1s 85ms/step - loss: 3.7329 - mse: 3.7329 - lr: 2.0611e-04
# Epoch 16/160
# 15/15 [==============================] - 1s 85ms/step - loss: 3.6670 - mse: 3.6670 - lr: 1.4645e-04
# Epoch 17/160
# 15/15 [==============================] - 1s 84ms/step - loss: 3.6638 - mse: 3.6638 - lr: 9.5492e-05
# Epoch 18/160
# 15/15 [==============================] - 1s 85ms/step - loss: 3.6847 - mse: 3.6847 - lr: 5.4497e-05
# Epoch 19/160
# 15/15 [==============================] - 1s 84ms/step - loss: 3.7492 - mse: 3.7492 - lr: 2.4472e-05
# Epoch 20/160
# 15/15 [==============================] - 1s 85ms/step - loss: 3.8247 - mse: 3.8247 - lr: 6.1558e-06
# Epoch 21/160
# 15/15 [==============================] - 1s 85ms/step - loss: 3.6817 - mse: 3.6817 - lr: 0.0010
# Epoch 22/160
# 15/15 [==============================] - 1s 101ms/step - loss: 3.7281 - mse: 3.7281 - lr: 9.9384e-04
# Epoch 23/160
# 15/15 [==============================] - 1s 84ms/step - loss: 3.6418 - mse: 3.6418 - lr: 9.7553e-04
# Epoch 24/160
# 15/15 [==============================] - 1s 86ms/step - loss: 3.7671 - mse: 3.7671 - lr: 9.4550e-04
# Epoch 25/160
# 15/15 [==============================] - 1s 85ms/step - loss: 3.7098 - mse: 3.7098 - lr: 9.0451e-04
# Epoch 26/160
# 15/15 [==============================] - 1s 83ms/step - loss: 3.7041 - mse: 3.7041 - lr: 8.5355e-04
# Epoch 27/160
# 15/15 [==============================] - 1s 85ms/step - loss: 3.7331 - mse: 3.7331 - lr: 7.9389e-04
# Epoch 28/160
# 15/15 [==============================] - 1s 84ms/step - loss: 3.6371 - mse: 3.6371 - lr: 7.2700e-04
# Epoch 29/160
# 15/15 [==============================] - 1s 90ms/step - loss: 3.7499 - mse: 3.7499 - lr: 6.5451e-04
# Epoch 30/160
# 15/15 [==============================] - 1s 86ms/step - loss: 3.6338 - mse: 3.6338 - lr: 5.7822e-04
# Epoch 31/160
# 15/15 [==============================] - 1s 88ms/step - loss: 3.6372 - mse: 3.6372 - lr: 5.0000e-04
# Epoch 32/160
# 15/15 [==============================] - 1s 86ms/step - loss: 3.6505 - mse: 3.6505 - lr: 4.2178e-04
# Epoch 33/160
# 15/15 [==============================] - 1s 87ms/step - loss: 3.7333 - mse: 3.7333 - lr: 3.4549e-04
# Epoch 34/160
# 15/15 [==============================] - 1s 85ms/step - loss: 3.6314 - mse: 3.6314 - lr: 2.7300e-04
# Epoch 35/160
# 15/15 [==============================] - 1s 84ms/step - loss: 3.6772 - mse: 3.6772 - lr: 2.0611e-04
# Epoch 36/160
# 15/15 [==============================] - 1s 84ms/step - loss: 3.7705 - mse: 3.7705 - lr: 1.4645e-04
# Epoch 37/160
# 15/15 [==============================] - 1s 90ms/step - loss: 3.6484 - mse: 3.6484 - lr: 9.5492e-05
# Epoch 38/160
# 15/15 [==============================] - 1s 86ms/step - loss: 3.6458 - mse: 3.6458 - lr: 5.4497e-05
# Epoch 39/160
# 15/15 [==============================] - 1s 85ms/step - loss: 3.7377 - mse: 3.7377 - lr: 2.4472e-05
# Epoch 40/160
# 15/15 [==============================] - 1s 83ms/step - loss: 3.6278 - mse: 3.6278 - lr: 6.1558e-06
# Epoch 41/160
# 15/15 [==============================] - 1s 87ms/step - loss: 3.6982 - mse: 3.6982 - lr: 0.0010
# Epoch 42/160
# 15/15 [==============================] - 1s 85ms/step - loss: 3.6035 - mse: 3.6035 - lr: 9.9384e-04
# Epoch 43/160
# 15/15 [==============================] - 1s 83ms/step - loss: 3.6973 - mse: 3.6973 - lr: 9.7553e-04
# Epoch 44/160
# 15/15 [==============================] - 1s 85ms/step - loss: 3.7106 - mse: 3.7106 - lr: 9.4550e-04
# Epoch 45/160
# 15/15 [==============================] - 1s 96ms/step - loss: 3.6877 - mse: 3.6877 - lr: 9.0451e-04
# Epoch 46/160
# 15/15 [==============================] - 1s 84ms/step - loss: 3.6638 - mse: 3.6638 - lr: 8.5355e-04
# Epoch 47/160
# 15/15 [==============================] - 1s 83ms/step - loss: 3.6399 - mse: 3.6399 - lr: 7.9389e-04
# Epoch 48/160
# 15/15 [==============================] - 1s 89ms/step - loss: 3.6542 - mse: 3.6542 - lr: 7.2700e-04
# Epoch 49/160
# 15/15 [==============================] - 1s 86ms/step - loss: 3.7138 - mse: 3.7138 - lr: 6.5451e-04
# Epoch 50/160
# 15/15 [==============================] - 1s 87ms/step - loss: 3.6287 - mse: 3.6287 - lr: 5.7822e-04
# Epoch 51/160
# 15/15 [==============================] - 1s 84ms/step - loss: 3.6925 - mse: 3.6925 - lr: 5.0000e-04
# Epoch 52/160
# 15/15 [==============================] - 1s 90ms/step - loss: 3.6392 - mse: 3.6392 - lr: 4.2178e-04
# Epoch 53/160
# 15/15 [==============================] - 1s 85ms/step - loss: 3.6368 - mse: 3.6368 - lr: 3.4549e-04
# Epoch 54/160
# 15/15 [==============================] - 1s 86ms/step - loss: 3.6174 - mse: 3.6174 - lr: 2.7300e-04
# Epoch 55/160
# 15/15 [==============================] - 1s 85ms/step - loss: 3.6029 - mse: 3.6029 - lr: 2.0611e-04
# Epoch 56/160
# 15/15 [==============================] - 1s 91ms/step - loss: 3.5159 - mse: 3.5159 - lr: 1.4645e-04
# Epoch 57/160
# 15/15 [==============================] - 1s 88ms/step - loss: 3.5782 - mse: 3.5782 - lr: 9.5492e-05
# Epoch 58/160
# 15/15 [==============================] - 1s 85ms/step - loss: 3.5909 - mse: 3.5909 - lr: 5.4497e-05
# Epoch 59/160
# 15/15 [==============================] - 1s 84ms/step - loss: 3.6730 - mse: 3.6730 - lr: 2.4472e-05
# Epoch 60/160
# 15/15 [==============================] - 1s 88ms/step - loss: 3.6340 - mse: 3.6340 - lr: 6.1558e-06
# Epoch 61/160
# 15/15 [==============================] - 1s 85ms/step - loss: 3.6469 - mse: 3.6469 - lr: 0.0010
# Epoch 62/160
# 15/15 [==============================] - 1s 84ms/step - loss: 3.6724 - mse: 3.6724 - lr: 9.9384e-04
# Epoch 63/160
# 15/15 [==============================] - 1s 87ms/step - loss: 3.6035 - mse: 3.6035 - lr: 9.7553e-04
# Epoch 64/160
# 15/15 [==============================] - 1s 87ms/step - loss: 3.6254 - mse: 3.6254 - lr: 9.4550e-04
# Epoch 65/160
# 15/15 [==============================] - 1s 86ms/step - loss: 3.5797 - mse: 3.5797 - lr: 9.0451e-04
# Epoch 66/160
# 15/15 [==============================] - 1s 85ms/step - loss: 3.6472 - mse: 3.6472 - lr: 8.5355e-04
# Epoch 67/160
# 15/15 [==============================] - 1s 86ms/step - loss: 3.5626 - mse: 3.5626 - lr: 7.9389e-04
# Epoch 68/160
# 15/15 [==============================] - 1s 86ms/step - loss: 3.6298 - mse: 3.6298 - lr: 7.2700e-04
# Epoch 69/160
# 15/15 [==============================] - 1s 87ms/step - loss: 3.6045 - mse: 3.6045 - lr: 6.5451e-04
# Epoch 70/160
# 15/15 [==============================] - 1s 94ms/step - loss: 3.6084 - mse: 3.6084 - lr: 5.7822e-04
# Epoch 71/160
# 15/15 [==============================] - 1s 85ms/step - loss: 3.5957 - mse: 3.5957 - lr: 5.0000e-04
# Epoch 72/160
# 15/15 [==============================] - 1s 86ms/step - loss: 3.6607 - mse: 3.6607 - lr: 4.2178e-04
# Epoch 73/160
# 15/15 [==============================] - 1s 85ms/step - loss: 3.6532 - mse: 3.6532 - lr: 3.4549e-04
# Epoch 74/160
# 15/15 [==============================] - 1s 87ms/step - loss: 3.5757 - mse: 3.5757 - lr: 2.7300e-04
# Epoch 75/160
# 15/15 [==============================] - 1s 85ms/step - loss: 3.6137 - mse: 3.6137 - lr: 2.0611e-04
# Epoch 76/160
# 15/15 [==============================] - 1s 85ms/step - loss: 3.6397 - mse: 3.6397 - lr: 1.4645e-04
# Epoch 77/160
# 15/15 [==============================] - 1s 85ms/step - loss: 3.6375 - mse: 3.6375 - lr: 9.5492e-05
# Epoch 78/160
# 15/15 [==============================] - 1s 90ms/step - loss: 3.6581 - mse: 3.6581 - lr: 5.4497e-05
# Epoch 79/160
# 15/15 [==============================] - 1s 88ms/step - loss: 3.6124 - mse: 3.6124 - lr: 2.4472e-05
# Epoch 80/160
# 15/15 [==============================] - 1s 85ms/step - loss: 3.6051 - mse: 3.6051 - lr: 6.1558e-06
# Epoch 81/160
# 15/15 [==============================] - 1s 85ms/step - loss: 3.6310 - mse: 3.6310 - lr: 0.0010
# Epoch 82/160
# 15/15 [==============================] - 1s 87ms/step - loss: 3.6203 - mse: 3.6203 - lr: 9.9384e-04
# Epoch 83/160
# 15/15 [==============================] - 1s 86ms/step - loss: 3.6012 - mse: 3.6012 - lr: 9.7553e-04
# Epoch 84/160
# 15/15 [==============================] - 1s 87ms/step - loss: 3.6156 - mse: 3.6156 - lr: 9.4550e-04
# Epoch 85/160
# 15/15 [==============================] - 1s 91ms/step - loss: 3.5960 - mse: 3.5960 - lr: 9.0451e-04
# Epoch 86/160
# 15/15 [==============================] - 1s 86ms/step - loss: 3.6646 - mse: 3.6646 - lr: 8.5355e-04
# Epoch 87/160
# 15/15 [==============================] - 1s 89ms/step - loss: 3.5988 - mse: 3.5988 - lr: 7.9389e-04
# Epoch 88/160
# 15/15 [==============================] - 1s 84ms/step - loss: 3.6435 - mse: 3.6435 - lr: 7.2700e-04
# Epoch 89/160
# 15/15 [==============================] - 1s 84ms/step - loss: 3.5316 - mse: 3.5316 - lr: 6.5451e-04
# Epoch 90/160
# 15/15 [==============================] - 1s 86ms/step - loss: 3.5590 - mse: 3.5590 - lr: 5.7822e-04
# Epoch 91/160
# 15/15 [==============================] - 1s 85ms/step - loss: 3.5520 - mse: 3.5520 - lr: 5.0000e-04
# Epoch 92/160
# 15/15 [==============================] - 1s 85ms/step - loss: 3.5328 - mse: 3.5328 - lr: 4.2178e-04
# Epoch 93/160
# 15/15 [==============================] - 1s 84ms/step - loss: 3.5377 - mse: 3.5377 - lr: 3.4549e-04
# Epoch 94/160
# 15/15 [==============================] - 1s 91ms/step - loss: 3.5799 - mse: 3.5799 - lr: 2.7300e-04
# Epoch 95/160
# 15/15 [==============================] - 1s 85ms/step - loss: 3.5352 - mse: 3.5352 - lr: 2.0611e-04
# Epoch 96/160
# 15/15 [==============================] - 1s 86ms/step - loss: 3.5441 - mse: 3.5441 - lr: 1.4645e-04
# Epoch 97/160
# 15/15 [==============================] - 1s 85ms/step - loss: 3.5543 - mse: 3.5543 - lr: 9.5492e-05
# Epoch 98/160
# 15/15 [==============================] - 1s 85ms/step - loss: 3.5557 - mse: 3.5557 - lr: 5.4497e-05
# Epoch 99/160
# 15/15 [==============================] - 1s 84ms/step - loss: 3.6173 - mse: 3.6173 - lr: 2.4472e-05
# Epoch 100/160
# 15/15 [==============================] - 1s 91ms/step - loss: 3.5170 - mse: 3.5170 - lr: 6.1558e-06
# Epoch 101/160
# 15/15 [==============================] - 1s 85ms/step - loss: 3.5800 - mse: 3.5800 - lr: 0.0010
# Epoch 102/160
# 15/15 [==============================] - 1s 93ms/step - loss: 3.5356 - mse: 3.5356 - lr: 9.9384e-04
# Epoch 103/160
# 15/15 [==============================] - 1s 87ms/step - loss: 3.5389 - mse: 3.5389 - lr: 9.7553e-04
# Epoch 104/160
# 15/15 [==============================] - 1s 87ms/step - loss: 3.6051 - mse: 3.6051 - lr: 9.4550e-04
# Epoch 105/160
# 15/15 [==============================] - 1s 85ms/step - loss: 3.5630 - mse: 3.5630 - lr: 9.0451e-04
# Epoch 106/160
# 15/15 [==============================] - 1s 84ms/step - loss: 3.5018 - mse: 3.5018 - lr: 8.5355e-04
# Epoch 107/160
# 15/15 [==============================] - 1s 86ms/step - loss: 3.5550 - mse: 3.5550 - lr: 7.9389e-04
# Epoch 108/160
# 15/15 [==============================] - 1s 84ms/step - loss: 3.5091 - mse: 3.5091 - lr: 7.2700e-04
# Epoch 109/160
# 15/15 [==============================] - 1s 83ms/step - loss: 3.4563 - mse: 3.4563 - lr: 6.5451e-04
# Epoch 110/160
# 15/15 [==============================] - 1s 87ms/step - loss: 3.5989 - mse: 3.5989 - lr: 5.7822e-04
# Epoch 111/160
# 15/15 [==============================] - 1s 84ms/step - loss: 3.5193 - mse: 3.5193 - lr: 5.0000e-04
# Epoch 112/160
# 15/15 [==============================] - 1s 85ms/step - loss: 3.4697 - mse: 3.4697 - lr: 4.2178e-04
# Epoch 113/160
# 15/15 [==============================] - 1s 87ms/step - loss: 3.5440 - mse: 3.5440 - lr: 3.4549e-04
# Epoch 114/160
# 15/15 [==============================] - 1s 91ms/step - loss: 3.5159 - mse: 3.5159 - lr: 2.7300e-04
# Epoch 115/160
# 15/15 [==============================] - 1s 85ms/step - loss: 3.4978 - mse: 3.4978 - lr: 2.0611e-04
# Epoch 116/160
# 15/15 [==============================] - 1s 86ms/step - loss: 3.4693 - mse: 3.4693 - lr: 1.4645e-04
# Epoch 117/160
# 15/15 [==============================] - 1s 92ms/step - loss: 3.5543 - mse: 3.5543 - lr: 9.5492e-05
# Epoch 118/160
# 15/15 [==============================] - 1s 85ms/step - loss: 3.4429 - mse: 3.4429 - lr: 5.4497e-05
# Epoch 119/160
# 15/15 [==============================] - 1s 88ms/step - loss: 3.4814 - mse: 3.4814 - lr: 2.4472e-05
# Epoch 120/160
# 15/15 [==============================] - 1s 86ms/step - loss: 3.5322 - mse: 3.5322 - lr: 6.1558e-06
# Epoch 121/160
# 15/15 [==============================] - 1s 86ms/step - loss: 3.4624 - mse: 3.4624 - lr: 0.0010
# Epoch 122/160
# 15/15 [==============================] - 1s 87ms/step - loss: 3.6021 - mse: 3.6021 - lr: 9.9384e-04
# Epoch 123/160
# 15/15 [==============================] - 1s 89ms/step - loss: 3.5859 - mse: 3.5859 - lr: 9.7553e-04
# Epoch 124/160
# 15/15 [==============================] - 1s 88ms/step - loss: 3.4764 - mse: 3.4764 - lr: 9.4550e-04
# Epoch 125/160
# 15/15 [==============================] - 1s 94ms/step - loss: 3.3932 - mse: 3.3932 - lr: 9.0451e-04
# Epoch 126/160
# 15/15 [==============================] - 1s 86ms/step - loss: 3.5817 - mse: 3.5817 - lr: 8.5355e-04
# Epoch 127/160
# 15/15 [==============================] - 1s 85ms/step - loss: 3.4679 - mse: 3.4679 - lr: 7.9389e-04
# Epoch 128/160
# 15/15 [==============================] - 1s 86ms/step - loss: 3.4696 - mse: 3.4696 - lr: 7.2700e-04
# Epoch 129/160
# 15/15 [==============================] - 1s 85ms/step - loss: 3.5749 - mse: 3.5749 - lr: 6.5451e-04
# Epoch 130/160
# 15/15 [==============================] - 1s 85ms/step - loss: 3.5498 - mse: 3.5498 - lr: 5.7822e-04
# Epoch 131/160
# 15/15 [==============================] - 1s 85ms/step - loss: 3.4255 - mse: 3.4255 - lr: 5.0000e-04
# Epoch 132/160
# 15/15 [==============================] - 1s 90ms/step - loss: 3.5101 - mse: 3.5101 - lr: 4.2178e-04
# Epoch 133/160
# 15/15 [==============================] - 1s 87ms/step - loss: 3.4176 - mse: 3.4176 - lr: 3.4549e-04
# Epoch 134/160
# 15/15 [==============================] - 1s 84ms/step - loss: 3.4584 - mse: 3.4584 - lr: 2.7300e-04
# Epoch 135/160
# 15/15 [==============================] - 1s 84ms/step - loss: 3.5424 - mse: 3.5424 - lr: 2.0611e-04
# Epoch 136/160
# 15/15 [==============================] - 1s 88ms/step - loss: 3.4782 - mse: 3.4782 - lr: 1.4645e-04
# Epoch 137/160
# 15/15 [==============================] - 1s 85ms/step - loss: 3.4721 - mse: 3.4721 - lr: 9.5492e-05
# Epoch 138/160
# 15/15 [==============================] - 1s 83ms/step - loss: 3.4207 - mse: 3.4207 - lr: 5.4497e-05
# Epoch 139/160
# 15/15 [==============================] - 1s 85ms/step - loss: 3.4426 - mse: 3.4426 - lr: 2.4472e-05
# Epoch 140/160
# 15/15 [==============================] - 1s 89ms/step - loss: 3.4816 - mse: 3.4816 - lr: 6.1558e-06
# Epoch 141/160
# 15/15 [==============================] - 1s 86ms/step - loss: 3.4362 - mse: 3.4362 - lr: 0.0010
# Epoch 142/160
# 15/15 [==============================] - 1s 87ms/step - loss: 3.4112 - mse: 3.4112 - lr: 9.9384e-04
# Epoch 143/160
# 15/15 [==============================] - 1s 84ms/step - loss: 3.4491 - mse: 3.4491 - lr: 9.7553e-04
# Epoch 144/160
# 15/15 [==============================] - 1s 89ms/step - loss: 3.5140 - mse: 3.5140 - lr: 9.4550e-04
# Epoch 145/160
# 15/15 [==============================] - 1s 84ms/step - loss: 3.5328 - mse: 3.5328 - lr: 9.0451e-04
# Epoch 146/160
# 15/15 [==============================] - 1s 84ms/step - loss: 3.5828 - mse: 3.5828 - lr: 8.5355e-04
# Epoch 147/160
# 15/15 [==============================] - 1s 86ms/step - loss: 3.4933 - mse: 3.4933 - lr: 7.9389e-04
# Epoch 148/160
# 15/15 [==============================] - 1s 86ms/step - loss: 3.5526 - mse: 3.5526 - lr: 7.2700e-04
# Epoch 149/160
# 15/15 [==============================] - 1s 90ms/step - loss: 3.4732 - mse: 3.4732 - lr: 6.5451e-04
# Epoch 150/160
# 15/15 [==============================] - 1s 84ms/step - loss: 3.4675 - mse: 3.4675 - lr: 5.7822e-04
# Epoch 151/160
# 15/15 [==============================] - 1s 83ms/step - loss: 3.4853 - mse: 3.4853 - lr: 5.0000e-04
# Epoch 152/160
# 15/15 [==============================] - 1s 83ms/step - loss: 3.5897 - mse: 3.5897 - lr: 4.2178e-04
# Epoch 153/160
# 15/15 [==============================] - 1s 84ms/step - loss: 3.4724 - mse: 3.4724 - lr: 3.4549e-04
# Epoch 154/160
# 15/15 [==============================] - 1s 87ms/step - loss: 3.5265 - mse: 3.5265 - lr: 2.7300e-04
# Epoch 155/160
# 15/15 [==============================] - 1s 88ms/step - loss: 3.4231 - mse: 3.4231 - lr: 2.0611e-04
# Epoch 156/160
# 15/15 [==============================] - 1s 85ms/step - loss: 3.4980 - mse: 3.4980 - lr: 1.4645e-04
# Epoch 157/160
# 15/15 [==============================] - 1s 85ms/step - loss: 3.4102 - mse: 3.4102 - lr: 9.5492e-05
# Epoch 158/160
# 15/15 [==============================] - 1s 83ms/step - loss: 3.3619 - mse: 3.3619 - lr: 5.4497e-05
# Epoch 159/160
# 15/15 [==============================] - 1s 87ms/step - loss: 3.4530 - mse: 3.4530 - lr: 2.4472e-05
# Epoch 160/160
# 15/15 [==============================] - 1s 89ms/step - loss: 3.4858 - mse: 3.4858 - lr: 6.1558e-06
# train error 1.7826717
